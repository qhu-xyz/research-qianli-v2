# %%
from pbase.config.ray import init_ray
import shadow_price_prediction

# Initialize Ray for parallel processing
extra_modules = [shadow_price_prediction]
init_ray(address='ray://10.8.0.36:10001', extra_modules=extra_modules)

import pandas as pd
import numpy as np
import random
from pathlib import Path
from pbase.utils.ray import parallel_equal_pool
from shadow_price_prediction.config import PredictionConfig

# Import tuning utilities for resumable search
from shadow_price_prediction.tuning_utils import (
    load_previous_params,
    sample_params,
    run_single_experiment
)

pd.set_option('display.max_columns', 99)

config = PredictionConfig()
# Out:
# 2025-12-10 20:30:30,508	INFO client_builder.py:242 -- Passing the following kwargs to ray.init() on the server: log_to_driver
# 2025-12-10 20:30:30,987	INFO packaging.py:588 -- Creating a file package for local module '/home/xyz/workspace/research-spice-shadow-price-pred/src/shadow_price_prediction'.
# 2025-12-10 20:30:30,992	INFO packaging.py:380 -- Pushing file package 'gcs://_ray_pkg_ba3b00fba20e751b.zip' (0.40MiB) to Ray cluster...
# 2025-12-10 20:30:30,996	INFO packaging.py:393 -- Successfully pushed file package 'gcs://_ray_pkg_ba3b00fba20e751b.zip'.
# SIGTERM handler is not set because current thread is not the main thread.

# %%
import pandas as pd
from shadow_price_prediction.config import PredictionConfig
from shadow_price_prediction.tuning_utils import update_config_with_params
from shadow_price_prediction.pipeline import ShadowPricePipeline

def create_pipeline_from_row(row):
    """
    Create a ShadowPricePipeline using the parameters from a single row of results.
    
    Args:
        row: DataFrame row with parameters
    
    Returns:
        ShadowPricePipeline configured with the parameters
    """
    params_dict = row.to_dict()
        
    print("Initializing pipeline with selected parameters:")
    for k, v in params_dict.items():
         print(f"  {k}: {v}")

    # Create Config
    config = PredictionConfig()
    
    # Update Config with Params
    config = update_config_with_params(config, params_dict)
    
    # Initialize Pipeline
    pipeline = ShadowPricePipeline(config)
    
    return pipeline

# %%
params = {
    'clf_xgb_n_estimators': 500,
    'clf_xgb_max_depth': 3,
    'clf_xgb_learning_rate': 0.3,
    'clf_xgb_gamma': 0,
    'clf_xgb_min_child_weight': 10,
    'clf_xgb_reg_alpha': 0.5,
    'clf_xgb_reg_lambda': 5,
    'reg_xgb_n_estimators': 500,
    'reg_xgb_max_depth': 3,
    'reg_xgb_learning_rate': 0.05,
    'reg_xgb_gamma': 0,
    'reg_xgb_min_child_weight': 10,
    'reg_xgb_reg_alpha': 0.5,
    'reg_xgb_reg_lambda': 10,
    'lr_penalty': 'l2',
    'lr_C': 10.0,
    'enet_alpha': 1.0,
    'enet_l1_ratio': 0.9,
    'threshold_beta': 10,
    'clf_xgb_thres': 1,
    'reg_xgb_thres': 1,
    'clf_lr_thres': 0.1,
    'reg_enet_thres': 0.1,

    'short_term_clf_xgb_w': 1,
    'short_term_reg_xgb_w': 1,
    'long_term_clf_xgb_w': 1,
    'long_term_reg_xgb_w': 1,
}

pipeline = create_pipeline_from_row(pd.Series(params))
# Out:
# Initializing pipeline with selected parameters:
#   clf_xgb_n_estimators: 500
#   clf_xgb_max_depth: 3
#   clf_xgb_learning_rate: 0.3
#   clf_xgb_gamma: 0
#   clf_xgb_min_child_weight: 10
#   clf_xgb_reg_alpha: 0.5
#   clf_xgb_reg_lambda: 5
#   reg_xgb_n_estimators: 500
#   reg_xgb_max_depth: 3
#   reg_xgb_learning_rate: 0.05
#   reg_xgb_gamma: 0
#   reg_xgb_min_child_weight: 10
#   reg_xgb_reg_alpha: 0.5
#   reg_xgb_reg_lambda: 10
#   lr_penalty: l2
#   lr_C: 10.0
#   enet_alpha: 1.0
#   enet_l1_ratio: 0.9
#   threshold_beta: 10
#   clf_xgb_thres: 1
#   reg_xgb_thres: 1
#   clf_lr_thres: 0.1
#   reg_enet_thres: 0.1
#   short_term_clf_xgb_w: 1
#   short_term_reg_xgb_w: 1
#   long_term_clf_xgb_w: 1
#   long_term_reg_xgb_w: 1

# %%
# PJM Execution
from shadow_price_prediction.iso_configs import PJM_ISO_CONFIG, PJM_HORIZON_GROUPS

# 1. Update Config for PJM
config = PredictionConfig()
config.iso = PJM_ISO_CONFIG
config.horizon_groups = PJM_HORIZON_GROUPS

# 2. Initialize Pipeline
# Using the same params as MISO for now, or you can define new ones
pipeline = ShadowPricePipeline(config)

# 3. Define Test Periods for PJM
test_periods = []

# PJM doesn't use q-periods, so logic is simpler
# Just check if f-period is in schedule
def get_pjm_period_type(auction_month, market_month):
    f_period = f'f{(market_month.year - auction_month.year)*12 + market_month.month - auction_month.month}'
    
    all_periods = config.iso.auction_schedule.get(auction_month.month, [])
    if f_period in all_periods:
        return f_period
    return None

# Example range for PJM
for auction_month in pd.date_range('2024-06', '2025-12', freq='MS'):
# for auction_month in pd.date_range('2024-09', '2024-09', freq='MS'):
    # PJM usually goes out 3 years, but let's just do 1 year for testing
    market_st = auction_month
    market_et = market_st
    # market_et = market_st + pd.offsets.MonthBegin(12)
    # market_et = market_et.replace(month=5)
    
    for market_month in pd.date_range(start=market_st, end=market_et, freq='MS'):
        if get_pjm_period_type(auction_month, market_month) is None:
            continue
        test_periods.append((auction_month, market_month))

print(f"PJM Test Periods: {len(test_periods)}")
# Out:
# PJM Test Periods: 19

# %%
# 4. Run Pipeline
results_per_outage, final_results, metrics, training_res, models = pipeline.run(
    test_periods=test_periods,
    verbose=True,
    use_parallel=True,
    n_jobs=36,
    output_dir='/opt/temp/tmp/pw_data/spice6/prod_f0p_model_pjm/ml_pred/', # Separate output dir for PJM
    refresh=True,
    class_type='onpeak',
    branch_name=None,
    # branch_name='CEN-REU1       1'
)
# Out:
# ================================================================================
# SHADOW PRICE PREDICTION PIPELINE - PARALLEL PER-AUCTION-MONTH MODE
# ================================================================================
# Total Test Periods: 19
# Unique Auction Months: 19
#
#   Auction: 2024-06 → 1 market month(s)
#     - Market: 2024-06
#   Auction: 2024-07 → 1 market month(s)
#     - Market: 2024-07
#   Auction: 2024-08 → 1 market month(s)
#     - Market: 2024-08
#   Auction: 2024-09 → 1 market month(s)
#     - Market: 2024-09
#   Auction: 2024-10 → 1 market month(s)
#     - Market: 2024-10
#   Auction: 2024-11 → 1 market month(s)
#     - Market: 2024-11
#   Auction: 2024-12 → 1 market month(s)
#     - Market: 2024-12
#   Auction: 2025-01 → 1 market month(s)
#     - Market: 2025-01
#   Auction: 2025-02 → 1 market month(s)
#     - Market: 2025-02
#   Auction: 2025-03 → 1 market month(s)
#     - Market: 2025-03
#   Auction: 2025-04 → 1 market month(s)
#     - Market: 2025-04
#   Auction: 2025-05 → 1 market month(s)
#     - Market: 2025-05
#   Auction: 2025-06 → 1 market month(s)
#     - Market: 2025-06
#   Auction: 2025-07 → 1 market month(s)
#     - Market: 2025-07
#   Auction: 2025-08 → 1 market month(s)
#     - Market: 2025-08
#   Auction: 2025-09 → 1 market month(s)
#     - Market: 2025-09
#   Auction: 2025-10 → 1 market month(s)
#     - Market: 2025-10
#   Auction: 2025-11 → 1 market month(s)
#     - Market: 2025-11
#   Auction: 2025-12 → 1 market month(s)
#     - Market: 2025-12
# Class Type: onpeak
#
# 🚀 Using Ray parallel processing for 19 auction months
#    Workers: 36
#
# ================================================================================
# [PARALLEL PROCESSING: Training and Predicting for All Auction Months]
# ================================================================================
#   0%|          | 0/19 [00:00<?, ?it/s]
# (PoolActor pid=3283545, ip=10.42.6.149)
# (PoolActor pid=3283545, ip=10.42.6.149) ================================================================================
# (PoolActor pid=3283545, ip=10.42.6.149) [Processing Auction Month: 2024-06]
# (PoolActor pid=3283545, ip=10.42.6.149)   Market Months: 1
# (PoolActor pid=3283545, ip=10.42.6.149)     - 2024-06
# (PoolActor pid=3283545, ip=10.42.6.149) ================================================================================
# (PoolActor pid=3283611, ip=10.42.6.149)
# (PoolActor pid=3283611, ip=10.42.6.149) ================================================================================
# (PoolActor pid=3283611, ip=10.42.6.149) [Processing Auction Month: 2025-07]
# (PoolActor pid=3283611, ip=10.42.6.149)   Market Months: 1
# (PoolActor pid=3283611, ip=10.42.6.149)     - 2025-07
# (PoolActor pid=3283611, ip=10.42.6.149) ================================================================================
# (PoolActor pid=3032598, ip=10.42.8.15)
# (PoolActor pid=3032598, ip=10.42.8.15) ================================================================================
# (PoolActor pid=3032598, ip=10.42.8.15) [Processing Auction Month: 2024-09]
# (PoolActor pid=3032598, ip=10.42.8.15)   Market Months: 1
# (PoolActor pid=3032598, ip=10.42.8.15)     - 2024-09
# (PoolActor pid=3032598, ip=10.42.8.15) ================================================================================
# (PoolActor pid=3032600, ip=10.42.8.15)
# (PoolActor pid=3032600, ip=10.42.8.15) ================================================================================
# (PoolActor pid=3032600, ip=10.42.8.15) [Processing Auction Month: 2025-09]
# (PoolActor pid=3032600, ip=10.42.8.15)   Market Months: 1
# (PoolActor pid=3032600, ip=10.42.8.15)     - 2025-09
# (PoolActor pid=3032600, ip=10.42.8.15) ================================================================================
# (PoolActor pid=3032599, ip=10.42.8.15)
# (PoolActor pid=3032599, ip=10.42.8.15) ================================================================================
# (PoolActor pid=3032599, ip=10.42.8.15) [Processing Auction Month: 2025-03]
# (PoolActor pid=3032599, ip=10.42.8.15)   Market Months: 1
# (PoolActor pid=3032599, ip=10.42.8.15)     - 2025-03
# (PoolActor pid=3032599, ip=10.42.8.15) ================================================================================
# (PoolActor pid=2969086, ip=10.42.7.70)
# (PoolActor pid=2969086, ip=10.42.7.70) ================================================================================
# (PoolActor pid=2969086, ip=10.42.7.70) [Processing Auction Month: 2025-11]
# (PoolActor pid=2969086, ip=10.42.7.70)   Market Months: 1
# (PoolActor pid=2969086, ip=10.42.7.70)     - 2025-11
# (PoolActor pid=2969086, ip=10.42.7.70) ================================================================================
# (PoolActor pid=2969085, ip=10.42.7.70)
# (PoolActor pid=2969085, ip=10.42.7.70) ================================================================================
# (PoolActor pid=2969085, ip=10.42.7.70) [Processing Auction Month: 2025-05]
# (PoolActor pid=2969085, ip=10.42.7.70)   Market Months: 1
# (PoolActor pid=2969085, ip=10.42.7.70)     - 2025-05
# (PoolActor pid=2969085, ip=10.42.7.70) ================================================================================
# (PoolActor pid=2969084, ip=10.42.7.70)
# (PoolActor pid=2969084, ip=10.42.7.70) ================================================================================
# (PoolActor pid=2969084, ip=10.42.7.70) [Processing Auction Month: 2024-11]
# (PoolActor pid=2969084, ip=10.42.7.70)   Market Months: 1
# (PoolActor pid=2969084, ip=10.42.7.70)     - 2024-11
# (PoolActor pid=2969084, ip=10.42.7.70) ================================================================================
# (PoolActor pid=3036046, ip=10.42.9.131)
# (PoolActor pid=3036046, ip=10.42.9.131) ================================================================================
# (PoolActor pid=3036046, ip=10.42.9.131) [Processing Auction Month: 2025-08]
# (PoolActor pid=3036046, ip=10.42.9.131)   Market Months: 1
# (PoolActor pid=3036046, ip=10.42.9.131)     - 2025-08
# (PoolActor pid=3036046, ip=10.42.9.131) ================================================================================
# (PoolActor pid=3036045, ip=10.42.9.131)
# (PoolActor pid=3036045, ip=10.42.9.131) ================================================================================
# (PoolActor pid=3036045, ip=10.42.9.131) [Processing Auction Month: 2025-02]
# (PoolActor pid=3036045, ip=10.42.9.131)   Market Months: 1
# (PoolActor pid=3036045, ip=10.42.9.131)     - 2025-02
# (PoolActor pid=3036045, ip=10.42.9.131) ================================================================================
# (PoolActor pid=3036044, ip=10.42.9.131)
# (PoolActor pid=3036044, ip=10.42.9.131) ================================================================================
# (PoolActor pid=3036044, ip=10.42.9.131) [Processing Auction Month: 2024-08]
# (PoolActor pid=3036044, ip=10.42.9.131)   Market Months: 1
# (PoolActor pid=3036044, ip=10.42.9.131)     - 2024-08
# (PoolActor pid=3036044, ip=10.42.9.131) ================================================================================
# (PoolActor pid=2969429, ip=10.42.0.182)
# (PoolActor pid=2969429, ip=10.42.0.182) ================================================================================
# (PoolActor pid=2969429, ip=10.42.0.182) [Processing Auction Month: 2024-10]
# (PoolActor pid=2969429, ip=10.42.0.182)   Market Months: 1
# (PoolActor pid=2969429, ip=10.42.0.182)     - 2024-10
# (PoolActor pid=2969429, ip=10.42.0.182) ================================================================================
# (PoolActor pid=2969427, ip=10.42.0.182)
# (PoolActor pid=2969427, ip=10.42.0.182) ================================================================================
# (PoolActor pid=2969427, ip=10.42.0.182) [Processing Auction Month: 2025-04]
# (PoolActor pid=2969427, ip=10.42.0.182)   Market Months: 1
# (PoolActor pid=2969427, ip=10.42.0.182)     - 2025-04
# (PoolActor pid=2969427, ip=10.42.0.182) ================================================================================
# (PoolActor pid=2969428, ip=10.42.0.182)
# (PoolActor pid=2969428, ip=10.42.0.182) ================================================================================
# (PoolActor pid=2969428, ip=10.42.0.182) [Processing Auction Month: 2025-10]
# (PoolActor pid=2969428, ip=10.42.0.182)   Market Months: 1
# (PoolActor pid=2969428, ip=10.42.0.182)     - 2025-10
# (PoolActor pid=2969428, ip=10.42.0.182) ================================================================================
# (PoolActor pid=3283546, ip=10.42.6.149)
# (PoolActor pid=3283546, ip=10.42.6.149) ================================================================================
# (PoolActor pid=3283546, ip=10.42.6.149) [Processing Auction Month: 2025-01]
# (PoolActor pid=3283546, ip=10.42.6.149)   Market Months: 1
# (PoolActor pid=3283546, ip=10.42.6.149)     - 2025-01
# (PoolActor pid=3283546, ip=10.42.6.149) ================================================================================
# (PoolActor pid=3051848, ip=10.42.4.173)
# (PoolActor pid=3051848, ip=10.42.4.173) ================================================================================
# (PoolActor pid=3051848, ip=10.42.4.173) [Processing Auction Month: 2024-07]
# (PoolActor pid=3051848, ip=10.42.4.173)   Market Months: 1
# (PoolActor pid=3051848, ip=10.42.4.173)     - 2024-07
# (PoolActor pid=3051848, ip=10.42.4.173) ================================================================================
# (PoolActor pid=3051851, ip=10.42.4.173)
# (PoolActor pid=3051851, ip=10.42.4.173) ================================================================================
# (PoolActor pid=3051851, ip=10.42.4.173) [Processing Auction Month: 2025-12]
# (PoolActor pid=3051851, ip=10.42.4.173)   Market Months: 1
# (PoolActor pid=3051851, ip=10.42.4.173)     - 2025-12
# (PoolActor pid=3051851, ip=10.42.4.173) ================================================================================
# (PoolActor pid=3051849, ip=10.42.4.173)
# (PoolActor pid=3051849, ip=10.42.4.173) ================================================================================
# (PoolActor pid=3051849, ip=10.42.4.173) [Processing Auction Month: 2024-12]
# (PoolActor pid=3051849, ip=10.42.4.173)   Market Months: 1
# (PoolActor pid=3051849, ip=10.42.4.173)     - 2024-12
# (PoolActor pid=3051849, ip=10.42.4.173) ================================================================================
# (PoolActor pid=3051850, ip=10.42.4.173)
# (PoolActor pid=3051850, ip=10.42.4.173) ================================================================================
# (PoolActor pid=3051850, ip=10.42.4.173) [Processing Auction Month: 2025-06]
# (PoolActor pid=3051850, ip=10.42.4.173)   Market Months: 1
# (PoolActor pid=3051850, ip=10.42.4.173)     - 2025-06
# (PoolActor pid=3051850, ip=10.42.4.173) ================================================================================
# (PoolActor pid=3283545, ip=10.42.6.149) 25-12-07 11:10:08 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=3283545, ip=10.42.6.149) 25-12-07 11:10:08 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=3283545, ip=10.42.6.149) 25-12-07 11:10:08 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=3283545, ip=10.42.6.149) 25-12-07 11:10:08 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=3283546, ip=10.42.6.149) 25-12-07 11:10:08 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=3283546, ip=10.42.6.149) 25-12-07 11:10:08 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=3283546, ip=10.42.6.149) 25-12-07 11:10:08 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=3283546, ip=10.42.6.149) 25-12-07 11:10:08 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=3283611, ip=10.42.6.149) 25-12-07 11:10:08 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=3283611, ip=10.42.6.149) 25-12-07 11:10:08 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=3283611, ip=10.42.6.149) 25-12-07 11:10:08 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=3283611, ip=10.42.6.149) 25-12-07 11:10:08 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=3032600, ip=10.42.8.15) 25-12-07 11:10:08 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=3032600, ip=10.42.8.15) 25-12-07 11:10:08 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=3032600, ip=10.42.8.15) 25-12-07 11:10:08 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=3032600, ip=10.42.8.15) 25-12-07 11:10:08 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=3032598, ip=10.42.8.15) 25-12-07 11:10:08 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=3032598, ip=10.42.8.15) 25-12-07 11:10:08 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=3032598, ip=10.42.8.15) 25-12-07 11:10:08 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=3032598, ip=10.42.8.15) 25-12-07 11:10:08 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=2969084, ip=10.42.7.70) 25-12-07 11:10:08 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=2969084, ip=10.42.7.70) 25-12-07 11:10:08 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=2969084, ip=10.42.7.70) 25-12-07 11:10:08 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=2969084, ip=10.42.7.70) 25-12-07 11:10:08 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=3032599, ip=10.42.8.15) 25-12-07 11:10:08 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=3032599, ip=10.42.8.15) 25-12-07 11:10:08 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=3032599, ip=10.42.8.15) 25-12-07 11:10:08 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=3032599, ip=10.42.8.15) 25-12-07 11:10:08 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=2969085, ip=10.42.7.70) 25-12-07 11:10:08 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=2969085, ip=10.42.7.70) 25-12-07 11:10:08 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=2969085, ip=10.42.7.70) 25-12-07 11:10:08 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=2969085, ip=10.42.7.70) 25-12-07 11:10:08 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=2969086, ip=10.42.7.70) 25-12-07 11:10:08 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=2969086, ip=10.42.7.70) 25-12-07 11:10:08 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=2969086, ip=10.42.7.70) 25-12-07 11:10:08 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=2969086, ip=10.42.7.70) 25-12-07 11:10:08 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=3051848, ip=10.42.4.173) 25-12-07 11:10:08 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=3051848, ip=10.42.4.173) 25-12-07 11:10:08 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=3051848, ip=10.42.4.173) 25-12-07 11:10:08 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=3051848, ip=10.42.4.173) 25-12-07 11:10:08 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=3051849, ip=10.42.4.173) 25-12-07 11:10:08 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=3051849, ip=10.42.4.173) 25-12-07 11:10:08 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=3051849, ip=10.42.4.173) 25-12-07 11:10:08 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=3051849, ip=10.42.4.173) 25-12-07 11:10:08 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=3051850, ip=10.42.4.173) 25-12-07 11:10:08 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=3051850, ip=10.42.4.173) 25-12-07 11:10:08 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=3051850, ip=10.42.4.173) 25-12-07 11:10:08 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=3051850, ip=10.42.4.173) 25-12-07 11:10:08 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=3051851, ip=10.42.4.173) 25-12-07 11:10:08 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=3051851, ip=10.42.4.173) 25-12-07 11:10:08 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=3051851, ip=10.42.4.173) 25-12-07 11:10:08 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=3051851, ip=10.42.4.173) 25-12-07 11:10:08 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=3036046, ip=10.42.9.131) 25-12-07 11:10:08 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=3036046, ip=10.42.9.131) 25-12-07 11:10:08 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=3036046, ip=10.42.9.131) 25-12-07 11:10:08 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=3036046, ip=10.42.9.131) 25-12-07 11:10:08 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=3036044, ip=10.42.9.131) 25-12-07 11:10:08 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=3036044, ip=10.42.9.131) 25-12-07 11:10:08 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=3036044, ip=10.42.9.131) 25-12-07 11:10:08 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=3036044, ip=10.42.9.131) 25-12-07 11:10:08 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=3036045, ip=10.42.9.131) 25-12-07 11:10:08 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=3036045, ip=10.42.9.131) 25-12-07 11:10:08 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=3036045, ip=10.42.9.131) 25-12-07 11:10:08 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=3036045, ip=10.42.9.131) 25-12-07 11:10:08 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=2969428, ip=10.42.0.182) 25-12-07 11:10:08 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=2969428, ip=10.42.0.182) 25-12-07 11:10:08 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=2969428, ip=10.42.0.182) 25-12-07 11:10:08 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=2969428, ip=10.42.0.182) 25-12-07 11:10:08 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=2969429, ip=10.42.0.182) 25-12-07 11:10:08 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=2969429, ip=10.42.0.182) 25-12-07 11:10:08 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=2969429, ip=10.42.0.182) 25-12-07 11:10:08 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=2969429, ip=10.42.0.182) 25-12-07 11:10:08 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=2969427, ip=10.42.0.182) 25-12-07 11:10:08 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=2969427, ip=10.42.0.182) 25-12-07 11:10:08 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=2969427, ip=10.42.0.182) 25-12-07 11:10:08 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=2969427, ip=10.42.0.182) 25-12-07 11:10:08 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=3032598, ip=10.42.8.15)
# (PoolActor pid=3032598, ip=10.42.8.15) [STEP 1: Training Period Calculation]
# (PoolActor pid=3032598, ip=10.42.8.15)   Training Range: 2023-09 to 2024-08
# (PoolActor pid=3032598, ip=10.42.8.15)
# (PoolActor pid=3032598, ip=10.42.8.15) [STEP 2: Loading Training Data]
# (PoolActor pid=3032598, ip=10.42.8.15)   Loading training data for 2023-09 (Types: ['f0'])...
# (PoolActor pid=3032600, ip=10.42.8.15)
# (PoolActor pid=3032600, ip=10.42.8.15) [STEP 1: Training Period Calculation]
# (PoolActor pid=3032600, ip=10.42.8.15)   Training Range: 2024-09 to 2025-08
# (PoolActor pid=3032600, ip=10.42.8.15)
# (PoolActor pid=3032600, ip=10.42.8.15) [STEP 2: Loading Training Data]
# (PoolActor pid=3032600, ip=10.42.8.15)   Loading training data for 2024-09 (Types: ['f0'])...
# (PoolActor pid=3032599, ip=10.42.8.15)
# (PoolActor pid=3032599, ip=10.42.8.15) [STEP 1: Training Period Calculation]
# (PoolActor pid=3032599, ip=10.42.8.15)   Training Range: 2024-03 to 2025-02
# (PoolActor pid=3032599, ip=10.42.8.15)
# (PoolActor pid=3032599, ip=10.42.8.15) [STEP 2: Loading Training Data]
# (PoolActor pid=3032599, ip=10.42.8.15)   Loading training data for 2024-03 (Types: ['f0'])...
# (PoolActor pid=3283545, ip=10.42.6.149)
# (PoolActor pid=3283545, ip=10.42.6.149) [STEP 1: Training Period Calculation]
# (PoolActor pid=3283545, ip=10.42.6.149)   Training Range: 2023-06 to 2024-05
# (PoolActor pid=3283545, ip=10.42.6.149)
# (PoolActor pid=3283545, ip=10.42.6.149) [STEP 2: Loading Training Data]
# (PoolActor pid=3283545, ip=10.42.6.149)   Loading training data for 2023-06 (Types: ['f0'])...
# (PoolActor pid=3283546, ip=10.42.6.149)
# (PoolActor pid=3283546, ip=10.42.6.149) [STEP 1: Training Period Calculation]
# (PoolActor pid=3283546, ip=10.42.6.149)   Training Range: 2024-01 to 2024-12
# (PoolActor pid=3283546, ip=10.42.6.149)
# (PoolActor pid=3283546, ip=10.42.6.149) [STEP 2: Loading Training Data]
# (PoolActor pid=3283546, ip=10.42.6.149)   Loading training data for 2024-01 (Types: ['f0'])...
# (PoolActor pid=3283611, ip=10.42.6.149)
# (PoolActor pid=3283611, ip=10.42.6.149) [STEP 1: Training Period Calculation]
# (PoolActor pid=3283611, ip=10.42.6.149)   Training Range: 2024-07 to 2025-06
# (PoolActor pid=3283611, ip=10.42.6.149)
# (PoolActor pid=3283611, ip=10.42.6.149) [STEP 2: Loading Training Data]
# (PoolActor pid=3283611, ip=10.42.6.149)   Loading training data for 2024-07 (Types: ['f0'])...
# (PoolActor pid=3051848, ip=10.42.4.173)
# (PoolActor pid=3051848, ip=10.42.4.173) [STEP 1: Training Period Calculation]
# (PoolActor pid=3051848, ip=10.42.4.173)   Training Range: 2023-07 to 2024-06
# (PoolActor pid=3051848, ip=10.42.4.173)
# (PoolActor pid=3051848, ip=10.42.4.173) [STEP 2: Loading Training Data]
# (PoolActor pid=3051848, ip=10.42.4.173)   Loading training data for 2023-07 (Types: ['f0'])...
# (PoolActor pid=3051851, ip=10.42.4.173)
# (PoolActor pid=3051851, ip=10.42.4.173) [STEP 1: Training Period Calculation]
# (PoolActor pid=3051851, ip=10.42.4.173)   Training Range: 2024-12 to 2025-11
# (PoolActor pid=3051851, ip=10.42.4.173)
# (PoolActor pid=3051851, ip=10.42.4.173) [STEP 2: Loading Training Data]
# (PoolActor pid=3051851, ip=10.42.4.173)   Loading training data for 2024-12 (Types: ['f0'])...
# (PoolActor pid=3051849, ip=10.42.4.173)
# (PoolActor pid=3051849, ip=10.42.4.173) [STEP 1: Training Period Calculation]
# (PoolActor pid=3051849, ip=10.42.4.173)   Training Range: 2023-12 to 2024-11
# (PoolActor pid=3051849, ip=10.42.4.173)
# (PoolActor pid=3051849, ip=10.42.4.173) [STEP 2: Loading Training Data]
# (PoolActor pid=3051849, ip=10.42.4.173)   Loading training data for 2023-12 (Types: ['f0'])...
# (PoolActor pid=3051850, ip=10.42.4.173)
# (PoolActor pid=3051850, ip=10.42.4.173) [STEP 1: Training Period Calculation]
# (PoolActor pid=3051850, ip=10.42.4.173)   Training Range: 2024-06 to 2025-05
# (PoolActor pid=3051850, ip=10.42.4.173)
# (PoolActor pid=3051850, ip=10.42.4.173) [STEP 2: Loading Training Data]
# (PoolActor pid=3051850, ip=10.42.4.173)   Loading training data for 2024-06 (Types: ['f0'])...
# (PoolActor pid=2969086, ip=10.42.7.70)
# (PoolActor pid=2969086, ip=10.42.7.70) [STEP 1: Training Period Calculation]
# (PoolActor pid=2969086, ip=10.42.7.70)   Training Range: 2024-11 to 2025-10
# (PoolActor pid=2969086, ip=10.42.7.70)
# (PoolActor pid=2969086, ip=10.42.7.70) [STEP 2: Loading Training Data]
# (PoolActor pid=2969086, ip=10.42.7.70)   Loading training data for 2024-11 (Types: ['f0'])...
# (PoolActor pid=2969085, ip=10.42.7.70)
# (PoolActor pid=2969085, ip=10.42.7.70) [STEP 1: Training Period Calculation]
# (PoolActor pid=2969085, ip=10.42.7.70)   Training Range: 2024-05 to 2025-04
# (PoolActor pid=2969085, ip=10.42.7.70)
# (PoolActor pid=2969085, ip=10.42.7.70) [STEP 2: Loading Training Data]
# (PoolActor pid=2969085, ip=10.42.7.70)   Loading training data for 2024-05 (Types: ['f0'])...
# (PoolActor pid=2969084, ip=10.42.7.70)
# (PoolActor pid=2969084, ip=10.42.7.70) [STEP 1: Training Period Calculation]
# (PoolActor pid=2969084, ip=10.42.7.70)   Training Range: 2023-11 to 2024-10
# (PoolActor pid=2969084, ip=10.42.7.70)
# (PoolActor pid=2969084, ip=10.42.7.70) [STEP 2: Loading Training Data]
# (PoolActor pid=2969084, ip=10.42.7.70)   Loading training data for 2023-11 (Types: ['f0'])...
# (PoolActor pid=3036046, ip=10.42.9.131)
# (PoolActor pid=3036046, ip=10.42.9.131) [STEP 1: Training Period Calculation]
# (PoolActor pid=3036046, ip=10.42.9.131)   Training Range: 2024-08 to 2025-07
# (PoolActor pid=3036046, ip=10.42.9.131)
# (PoolActor pid=3036046, ip=10.42.9.131) [STEP 2: Loading Training Data]
# (PoolActor pid=3036046, ip=10.42.9.131)   Loading training data for 2024-08 (Types: ['f0'])...
# (PoolActor pid=3036045, ip=10.42.9.131)
# (PoolActor pid=3036045, ip=10.42.9.131) [STEP 1: Training Period Calculation]
# (PoolActor pid=3036045, ip=10.42.9.131)   Training Range: 2024-02 to 2025-01
# (PoolActor pid=3036045, ip=10.42.9.131)
# (PoolActor pid=3036045, ip=10.42.9.131) [STEP 2: Loading Training Data]
# (PoolActor pid=3036045, ip=10.42.9.131)   Loading training data for 2024-02 (Types: ['f0'])...
# (PoolActor pid=3036044, ip=10.42.9.131)
# (PoolActor pid=3036044, ip=10.42.9.131) [STEP 1: Training Period Calculation]
# (PoolActor pid=3036044, ip=10.42.9.131)   Training Range: 2023-08 to 2024-07
# (PoolActor pid=3036044, ip=10.42.9.131)
# (PoolActor pid=3036044, ip=10.42.9.131) [STEP 2: Loading Training Data]
# (PoolActor pid=3036044, ip=10.42.9.131)   Loading training data for 2023-08 (Types: ['f0'])...
# (PoolActor pid=2969429, ip=10.42.0.182)
# (PoolActor pid=2969429, ip=10.42.0.182) [STEP 1: Training Period Calculation]
# (PoolActor pid=2969429, ip=10.42.0.182)   Training Range: 2023-10 to 2024-09
# (PoolActor pid=2969429, ip=10.42.0.182)
# (PoolActor pid=2969429, ip=10.42.0.182) [STEP 2: Loading Training Data]
# (PoolActor pid=2969429, ip=10.42.0.182)   Loading training data for 2023-10 (Types: ['f0'])...
# (PoolActor pid=2969427, ip=10.42.0.182)
# (PoolActor pid=2969427, ip=10.42.0.182) [STEP 1: Training Period Calculation]
# (PoolActor pid=2969427, ip=10.42.0.182)   Training Range: 2024-04 to 2025-03
# (PoolActor pid=2969427, ip=10.42.0.182)
# (PoolActor pid=2969427, ip=10.42.0.182) [STEP 2: Loading Training Data]
# (PoolActor pid=2969427, ip=10.42.0.182)   Loading training data for 2024-04 (Types: ['f0'])...
# (PoolActor pid=2969428, ip=10.42.0.182)
# (PoolActor pid=2969428, ip=10.42.0.182) [STEP 1: Training Period Calculation]
# (PoolActor pid=2969428, ip=10.42.0.182)   Training Range: 2024-10 to 2025-09
# (PoolActor pid=2969428, ip=10.42.0.182)
# (PoolActor pid=2969428, ip=10.42.0.182) [STEP 2: Loading Training Data]
# (PoolActor pid=2969428, ip=10.42.0.182)   Loading training data for 2024-10 (Types: ['f0'])...
# (PoolActor pid=3032600, ip=10.42.8.15) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 768 hours => 1184 hours
# (PoolActor pid=3032600, ip=10.42.8.15) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 768 hours => 1168 hours
# (PoolActor pid=3032598, ip=10.42.8.15) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 768 hours => 1152 hours
# (PoolActor pid=3032598, ip=10.42.8.15) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 768 hours => 1200 hours
# (PoolActor pid=3032599, ip=10.42.8.15) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 720 hours => 1088 hours
# (PoolActor pid=3032599, ip=10.42.8.15) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 768 hours => 1168 hours
# (PoolActor pid=3032599, ip=10.42.8.15) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 768 hours => 1216 hours
# (PoolActor pid=3032600, ip=10.42.8.15) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 744 hours => 1152 hours
# (PoolActor pid=3032598, ip=10.42.8.15) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 744 hours => 1136 hours
# (PoolActor pid=3283545, ip=10.42.6.149) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 768 hours => 1168 hours
# (PoolActor pid=3283545, ip=10.42.6.149) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 744 hours => 1152 hours
# (PoolActor pid=3283546, ip=10.42.6.149) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 768 hours => 1216 hours
# (PoolActor pid=3283611, ip=10.42.6.149) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 744 hours => 1152 hours
# (PoolActor pid=3032600, ip=10.42.8.15) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 745 hours => 1138 hours
# (PoolActor pid=3032600, ip=10.42.8.15) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 768 hours => 1168 hours
# (PoolActor pid=3032600, ip=10.42.8.15) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 744 hours => 1168 hours
# (PoolActor pid=3032598, ip=10.42.8.15) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 745 hours => 1138 hours
# (PoolActor pid=3032598, ip=10.42.8.15) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 768 hours => 1184 hours
# (PoolActor pid=3032598, ip=10.42.8.15) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 744 hours => 1152 hours
# (PoolActor pid=3032599, ip=10.42.8.15) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 768 hours => 1168 hours
# (PoolActor pid=3032599, ip=10.42.8.15) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 744 hours => 1152 hours
# (PoolActor pid=3032599, ip=10.42.8.15) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 767 hours => 1166 hours
# (PoolActor pid=3283545, ip=10.42.6.149) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 767 hours => 1166 hours
# (PoolActor pid=3283545, ip=10.42.6.149) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 768 hours => 1152 hours
# (PoolActor pid=3283546, ip=10.42.6.149) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 745 hours => 1138 hours
# (PoolActor pid=3283546, ip=10.42.6.149) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 768 hours => 1168 hours
# (PoolActor pid=3283611, ip=10.42.6.149) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 768 hours => 1184 hours
# (PoolActor pid=3283611, ip=10.42.6.149) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 744 hours => 1120 hours
# (PoolActor pid=3032600, ip=10.42.8.15) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 745 hours => 1138 hours
# (PoolActor pid=3032600, ip=10.42.8.15) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 768 hours => 1184 hours
# (PoolActor pid=3032600, ip=10.42.8.15) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 744 hours => 1152 hours
# (PoolActor pid=3032600, ip=10.42.8.15) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 745 hours => 1138 hours
# (PoolActor pid=3032598, ip=10.42.8.15) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 745 hours => 1138 hours
# (PoolActor pid=3032598, ip=10.42.8.15) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 768 hours => 1184 hours
# (PoolActor pid=3032598, ip=10.42.8.15) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 744 hours => 1136 hours
# (PoolActor pid=3032599, ip=10.42.8.15) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 768 hours => 1184 hours
# (PoolActor pid=3032599, ip=10.42.8.15) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 744 hours => 1152 hours
# (PoolActor pid=3032599, ip=10.42.8.15) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 767 hours => 1150 hours
# (PoolActor pid=2969084, ip=10.42.7.70) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 768 hours => 1168 hours
# (PoolActor pid=2969085, ip=10.42.7.70) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 744 hours => 1120 hours
# (PoolActor pid=2969086, ip=10.42.7.70) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 768 hours => 1152 hours
# (PoolActor pid=3036046, ip=10.42.9.131) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 768 hours => 1168 hours
# (PoolActor pid=3036046, ip=10.42.9.131) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 744 hours => 1152 hours
# (PoolActor pid=3036044, ip=10.42.9.131) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 768 hours => 1200 hours
# (PoolActor pid=3036044, ip=10.42.9.131) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 744 hours => 1136 hours
# (PoolActor pid=3036045, ip=10.42.9.131) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 768 hours => 1168 hours
# (PoolActor pid=3036045, ip=10.42.9.131) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 768 hours => 1216 hours
# (PoolActor pid=2969428, ip=10.42.0.182) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 744 hours => 1152 hours
# (PoolActor pid=2969429, ip=10.42.0.182) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 744 hours => 1168 hours
# (PoolActor pid=2969427, ip=10.42.0.182) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 767 hours => 1182 hours
# (PoolActor pid=2969428, ip=10.42.0.182) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 768 hours => 1184 hours
# (PoolActor pid=3051848, ip=10.42.4.173) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 744 hours => 1136 hours
# (PoolActor pid=3051848, ip=10.42.4.173) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 768 hours => 1168 hours
# (PoolActor pid=3051849, ip=10.42.4.173) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 745 hours => 1138 hours
# (PoolActor pid=3051849, ip=10.42.4.173) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 768 hours => 1168 hours
# (PoolActor pid=3051850, ip=10.42.4.173) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 768 hours => 1184 hours
# (PoolActor pid=3051850, ip=10.42.4.173) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 744 hours => 1120 hours
# (PoolActor pid=3051851, ip=10.42.4.173) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 745 hours => 1170 hours
# (PoolActor pid=3051851, ip=10.42.4.173) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 768 hours => 1152 hours
# (PoolActor pid=3032600, ip=10.42.8.15) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 768 hours => 1184 hours
# (PoolActor pid=3032600, ip=10.42.8.15) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 744 hours => 1136 hours
# (PoolActor pid=3032598, ip=10.42.8.15) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 745 hours => 1154 hours
# (PoolActor pid=3032598, ip=10.42.8.15) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 769 hours => 1186 hours
# (PoolActor pid=3032598, ip=10.42.8.15) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 744 hours => 1136 hours
# (PoolActor pid=3032599, ip=10.42.8.15) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 768 hours => 1200 hours
# (PoolActor pid=3032599, ip=10.42.8.15) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 744 hours => 1136 hours
# (PoolActor pid=3032599, ip=10.42.8.15) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 767 hours => 1150 hours
# (PoolActor pid=2969084, ip=10.42.7.70) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 744 hours => 1168 hours
# (PoolActor pid=2969084, ip=10.42.7.70) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 768 hours => 1152 hours
# (PoolActor pid=2969085, ip=10.42.7.70) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 767 hours => 1182 hours
# (PoolActor pid=2969085, ip=10.42.7.70) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 720 hours => 1088 hours
# (PoolActor pid=2969086, ip=10.42.7.70) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 744 hours => 1152 hours
# (PoolActor pid=2969086, ip=10.42.7.70) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 768 hours => 1184 hours
# (PoolActor pid=3036046, ip=10.42.9.131) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 768 hours => 1184 hours
# (PoolActor pid=3036046, ip=10.42.9.131) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 768 hours => 1152 hours
# (PoolActor pid=3036044, ip=10.42.9.131) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 768 hours => 1168 hours
# (PoolActor pid=3036044, ip=10.42.9.131) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 768 hours => 1152 hours
# (PoolActor pid=3036045, ip=10.42.9.131) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 745 hours => 1138 hours
# (PoolActor pid=3036045, ip=10.42.9.131) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 696 hours => 1056 hours
# (PoolActor pid=2969428, ip=10.42.0.182) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 768 hours => 1168 hours
# (PoolActor pid=2969428, ip=10.42.0.182) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 745 hours => 1138 hours
# (PoolActor pid=2969429, ip=10.42.0.182) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 768 hours => 1152 hours
# (PoolActor pid=2969429, ip=10.42.0.182) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 768 hours => 1200 hours
# (PoolActor pid=2969429, ip=10.42.0.182) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 745 hours => 1138 hours
# (PoolActor pid=2969427, ip=10.42.0.182) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 720 hours => 1088 hours
# (PoolActor pid=2969427, ip=10.42.0.182) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 768 hours => 1168 hours
# (PoolActor pid=2969427, ip=10.42.0.182) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 768 hours => 1168 hours
# (PoolActor pid=3051848, ip=10.42.4.173) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 744 hours => 1152 hours
# (PoolActor pid=3051848, ip=10.42.4.173) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 768 hours => 1152 hours
# (PoolActor pid=3051848, ip=10.42.4.173) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 744 hours => 1168 hours
# (PoolActor pid=3051849, ip=10.42.4.173) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 744 hours => 1168 hours
# (PoolActor pid=3051849, ip=10.42.4.173) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 696 hours => 1056 hours
# (PoolActor pid=3051849, ip=10.42.4.173) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 768 hours => 1184 hours
# (PoolActor pid=3051850, ip=10.42.4.173) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 767 hours => 1182 hours
# (PoolActor pid=3051850, ip=10.42.4.173) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 768 hours => 1152 hours
# (PoolActor pid=3051851, ip=10.42.4.173) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 744 hours => 1152 hours
# (PoolActor pid=3051851, ip=10.42.4.173) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 720 hours => 1088 hours
# (PoolActor pid=3283545, ip=10.42.6.149) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 744 hours => 1168 hours
# (PoolActor pid=3283545, ip=10.42.6.149) 25-12-07 11:10:09 EST | INFO    | pbase.analysis.tools.base | add_offpeak         | #7935 | extended offpeak: 744 hours => 1120 hours
# ...
# (PoolActor pid=2969427, ip=10.42.0.182) [F2]
# (PoolActor pid=2969427, ip=10.42.0.182)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=2969427, ip=10.42.0.182)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=2969427, ip=10.42.0.182)
# (PoolActor pid=2969427, ip=10.42.0.182) [LONG]
# (PoolActor pid=2969427, ip=10.42.0.182)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=2969427, ip=10.42.0.182)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=2969427, ip=10.42.0.182)
# (PoolActor pid=2969427, ip=10.42.0.182) [STEP 6: Making Predictions for Auction Month 2025-04]
# (PoolActor pid=2969427, ip=10.42.0.182)   Predicting for Market Month: 2025-04
# (PoolActor pid=3283611, ip=10.42.6.149)   Training default fallback regressor (f0)...
# (PoolActor pid=2969429, ip=10.42.0.182)     ✓ Trained 509 branch models (skipped 3263)
# (PoolActor pid=2969429, ip=10.42.0.182)
# (PoolActor pid=2969429, ip=10.42.0.182) ✓ Regression Training Complete
# (PoolActor pid=2969429, ip=10.42.0.182)
# (PoolActor pid=2969429, ip=10.42.0.182) ================================================================================
# (PoolActor pid=2969429, ip=10.42.0.182) FALLBACK MONITORING STATISTICS
# (PoolActor pid=2969429, ip=10.42.0.182) ================================================================================
# (PoolActor pid=2969429, ip=10.42.0.182)
# (PoolActor pid=2969429, ip=10.42.0.182) [F0]
# (PoolActor pid=2969429, ip=10.42.0.182)   Classification Fallback Rate: 0/258 (0.00%)
# (PoolActor pid=2969429, ip=10.42.0.182)   Regression Fallback Rate:     0/509 (0.00%)
# (PoolActor pid=2969429, ip=10.42.0.182)
# (PoolActor pid=2969429, ip=10.42.0.182) [F1]
# (PoolActor pid=2969429, ip=10.42.0.182)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=2969429, ip=10.42.0.182)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=2969429, ip=10.42.0.182)
# (PoolActor pid=2969429, ip=10.42.0.182) [F2]
# (PoolActor pid=2969429, ip=10.42.0.182)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=2969429, ip=10.42.0.182)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=2969429, ip=10.42.0.182)
# (PoolActor pid=2969429, ip=10.42.0.182) [LONG]
# (PoolActor pid=2969429, ip=10.42.0.182)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=2969429, ip=10.42.0.182)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=2969429, ip=10.42.0.182)
# (PoolActor pid=2969429, ip=10.42.0.182) [STEP 6: Making Predictions for Auction Month 2024-10]
# (PoolActor pid=2969429, ip=10.42.0.182)   Predicting for Market Month: 2024-10
# (PoolActor pid=3283611, ip=10.42.6.149)     ✓ Default ensemble trained (1 models)
# (PoolActor pid=3283611, ip=10.42.6.149)     Total binding samples: 45,797
# (PoolActor pid=3283611, ip=10.42.6.149)   Training branch-specific regressors (f0)...
# (PoolActor pid=3051849, ip=10.42.4.173)     ✓ Trained 517 branch models (skipped 3220)
# (PoolActor pid=3051849, ip=10.42.4.173)
# (PoolActor pid=3051849, ip=10.42.4.173) ✓ Regression Training Complete
# (PoolActor pid=3051849, ip=10.42.4.173)
# (PoolActor pid=3051849, ip=10.42.4.173) ================================================================================
# (PoolActor pid=3051849, ip=10.42.4.173) FALLBACK MONITORING STATISTICS
# (PoolActor pid=3051849, ip=10.42.4.173) ================================================================================
# (PoolActor pid=3051849, ip=10.42.4.173)
# (PoolActor pid=3051849, ip=10.42.4.173) [F0]
# (PoolActor pid=3051849, ip=10.42.4.173)   Classification Fallback Rate: 0/271 (0.00%)
# (PoolActor pid=3051849, ip=10.42.4.173)   Regression Fallback Rate:     0/517 (0.00%)
# (PoolActor pid=3051849, ip=10.42.4.173)
# (PoolActor pid=3051849, ip=10.42.4.173) [F1]
# (PoolActor pid=3051849, ip=10.42.4.173)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=3051849, ip=10.42.4.173)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=3051849, ip=10.42.4.173)
# (PoolActor pid=3051849, ip=10.42.4.173) [F2]
# (PoolActor pid=3051849, ip=10.42.4.173)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=3051849, ip=10.42.4.173)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=3051849, ip=10.42.4.173)
# (PoolActor pid=3051849, ip=10.42.4.173) [LONG]
# (PoolActor pid=3051849, ip=10.42.4.173)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=3051849, ip=10.42.4.173)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=3051849, ip=10.42.4.173)
# (PoolActor pid=3051849, ip=10.42.4.173) [STEP 6: Making Predictions for Auction Month 2024-12]
# (PoolActor pid=3051849, ip=10.42.4.173)   Predicting for Market Month: 2024-12
# (PoolActor pid=3283545, ip=10.42.6.149)   Saved final results to: /opt/temp/tmp/pw_data/spice6/prod_f0p_model_pjm/ml_pred/auction_month=2024-06/market_month=2024-06/class_type=onpeak
# (PoolActor pid=3283545, ip=10.42.6.149)
# (PoolActor pid=3283545, ip=10.42.6.149) ✅ Auction Month 2024-06 Complete (1 predictions)
# (PoolActor pid=3283545, ip=10.42.6.149) [Timing] _process_auction_month for 2024-06 took 76.67 seconds
# (PoolActor pid=3283546, ip=10.42.6.149)     ✓ Trained 527 branch models (skipped 3140)
# (PoolActor pid=3283546, ip=10.42.6.149)
# (PoolActor pid=3283546, ip=10.42.6.149) ✓ Regression Training Complete
# (PoolActor pid=3283546, ip=10.42.6.149)
# (PoolActor pid=3283546, ip=10.42.6.149) ================================================================================
# (PoolActor pid=3283546, ip=10.42.6.149) FALLBACK MONITORING STATISTICS
# (PoolActor pid=3283546, ip=10.42.6.149) ================================================================================
# (PoolActor pid=3283546, ip=10.42.6.149)
# (PoolActor pid=3283546, ip=10.42.6.149) [F0]
# (PoolActor pid=3283546, ip=10.42.6.149)   Classification Fallback Rate: 0/263 (0.00%)
# (PoolActor pid=3283546, ip=10.42.6.149)   Regression Fallback Rate:     0/527 (0.00%)
# (PoolActor pid=3283546, ip=10.42.6.149)
# (PoolActor pid=3283546, ip=10.42.6.149) [F1]
# (PoolActor pid=3283546, ip=10.42.6.149)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=3283546, ip=10.42.6.149)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=3283546, ip=10.42.6.149)
# (PoolActor pid=3283546, ip=10.42.6.149) [F2]
# (PoolActor pid=3283546, ip=10.42.6.149)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=3283546, ip=10.42.6.149)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=3283546, ip=10.42.6.149)
# (PoolActor pid=3283546, ip=10.42.6.149) [LONG]
# (PoolActor pid=3283546, ip=10.42.6.149)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=3283546, ip=10.42.6.149)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=3283546, ip=10.42.6.149)
# (PoolActor pid=3283546, ip=10.42.6.149) [STEP 6: Making Predictions for Auction Month 2025-01]
# (PoolActor pid=3283546, ip=10.42.6.149)   Predicting for Market Month: 2025-01
# (PoolActor pid=3283611, ip=10.42.6.149)     ✓ Trained 506 branch models (skipped 3164)
# (PoolActor pid=3283611, ip=10.42.6.149)
# (PoolActor pid=3283611, ip=10.42.6.149) ✓ Regression Training Complete
# (PoolActor pid=3283611, ip=10.42.6.149)
# (PoolActor pid=3283611, ip=10.42.6.149) ================================================================================
# (PoolActor pid=3283611, ip=10.42.6.149) FALLBACK MONITORING STATISTICS
# (PoolActor pid=3283611, ip=10.42.6.149) ================================================================================
# (PoolActor pid=3283611, ip=10.42.6.149)
# (PoolActor pid=3283611, ip=10.42.6.149) [F0]
# (PoolActor pid=3283611, ip=10.42.6.149)   Classification Fallback Rate: 0/285 (0.00%)
# (PoolActor pid=3283611, ip=10.42.6.149)   Regression Fallback Rate:     0/506 (0.00%)
# (PoolActor pid=3283611, ip=10.42.6.149)
# (PoolActor pid=3283611, ip=10.42.6.149) [F1]
# (PoolActor pid=3283611, ip=10.42.6.149)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=3283611, ip=10.42.6.149)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=3283611, ip=10.42.6.149)
# (PoolActor pid=3283611, ip=10.42.6.149) [F2]
# (PoolActor pid=3283611, ip=10.42.6.149)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=3283611, ip=10.42.6.149)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=3283611, ip=10.42.6.149)
# (PoolActor pid=3283611, ip=10.42.6.149) [LONG]
# (PoolActor pid=3283611, ip=10.42.6.149)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=3283611, ip=10.42.6.149)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=3283611, ip=10.42.6.149)
# (PoolActor pid=3283611, ip=10.42.6.149) [STEP 6: Making Predictions for Auction Month 2025-07]
# (PoolActor pid=3283611, ip=10.42.6.149)   Predicting for Market Month: 2025-07
# (PoolActor pid=2969084, ip=10.42.7.70)   Saved final results to: /opt/temp/tmp/pw_data/spice6/prod_f0p_model_pjm/ml_pred/auction_month=2024-11/market_month=2024-11/class_type=onpeak
# (PoolActor pid=2969084, ip=10.42.7.70)
# (PoolActor pid=2969084, ip=10.42.7.70) ✅ Auction Month 2024-11 Complete (1 predictions)
# (PoolActor pid=2969084, ip=10.42.7.70) [Timing] _process_auction_month for 2024-11 took 89.86 seconds
# (PoolActor pid=2969086, ip=10.42.7.70)   Saved final results to: /opt/temp/tmp/pw_data/spice6/prod_f0p_model_pjm/ml_pred/auction_month=2025-11/market_month=2025-11/class_type=onpeak
# (PoolActor pid=2969086, ip=10.42.7.70)
# (PoolActor pid=2969086, ip=10.42.7.70) ✅ Auction Month 2025-11 Complete (1 predictions)
# (PoolActor pid=2969086, ip=10.42.7.70) [Timing] _process_auction_month for 2025-11 took 90.35 seconds
# (PoolActor pid=3036045, ip=10.42.9.131)   Saved final results to: /opt/temp/tmp/pw_data/spice6/prod_f0p_model_pjm/ml_pred/auction_month=2025-02/market_month=2025-02/class_type=onpeak
# (PoolActor pid=3036045, ip=10.42.9.131)
# (PoolActor pid=3036045, ip=10.42.9.131) ✅ Auction Month 2025-02 Complete (1 predictions)
# (PoolActor pid=3036045, ip=10.42.9.131) [Timing] _process_auction_month for 2025-02 took 90.85 seconds
# (PoolActor pid=3051850, ip=10.42.4.173)   Saved final results to: /opt/temp/tmp/pw_data/spice6/prod_f0p_model_pjm/ml_pred/auction_month=2025-06/market_month=2025-06/class_type=onpeak
# (PoolActor pid=3051850, ip=10.42.4.173)
# (PoolActor pid=3051850, ip=10.42.4.173) ✅ Auction Month 2025-06 Complete (1 predictions)
# (PoolActor pid=3051850, ip=10.42.4.173) [Timing] _process_auction_month for 2025-06 took 92.36 seconds
# (PoolActor pid=2969427, ip=10.42.0.182)   Saved final results to: /opt/temp/tmp/pw_data/spice6/prod_f0p_model_pjm/ml_pred/auction_month=2025-04/market_month=2025-04/class_type=onpeak
# (PoolActor pid=2969427, ip=10.42.0.182)
# (PoolActor pid=2969427, ip=10.42.0.182) ✅ Auction Month 2025-04 Complete (1 predictions)
# (PoolActor pid=2969427, ip=10.42.0.182) [Timing] _process_auction_month for 2025-04 took 92.49 seconds
# (PoolActor pid=3051848, ip=10.42.4.173)   Saved final results to: /opt/temp/tmp/pw_data/spice6/prod_f0p_model_pjm/ml_pred/auction_month=2024-07/market_month=2024-07/class_type=onpeak
# (PoolActor pid=3051848, ip=10.42.4.173)
# (PoolActor pid=3051848, ip=10.42.4.173) ✅ Auction Month 2024-07 Complete (1 predictions)
# (PoolActor pid=3051848, ip=10.42.4.173) [Timing] _process_auction_month for 2024-07 took 93.38 seconds
# (PoolActor pid=3036044, ip=10.42.9.131)   Saved final results to: /opt/temp/tmp/pw_data/spice6/prod_f0p_model_pjm/ml_pred/auction_month=2024-08/market_month=2024-08/class_type=onpeak
# (PoolActor pid=3036044, ip=10.42.9.131)
# (PoolActor pid=3036044, ip=10.42.9.131) ✅ Auction Month 2024-08 Complete (1 predictions)
# (PoolActor pid=3036044, ip=10.42.9.131) [Timing] _process_auction_month for 2024-08 took 93.57 seconds
# (PoolActor pid=2969428, ip=10.42.0.182)   Saved final results to: /opt/temp/tmp/pw_data/spice6/prod_f0p_model_pjm/ml_pred/auction_month=2025-10/market_month=2025-10/class_type=onpeak
# (PoolActor pid=2969428, ip=10.42.0.182)
# (PoolActor pid=2969428, ip=10.42.0.182) ✅ Auction Month 2025-10 Complete (1 predictions)
# (PoolActor pid=2969428, ip=10.42.0.182) [Timing] _process_auction_month for 2025-10 took 93.98 seconds
# (PoolActor pid=2969085, ip=10.42.7.70)   Saved final results to: /opt/temp/tmp/pw_data/spice6/prod_f0p_model_pjm/ml_pred/auction_month=2025-05/market_month=2025-05/class_type=onpeak
# (PoolActor pid=2969085, ip=10.42.7.70)
# (PoolActor pid=2969085, ip=10.42.7.70) ✅ Auction Month 2025-05 Complete (1 predictions)
# (PoolActor pid=2969085, ip=10.42.7.70) [Timing] _process_auction_month for 2025-05 took 94.23 seconds
# (PoolActor pid=3283546, ip=10.42.6.149)   Saved final results to: /opt/temp/tmp/pw_data/spice6/prod_f0p_model_pjm/ml_pred/auction_month=2025-01/market_month=2025-01/class_type=onpeak
# (PoolActor pid=3283546, ip=10.42.6.149)
# (PoolActor pid=3283546, ip=10.42.6.149) ✅ Auction Month 2025-01 Complete (1 predictions)
# (PoolActor pid=3283546, ip=10.42.6.149) [Timing] _process_auction_month for 2025-01 took 94.38 seconds
# (PoolActor pid=3051851, ip=10.42.4.173)   Saved final results to: /opt/temp/tmp/pw_data/spice6/prod_f0p_model_pjm/ml_pred/auction_month=2025-12/market_month=2025-12/class_type=onpeak
# (PoolActor pid=3051851, ip=10.42.4.173)
# (PoolActor pid=3051851, ip=10.42.4.173) ✅ Auction Month 2025-12 Complete (1 predictions)
# (PoolActor pid=3051851, ip=10.42.4.173) [Timing] _process_auction_month for 2025-12 took 94.46 seconds
# (PoolActor pid=3051849, ip=10.42.4.173)   Saved final results to: /opt/temp/tmp/pw_data/spice6/prod_f0p_model_pjm/ml_pred/auction_month=2024-12/market_month=2024-12/class_type=onpeak
# (PoolActor pid=3051849, ip=10.42.4.173)
# (PoolActor pid=3051849, ip=10.42.4.173) ✅ Auction Month 2024-12 Complete (1 predictions)
# (PoolActor pid=3051849, ip=10.42.4.173) [Timing] _process_auction_month for 2024-12 took 94.53 seconds
# (PoolActor pid=3036046, ip=10.42.9.131)   Saved final results to: /opt/temp/tmp/pw_data/spice6/prod_f0p_model_pjm/ml_pred/auction_month=2025-08/market_month=2025-08/class_type=onpeak
# (PoolActor pid=3036046, ip=10.42.9.131)
# (PoolActor pid=3036046, ip=10.42.9.131) ✅ Auction Month 2025-08 Complete (1 predictions)
# (PoolActor pid=3036046, ip=10.42.9.131) [Timing] _process_auction_month for 2025-08 took 94.89 seconds
# (PoolActor pid=2969429, ip=10.42.0.182)   Saved final results to: /opt/temp/tmp/pw_data/spice6/prod_f0p_model_pjm/ml_pred/auction_month=2024-10/market_month=2024-10/class_type=onpeak
# (PoolActor pid=2969429, ip=10.42.0.182)
# (PoolActor pid=2969429, ip=10.42.0.182) ✅ Auction Month 2024-10 Complete (1 predictions)
# (PoolActor pid=2969429, ip=10.42.0.182) [Timing] _process_auction_month for 2024-10 took 95.59 seconds
# (PoolActor pid=3283611, ip=10.42.6.149)   Saved final results to: /opt/temp/tmp/pw_data/spice6/prod_f0p_model_pjm/ml_pred/auction_month=2025-07/market_month=2025-07/class_type=onpeak
# (PoolActor pid=3283611, ip=10.42.6.149)
# (PoolActor pid=3283611, ip=10.42.6.149) ✅ Auction Month 2025-07 Complete (1 predictions)
# (PoolActor pid=3283611, ip=10.42.6.149) [Timing] _process_auction_month for 2025-07 took 97.10 seconds
#
# ================================================================================
# ✅ ALL AUCTION MONTHS TRAINING COMPLETE!
# ================================================================================
#
# ================================================================================
# [COMBINING RESULTS ACROSS ALL PERIODS]
# ================================================================================
#
# ✓ Results Combined
#   Total samples (per-outage): 2,224,886
#   Total unique constraints (monthly): 243,583
#   Date range: 2024-06-01 to 2025-12-31
#
# [ANALYZING COMBINED RESULTS]
#   Skipping metrics calculation (no labels available)
#
# ================================================================================
# ✅ PIPELINE COMPLETE!
# ================================================================================
# (PoolActor pid=3032600, ip=10.42.8.15) E1207 11:11:46.585268086 3032600 backup_poller.cc:113]                 run_poller: UNKNOWN:Timer list shutdown {created_time:"2025-12-07T11:11:46.585242086-05:00"}

# %%
x = pd.read_parquet('/opt/temp/tmp/pw_data/spice6/prod_f0p_model_pjm/ml_pred/auction_month=2025-07/market_month=2025-07/class_type=onpeak/final_results.parquet')
x[x.index.get_level_values('constraint_id').str.contains('274D')]
# Out:
#                                                                         branch_name  \
# constraint_id                                      flow_direction
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Belm... 1               274D           1
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Bram... 1               274D           1
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Bram... 1               274D           1
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Ever... 1               274D           1
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Ever... 1               274D           1
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Goos... 1               274D           1
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Plea... 1               274D           1
# PLEASNTV-ASHBURN  274D      A  230 KV:L500.Burc... 1               274D           1
# PLEASNTV-ASHBURN  274D      A  230 KV:L500.Calv... 1               274D           1
# PLEASNTV-ASHBURN  274D      B  230 KV:L230.Bram... 1               274D           1
# PLEASNTV-ASHBURN 274D A 230 KV:L230.EvergreenMi... 1               274D           1
# PLEASNTV-ASHBURN 274D:L230.EvergreenMills-Brabl... 1               274D           1
# PLEASNTV230 KV  274D:BASE                          1               274D           1
# PLEASNTV230 KV  274D:L230.Belmont-CochranMill-A... 1               274D           1
# PLEASNTV230 KV  274D:L230.Brambleton-Beaumeade.227 1               274D           1
# PLEASNTV230 KV  274D:L230.Brambleton-PolandRoad... 1               274D           1
# PLEASNTV230 KV  274D:L230.EvergreenMills-Brable... 1               274D           1
# PLEASNTV230 KV  274D:L230.EvergreenMills-Yarley... 1               274D           1
# PLEASNTV230 KV  274D:L230.GooseCreek-Ashburn-Be... 1               274D           1
# PLEASNTV230 KV  274D:L230.PleasantView-Belmont.... 1               274D           1
# PLEASNTV230 KV  274D:L230.Shellhorn-Enterprise.... 1               274D           1
# PLEASNTV230 KV  274D:L500.Burches Hill-Possum P... 1               274D           1
# PLEASNTV230 KV  274D:L500.BurchesHill-PossumPoi... 1               274D           1
# PLEASNTV230 KV  274D:L500.Carson-Rawlings.511      1               274D           1
# PLEASNTV230 KV  274D:L500.Clifton-Mosby.559A       1               274D           1
# PLEASNTV230 KV  274D:L500.Elmont-Cunningham.553    1               274D           1
# PLEASNTV230 KV  274D:L500.Loudoun-Meadowbrook (... 1               274D           1
# PLEASNTV230 KV  274D:L500.MtStorm-Meadowbrook (... 1               274D           1
# PLEASNTV230 KV 274D FOR ELMONT-CUNNIGHAM:L500.E... 1               274D           1
#
#                                                                    prob_below_90  \
# constraint_id                                      flow_direction
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Belm... 1                    1.000000
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Bram... 1                    1.000000
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Bram... 1                    1.000000
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Ever... 1                    1.000000
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Ever... 1                    1.000000
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Goos... 1                    0.995859
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Plea... 1                    0.999502
# PLEASNTV-ASHBURN  274D      A  230 KV:L500.Burc... 1                    0.999555
# PLEASNTV-ASHBURN  274D      A  230 KV:L500.Calv... 1                    1.000000
# PLEASNTV-ASHBURN  274D      B  230 KV:L230.Bram... 1                    1.000000
# PLEASNTV-ASHBURN 274D A 230 KV:L230.EvergreenMi... 1                    1.000000
# PLEASNTV-ASHBURN 274D:L230.EvergreenMills-Brabl... 1                    1.000000
# PLEASNTV230 KV  274D:BASE                          1                    1.000000
# PLEASNTV230 KV  274D:L230.Belmont-CochranMill-A... 1                    1.000000
# PLEASNTV230 KV  274D:L230.Brambleton-Beaumeade.227 1                    1.000000
# PLEASNTV230 KV  274D:L230.Brambleton-PolandRoad... 1                    1.000000
# PLEASNTV230 KV  274D:L230.EvergreenMills-Brable... 1                    1.000000
# PLEASNTV230 KV  274D:L230.EvergreenMills-Yarley... 1                    1.000000
# PLEASNTV230 KV  274D:L230.GooseCreek-Ashburn-Be... 1                    0.995859
# PLEASNTV230 KV  274D:L230.PleasantView-Belmont.... 1                    0.999502
# PLEASNTV230 KV  274D:L230.Shellhorn-Enterprise.... 1                    1.000000
# PLEASNTV230 KV  274D:L500.Burches Hill-Possum P... 1                    0.999555
# PLEASNTV230 KV  274D:L500.BurchesHill-PossumPoi... 1                    0.999555
# PLEASNTV230 KV  274D:L500.Carson-Rawlings.511      1                    1.000000
# PLEASNTV230 KV  274D:L500.Clifton-Mosby.559A       1                    1.000000
# PLEASNTV230 KV  274D:L500.Elmont-Cunningham.553    1                    1.000000
# PLEASNTV230 KV  274D:L500.Loudoun-Meadowbrook (... 1                    1.000000
# PLEASNTV230 KV  274D:L500.MtStorm-Meadowbrook (... 1                    1.000000
# PLEASNTV230 KV 274D FOR ELMONT-CUNNIGHAM:L500.E... 1                    1.000000
#
#                                                                      hist_da  \
# constraint_id                                      flow_direction
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Belm... 1               10.155745
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Bram... 1               10.155745
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Bram... 1               10.155745
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Ever... 1               10.155745
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Ever... 1               10.155745
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Goos... 1               10.155745
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Plea... 1               10.155745
# PLEASNTV-ASHBURN  274D      A  230 KV:L500.Burc... 1               10.155745
# PLEASNTV-ASHBURN  274D      A  230 KV:L500.Calv... 1               10.155745
# PLEASNTV-ASHBURN  274D      B  230 KV:L230.Bram... 1               10.155745
# PLEASNTV-ASHBURN 274D A 230 KV:L230.EvergreenMi... 1               10.155745
# PLEASNTV-ASHBURN 274D:L230.EvergreenMills-Brabl... 1               10.155745
# PLEASNTV230 KV  274D:BASE                          1               10.155745
# PLEASNTV230 KV  274D:L230.Belmont-CochranMill-A... 1               10.155745
# PLEASNTV230 KV  274D:L230.Brambleton-Beaumeade.227 1               10.155745
# PLEASNTV230 KV  274D:L230.Brambleton-PolandRoad... 1               10.155745
# PLEASNTV230 KV  274D:L230.EvergreenMills-Brable... 1               10.155745
# PLEASNTV230 KV  274D:L230.EvergreenMills-Yarley... 1               10.155745
# PLEASNTV230 KV  274D:L230.GooseCreek-Ashburn-Be... 1               10.155745
# PLEASNTV230 KV  274D:L230.PleasantView-Belmont.... 1               10.155745
# PLEASNTV230 KV  274D:L230.Shellhorn-Enterprise.... 1               10.155745
# PLEASNTV230 KV  274D:L500.Burches Hill-Possum P... 1               10.155745
# PLEASNTV230 KV  274D:L500.BurchesHill-PossumPoi... 1               10.155745
# PLEASNTV230 KV  274D:L500.Carson-Rawlings.511      1               10.155745
# PLEASNTV230 KV  274D:L500.Clifton-Mosby.559A       1               10.155745
# PLEASNTV230 KV  274D:L500.Elmont-Cunningham.553    1               10.155745
# PLEASNTV230 KV  274D:L500.Loudoun-Meadowbrook (... 1               10.155745
# PLEASNTV230 KV  274D:L500.MtStorm-Meadowbrook (... 1               10.155745
# PLEASNTV230 KV 274D FOR ELMONT-CUNNIGHAM:L500.E... 1               10.155745
#
#                                                                    prob_exceed_100  \
# constraint_id                                      flow_direction
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Belm... 1                  2.578188e-48
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Bram... 1                 9.086125e-298
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Bram... 1                 3.134752e-142
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Ever... 1                 7.035415e-131
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Ever... 1                 7.432700e-135
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Goos... 1                  3.300362e-04
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Plea... 1                  7.489392e-05
# PLEASNTV-ASHBURN  274D      A  230 KV:L500.Burc... 1                  6.480628e-05
# PLEASNTV-ASHBURN  274D      A  230 KV:L500.Calv... 1                  1.371955e-54
# PLEASNTV-ASHBURN  274D      B  230 KV:L230.Bram... 1                 9.086125e-298
# PLEASNTV-ASHBURN 274D A 230 KV:L230.EvergreenMi... 1                 7.432700e-135
# PLEASNTV-ASHBURN 274D:L230.EvergreenMills-Brabl... 1                 7.035415e-131
# PLEASNTV230 KV  274D:BASE                          1                 2.684927e-141
# PLEASNTV230 KV  274D:L230.Belmont-CochranMill-A... 1                  2.578188e-48
# PLEASNTV230 KV  274D:L230.Brambleton-Beaumeade.227 1                 9.086125e-298
# PLEASNTV230 KV  274D:L230.Brambleton-PolandRoad... 1                 3.134752e-142
# PLEASNTV230 KV  274D:L230.EvergreenMills-Brable... 1                 7.035415e-131
# PLEASNTV230 KV  274D:L230.EvergreenMills-Yarley... 1                 7.432700e-135
# PLEASNTV230 KV  274D:L230.GooseCreek-Ashburn-Be... 1                  3.300362e-04
# PLEASNTV230 KV  274D:L230.PleasantView-Belmont.... 1                  7.489392e-05
# PLEASNTV230 KV  274D:L230.Shellhorn-Enterprise.... 1                 1.041399e-129
# PLEASNTV230 KV  274D:L500.Burches Hill-Possum P... 1                  6.480628e-05
# PLEASNTV230 KV  274D:L500.BurchesHill-PossumPoi... 1                  6.480628e-05
# PLEASNTV230 KV  274D:L500.Carson-Rawlings.511      1                 9.871022e-144
# PLEASNTV230 KV  274D:L500.Clifton-Mosby.559A       1                 3.219267e-142
# PLEASNTV230 KV  274D:L500.Elmont-Cunningham.553    1                 4.189352e-141
# PLEASNTV230 KV  274D:L500.Loudoun-Meadowbrook (... 1                 1.609135e-124
# PLEASNTV230 KV  274D:L500.MtStorm-Meadowbrook (... 1                 1.647003e-134
# PLEASNTV230 KV 274D FOR ELMONT-CUNNIGHAM:L500.E... 1                 4.189352e-141
#
#                                                                    prob_exceed_110  \
# constraint_id                                      flow_direction
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Belm... 1                 8.389672e-141
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Bram... 1                  0.000000e+00
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Bram... 1                 9.881313e-324
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Ever... 1                 2.896262e-298
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Ever... 1                 9.174379e-309
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Goos... 1                  1.409964e-34
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Plea... 1                  2.755513e-07
# PLEASNTV-ASHBURN  274D      A  230 KV:L500.Burc... 1                  1.789745e-07
# PLEASNTV-ASHBURN  274D      A  230 KV:L500.Calv... 1                 9.456545e-157
# PLEASNTV-ASHBURN  274D      B  230 KV:L230.Bram... 1                  0.000000e+00
# PLEASNTV-ASHBURN 274D A 230 KV:L230.EvergreenMi... 1                 9.174379e-309
# PLEASNTV-ASHBURN 274D:L230.EvergreenMills-Brabl... 1                 2.896262e-298
# PLEASNTV230 KV  274D:BASE                          1                 3.952525e-322
# PLEASNTV230 KV  274D:L230.Belmont-CochranMill-A... 1                 8.389672e-141
# PLEASNTV230 KV  274D:L230.Brambleton-Beaumeade.227 1                  0.000000e+00
# PLEASNTV230 KV  274D:L230.Brambleton-PolandRoad... 1                 9.881313e-324
# PLEASNTV230 KV  274D:L230.EvergreenMills-Brable... 1                 2.896262e-298
# PLEASNTV230 KV  274D:L230.EvergreenMills-Yarley... 1                 9.174379e-309
# PLEASNTV230 KV  274D:L230.GooseCreek-Ashburn-Be... 1                  1.409964e-34
# PLEASNTV230 KV  274D:L230.PleasantView-Belmont.... 1                  2.755513e-07
# PLEASNTV230 KV  274D:L230.Shellhorn-Enterprise.... 1                 6.148248e-308
# PLEASNTV230 KV  274D:L500.Burches Hill-Possum P... 1                  1.789745e-07
# PLEASNTV230 KV  274D:L500.BurchesHill-PossumPoi... 1                  1.789745e-07
# PLEASNTV230 KV  274D:L500.Carson-Rawlings.511      1                  0.000000e+00
# PLEASNTV230 KV  274D:L500.Clifton-Mosby.559A       1                 4.940656e-324
# PLEASNTV230 KV  274D:L500.Elmont-Cunningham.553    1                  0.000000e+00
# PLEASNTV230 KV  274D:L500.Loudoun-Meadowbrook (... 1                 4.265320e-307
# PLEASNTV230 KV  274D:L500.MtStorm-Meadowbrook (... 1                 7.822341e-317
# PLEASNTV230 KV 274D FOR ELMONT-CUNNIGHAM:L500.E... 1                  0.000000e+00
#
#                                                                    density_skewness  \
# constraint_id                                      flow_direction
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Belm... 1                      -0.397802
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Bram... 1                      -0.203034
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Bram... 1                      -0.151468
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Ever... 1                      -0.270689
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Ever... 1                      -0.147894
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Goos... 1                      -0.098466
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Plea... 1                      -0.158647
# PLEASNTV-ASHBURN  274D      A  230 KV:L500.Burc... 1                      -0.323960
# PLEASNTV-ASHBURN  274D      A  230 KV:L500.Calv... 1                      -0.254179
# PLEASNTV-ASHBURN  274D      B  230 KV:L230.Bram... 1                      -0.203034
# PLEASNTV-ASHBURN 274D A 230 KV:L230.EvergreenMi... 1                      -0.147894
# PLEASNTV-ASHBURN 274D:L230.EvergreenMills-Brabl... 1                      -0.270689
# PLEASNTV230 KV  274D:BASE                          1                      -0.151357
# PLEASNTV230 KV  274D:L230.Belmont-CochranMill-A... 1                      -0.397802
# PLEASNTV230 KV  274D:L230.Brambleton-Beaumeade.227 1                      -0.203034
# PLEASNTV230 KV  274D:L230.Brambleton-PolandRoad... 1                      -0.151468
# PLEASNTV230 KV  274D:L230.EvergreenMills-Brable... 1                      -0.270689
# PLEASNTV230 KV  274D:L230.EvergreenMills-Yarley... 1                      -0.147894
# PLEASNTV230 KV  274D:L230.GooseCreek-Ashburn-Be... 1                      -0.098466
# PLEASNTV230 KV  274D:L230.PleasantView-Belmont.... 1                      -0.158647
# PLEASNTV230 KV  274D:L230.Shellhorn-Enterprise.... 1                      -0.134446
# PLEASNTV230 KV  274D:L500.Burches Hill-Possum P... 1                      -0.323960
# PLEASNTV230 KV  274D:L500.BurchesHill-PossumPoi... 1                      -0.323960
# PLEASNTV230 KV  274D:L500.Carson-Rawlings.511      1                      -0.153479
# PLEASNTV230 KV  274D:L500.Clifton-Mosby.559A       1                      -0.154263
# PLEASNTV230 KV  274D:L500.Elmont-Cunningham.553    1                      -0.141506
# PLEASNTV230 KV  274D:L500.Loudoun-Meadowbrook (... 1                      -0.188807
# PLEASNTV230 KV  274D:L500.MtStorm-Meadowbrook (... 1                      -0.157841
# PLEASNTV230 KV 274D FOR ELMONT-CUNNIGHAM:L500.E... 1                      -0.141506
#
#                                                                    prob_exceed_95  \
# constraint_id                                      flow_direction
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Belm... 1                 2.404289e-21
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Bram... 1                3.544120e-196
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Bram... 1                 3.463351e-81
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Ever... 1                 8.274618e-75
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Ever... 1                 1.119438e-76
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Goos... 1                 1.182888e-03
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Plea... 1                 2.428461e-04
# PLEASNTV-ASHBURN  274D      A  230 KV:L500.Burc... 1                 1.415791e-04
# PLEASNTV-ASHBURN  274D      A  230 KV:L500.Calv... 1                 4.848373e-27
# PLEASNTV-ASHBURN  274D      B  230 KV:L230.Bram... 1                3.544120e-196
# PLEASNTV-ASHBURN 274D A 230 KV:L230.EvergreenMi... 1                 1.119438e-76
# PLEASNTV-ASHBURN 274D:L230.EvergreenMills-Brabl... 1                 8.274618e-75
# PLEASNTV230 KV  274D:BASE                          1                 1.505786e-80
# PLEASNTV230 KV  274D:L230.Belmont-CochranMill-A... 1                 2.404289e-21
# PLEASNTV230 KV  274D:L230.Brambleton-Beaumeade.227 1                3.544120e-196
# PLEASNTV230 KV  274D:L230.Brambleton-PolandRoad... 1                 3.463351e-81
# PLEASNTV230 KV  274D:L230.EvergreenMills-Brable... 1                 8.274618e-75
# PLEASNTV230 KV  274D:L230.EvergreenMills-Yarley... 1                 1.119438e-76
# PLEASNTV230 KV  274D:L230.GooseCreek-Ashburn-Be... 1                 1.182888e-03
# PLEASNTV230 KV  274D:L230.PleasantView-Belmont.... 1                 2.428461e-04
# PLEASNTV230 KV  274D:L230.Shellhorn-Enterprise.... 1                 2.167648e-71
# PLEASNTV230 KV  274D:L500.Burches Hill-Possum P... 1                 1.415791e-04
# PLEASNTV230 KV  274D:L500.BurchesHill-PossumPoi... 1                 1.415791e-04
# PLEASNTV230 KV  274D:L500.Carson-Rawlings.511      1                 6.614501e-82
# PLEASNTV230 KV  274D:L500.Clifton-Mosby.559A       1                 4.183231e-81
# PLEASNTV230 KV  274D:L500.Elmont-Cunningham.553    1                 2.063287e-77
# PLEASNTV230 KV  274D:L500.Loudoun-Meadowbrook (... 1                 3.503965e-66
# PLEASNTV230 KV  274D:L500.MtStorm-Meadowbrook (... 1                 1.724044e-74
# PLEASNTV230 KV 274D FOR ELMONT-CUNNIGHAM:L500.E... 1                 2.063287e-77
#
#                                                                    prob_exceed_90  \
# constraint_id                                      flow_direction
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Belm... 1                 2.851607e-07
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Bram... 1                4.072439e-117
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Bram... 1                 6.014946e-40
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Ever... 1                 3.744218e-37
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Ever... 1                 1.102974e-37
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Goos... 1                 4.140575e-03
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Plea... 1                 4.983327e-04
# PLEASNTV-ASHBURN  274D      A  230 KV:L500.Burc... 1                 4.447650e-04
# PLEASNTV-ASHBURN  274D      A  230 KV:L500.Calv... 1                 9.827006e-09
# PLEASNTV-ASHBURN  274D      B  230 KV:L230.Bram... 1                4.072439e-117
# PLEASNTV-ASHBURN 274D A 230 KV:L230.EvergreenMi... 1                 1.102974e-37
# PLEASNTV-ASHBURN 274D:L230.EvergreenMills-Brabl... 1                 3.744218e-37
# PLEASNTV230 KV  274D:BASE                          1                 1.409676e-39
# PLEASNTV230 KV  274D:L230.Belmont-CochranMill-A... 1                 2.851607e-07
# PLEASNTV230 KV  274D:L230.Brambleton-Beaumeade.227 1                4.072439e-117
# PLEASNTV230 KV  274D:L230.Brambleton-PolandRoad... 1                 6.014946e-40
# PLEASNTV230 KV  274D:L230.EvergreenMills-Brable... 1                 3.744218e-37
# PLEASNTV230 KV  274D:L230.EvergreenMills-Yarley... 1                 1.102974e-37
# PLEASNTV230 KV  274D:L230.GooseCreek-Ashburn-Be... 1                 4.140575e-03
# PLEASNTV230 KV  274D:L230.PleasantView-Belmont.... 1                 4.983327e-04
# PLEASNTV230 KV  274D:L230.Shellhorn-Enterprise.... 1                 1.329392e-33
# PLEASNTV230 KV  274D:L500.Burches Hill-Possum P... 1                 4.447650e-04
# PLEASNTV230 KV  274D:L500.BurchesHill-PossumPoi... 1                 4.447650e-04
# PLEASNTV230 KV  274D:L500.Carson-Rawlings.511      1                 3.650093e-40
# PLEASNTV230 KV  274D:L500.Clifton-Mosby.559A       1                 7.495295e-40
# PLEASNTV230 KV  274D:L500.Elmont-Cunningham.553    1                 6.382196e-36
# PLEASNTV230 KV  274D:L500.Loudoun-Meadowbrook (... 1                 8.234269e-30
# PLEASNTV230 KV  274D:L500.MtStorm-Meadowbrook (... 1                 3.127417e-35
# PLEASNTV230 KV 274D FOR ELMONT-CUNNIGHAM:L500.E... 1                 6.382196e-36
#
#                                                                    prob_exceed_105  \
# constraint_id                                      flow_direction
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Belm... 1                  3.524835e-88
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Bram... 1                  0.000000e+00
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Bram... 1                 4.460173e-223
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Ever... 1                 2.301370e-205
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Ever... 1                 3.228535e-212
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Goos... 1                  3.617404e-09
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Plea... 1                  2.895946e-05
# PLEASNTV-ASHBURN  274D      A  230 KV:L500.Burc... 1                  3.123641e-05
# PLEASNTV-ASHBURN  274D      A  230 KV:L500.Calv... 1                  9.080454e-98
# PLEASNTV-ASHBURN  274D      B  230 KV:L230.Bram... 1                  0.000000e+00
# PLEASNTV-ASHBURN 274D A 230 KV:L230.EvergreenMi... 1                 3.228535e-212
# PLEASNTV-ASHBURN 274D:L230.EvergreenMills-Brabl... 1                 2.301370e-205
# PLEASNTV230 KV  274D:BASE                          1                 7.991469e-222
# PLEASNTV230 KV  274D:L230.Belmont-CochranMill-A... 1                  3.524835e-88
# PLEASNTV230 KV  274D:L230.Brambleton-Beaumeade.227 1                  0.000000e+00
# PLEASNTV230 KV  274D:L230.Brambleton-PolandRoad... 1                 4.460173e-223
# PLEASNTV230 KV  274D:L230.EvergreenMills-Brable... 1                 2.301370e-205
# PLEASNTV230 KV  274D:L230.EvergreenMills-Yarley... 1                 3.228535e-212
# PLEASNTV230 KV  274D:L230.GooseCreek-Ashburn-Be... 1                  3.617404e-09
# PLEASNTV230 KV  274D:L230.PleasantView-Belmont.... 1                  2.895946e-05
# PLEASNTV230 KV  274D:L230.Shellhorn-Enterprise.... 1                 1.474137e-208
# PLEASNTV230 KV  274D:L500.Burches Hill-Possum P... 1                  3.123641e-05
# PLEASNTV230 KV  274D:L500.BurchesHill-PossumPoi... 1                  3.123641e-05
# PLEASNTV230 KV  274D:L500.Carson-Rawlings.511      1                 1.213107e-225
# PLEASNTV230 KV  274D:L500.Clifton-Mosby.559A       1                 3.416052e-223
# PLEASNTV230 KV  274D:L500.Elmont-Cunningham.553    1                 5.342341e-227
# PLEASNTV230 KV  274D:L500.Loudoun-Meadowbrook (... 1                 7.974861e-205
# PLEASNTV230 KV  274D:L500.MtStorm-Meadowbrook (... 1                 2.726615e-215
# PLEASNTV230 KV 274D FOR ELMONT-CUNNIGHAM:L500.E... 1                 5.342341e-227
#
#                                                                    actual_shadow_price  \
# constraint_id                                      flow_direction
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Belm... 1                               0.0
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Bram... 1                               0.0
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Bram... 1                               0.0
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Ever... 1                               0.0
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Ever... 1                               0.0
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Goos... 1                               0.0
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Plea... 1                               0.0
# PLEASNTV-ASHBURN  274D      A  230 KV:L500.Burc... 1                               0.0
# PLEASNTV-ASHBURN  274D      A  230 KV:L500.Calv... 1                               0.0
# PLEASNTV-ASHBURN  274D      B  230 KV:L230.Bram... 1                               0.0
# PLEASNTV-ASHBURN 274D A 230 KV:L230.EvergreenMi... 1                               0.0
# PLEASNTV-ASHBURN 274D:L230.EvergreenMills-Brabl... 1                               0.0
# PLEASNTV230 KV  274D:BASE                          1                               0.0
# PLEASNTV230 KV  274D:L230.Belmont-CochranMill-A... 1                               0.0
# PLEASNTV230 KV  274D:L230.Brambleton-Beaumeade.227 1                               0.0
# PLEASNTV230 KV  274D:L230.Brambleton-PolandRoad... 1                               0.0
# PLEASNTV230 KV  274D:L230.EvergreenMills-Brable... 1                               0.0
# PLEASNTV230 KV  274D:L230.EvergreenMills-Yarley... 1                               0.0
# PLEASNTV230 KV  274D:L230.GooseCreek-Ashburn-Be... 1                               0.0
# PLEASNTV230 KV  274D:L230.PleasantView-Belmont.... 1                               0.0
# PLEASNTV230 KV  274D:L230.Shellhorn-Enterprise.... 1                               0.0
# PLEASNTV230 KV  274D:L500.Burches Hill-Possum P... 1                               0.0
# PLEASNTV230 KV  274D:L500.BurchesHill-PossumPoi... 1                               0.0
# PLEASNTV230 KV  274D:L500.Carson-Rawlings.511      1                               0.0
# PLEASNTV230 KV  274D:L500.Clifton-Mosby.559A       1                               0.0
# PLEASNTV230 KV  274D:L500.Elmont-Cunningham.553    1                               0.0
# PLEASNTV230 KV  274D:L500.Loudoun-Meadowbrook (... 1                               0.0
# PLEASNTV230 KV  274D:L500.MtStorm-Meadowbrook (... 1                               0.0
# PLEASNTV230 KV 274D FOR ELMONT-CUNNIGHAM:L500.E... 1                               0.0
#
#                                                                    predicted_shadow_price  \
# constraint_id                                      flow_direction
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Belm... 1                          2097.359131
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Bram... 1                             0.000000
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Bram... 1                             0.000000
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Ever... 1                             0.000000
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Ever... 1                             0.000000
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Goos... 1                         23651.080078
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Plea... 1                         23671.671631
# PLEASNTV-ASHBURN  274D      A  230 KV:L500.Burc... 1                         23326.573242
# PLEASNTV-ASHBURN  274D      A  230 KV:L500.Calv... 1                          2097.359131
# PLEASNTV-ASHBURN  274D      B  230 KV:L230.Bram... 1                             0.000000
# PLEASNTV-ASHBURN 274D A 230 KV:L230.EvergreenMi... 1                             0.000000
# PLEASNTV-ASHBURN 274D:L230.EvergreenMills-Brabl... 1                             0.000000
# PLEASNTV230 KV  274D:BASE                          1                             0.000000
# PLEASNTV230 KV  274D:L230.Belmont-CochranMill-A... 1                          2097.359131
# PLEASNTV230 KV  274D:L230.Brambleton-Beaumeade.227 1                             0.000000
# PLEASNTV230 KV  274D:L230.Brambleton-PolandRoad... 1                             0.000000
# PLEASNTV230 KV  274D:L230.EvergreenMills-Brable... 1                             0.000000
# PLEASNTV230 KV  274D:L230.EvergreenMills-Yarley... 1                             0.000000
# PLEASNTV230 KV  274D:L230.GooseCreek-Ashburn-Be... 1                         23651.080078
# PLEASNTV230 KV  274D:L230.PleasantView-Belmont.... 1                         23671.671631
# PLEASNTV230 KV  274D:L230.Shellhorn-Enterprise.... 1                             0.000000
# PLEASNTV230 KV  274D:L500.Burches Hill-Possum P... 1                         23326.573242
# PLEASNTV230 KV  274D:L500.BurchesHill-PossumPoi... 1                         23326.573242
# PLEASNTV230 KV  274D:L500.Carson-Rawlings.511      1                             0.000000
# PLEASNTV230 KV  274D:L500.Clifton-Mosby.559A       1                             0.000000
# PLEASNTV230 KV  274D:L500.Elmont-Cunningham.553    1                             0.000000
# PLEASNTV230 KV  274D:L500.Loudoun-Meadowbrook (... 1                             0.000000
# PLEASNTV230 KV  274D:L500.MtStorm-Meadowbrook (... 1                             0.000000
# PLEASNTV230 KV 274D FOR ELMONT-CUNNIGHAM:L500.E... 1                             0.000000
#
#                                                                    binding_probability  \
# constraint_id                                      flow_direction
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Belm... 1                          0.345923
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Bram... 1                          0.012459
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Bram... 1                          0.012459
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Ever... 1                          0.012459
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Ever... 1                          0.012459
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Goos... 1                          0.815353
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Plea... 1                          0.815353
# PLEASNTV-ASHBURN  274D      A  230 KV:L500.Burc... 1                          0.485773
# PLEASNTV-ASHBURN  274D      A  230 KV:L500.Calv... 1                          0.345923
# PLEASNTV-ASHBURN  274D      B  230 KV:L230.Bram... 1                          0.012459
# PLEASNTV-ASHBURN 274D A 230 KV:L230.EvergreenMi... 1                          0.012459
# PLEASNTV-ASHBURN 274D:L230.EvergreenMills-Brabl... 1                          0.012459
# PLEASNTV230 KV  274D:BASE                          1                          0.012459
# PLEASNTV230 KV  274D:L230.Belmont-CochranMill-A... 1                          0.345923
# PLEASNTV230 KV  274D:L230.Brambleton-Beaumeade.227 1                          0.012459
# PLEASNTV230 KV  274D:L230.Brambleton-PolandRoad... 1                          0.012459
# PLEASNTV230 KV  274D:L230.EvergreenMills-Brable... 1                          0.012459
# PLEASNTV230 KV  274D:L230.EvergreenMills-Yarley... 1                          0.012459
# PLEASNTV230 KV  274D:L230.GooseCreek-Ashburn-Be... 1                          0.815353
# PLEASNTV230 KV  274D:L230.PleasantView-Belmont.... 1                          0.815353
# PLEASNTV230 KV  274D:L230.Shellhorn-Enterprise.... 1                          0.012459
# PLEASNTV230 KV  274D:L500.Burches Hill-Possum P... 1                          0.485773
# PLEASNTV230 KV  274D:L500.BurchesHill-PossumPoi... 1                          0.485773
# PLEASNTV230 KV  274D:L500.Carson-Rawlings.511      1                          0.012459
# PLEASNTV230 KV  274D:L500.Clifton-Mosby.559A       1                          0.012459
# PLEASNTV230 KV  274D:L500.Elmont-Cunningham.553    1                          0.012459
# PLEASNTV230 KV  274D:L500.Loudoun-Meadowbrook (... 1                          0.012459
# PLEASNTV230 KV  274D:L500.MtStorm-Meadowbrook (... 1                          0.012459
# PLEASNTV230 KV 274D FOR ELMONT-CUNNIGHAM:L500.E... 1                          0.012459
#
#                                                                    binding_probability_scaled  \
# constraint_id                                      flow_direction
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Belm... 1                                 0.230033
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Bram... 1                                 0.014604
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Bram... 1                                 0.016227
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Ever... 1                                 0.011270
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Ever... 1                                 0.016227
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Goos... 1                                 0.804812
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Plea... 1                                 0.736088
# PLEASNTV-ASHBURN  274D      A  230 KV:L500.Burc... 1                                 0.567150
# PLEASNTV-ASHBURN  274D      A  230 KV:L500.Calv... 1                                 0.230051
# PLEASNTV-ASHBURN  274D      B  230 KV:L230.Bram... 1                                 0.014604
# PLEASNTV-ASHBURN 274D A 230 KV:L230.EvergreenMi... 1                                 0.016227
# PLEASNTV-ASHBURN 274D:L230.EvergreenMills-Brabl... 1                                 0.011270
# PLEASNTV230 KV  274D:BASE                          1                                 0.016227
# PLEASNTV230 KV  274D:L230.Belmont-CochranMill-A... 1                                 0.230033
# PLEASNTV230 KV  274D:L230.Brambleton-Beaumeade.227 1                                 0.014604
# PLEASNTV230 KV  274D:L230.Brambleton-PolandRoad... 1                                 0.016227
# PLEASNTV230 KV  274D:L230.EvergreenMills-Brable... 1                                 0.011270
# PLEASNTV230 KV  274D:L230.EvergreenMills-Yarley... 1                                 0.016227
# PLEASNTV230 KV  274D:L230.GooseCreek-Ashburn-Be... 1                                 0.804812
# PLEASNTV230 KV  274D:L230.PleasantView-Belmont.... 1                                 0.736088
# PLEASNTV230 KV  274D:L230.Shellhorn-Enterprise.... 1                                 0.016227
# PLEASNTV230 KV  274D:L500.Burches Hill-Possum P... 1                                 0.567150
# PLEASNTV230 KV  274D:L500.BurchesHill-PossumPoi... 1                                 0.567150
# PLEASNTV230 KV  274D:L500.Carson-Rawlings.511      1                                 0.016275
# PLEASNTV230 KV  274D:L500.Clifton-Mosby.559A       1                                 0.016196
# PLEASNTV230 KV  274D:L500.Elmont-Cunningham.553    1                                 0.018193
# PLEASNTV230 KV  274D:L500.Loudoun-Meadowbrook (... 1                                 0.015551
# PLEASNTV230 KV  274D:L500.MtStorm-Meadowbrook (... 1                                 0.015431
# PLEASNTV230 KV 274D FOR ELMONT-CUNNIGHAM:L500.E... 1                                 0.018193
#
#                                                                    threshold  \
# constraint_id                                      flow_direction
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Belm... 1                0.330407
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Bram... 1                0.330407
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Bram... 1                0.330407
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Ever... 1                0.330407
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Ever... 1                0.330407
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Goos... 1                0.330407
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Plea... 1                0.330407
# PLEASNTV-ASHBURN  274D      A  230 KV:L500.Burc... 1                0.330407
# PLEASNTV-ASHBURN  274D      A  230 KV:L500.Calv... 1                0.330407
# PLEASNTV-ASHBURN  274D      B  230 KV:L230.Bram... 1                0.330407
# PLEASNTV-ASHBURN 274D A 230 KV:L230.EvergreenMi... 1                0.330407
# PLEASNTV-ASHBURN 274D:L230.EvergreenMills-Brabl... 1                0.330407
# PLEASNTV230 KV  274D:BASE                          1                0.330407
# PLEASNTV230 KV  274D:L230.Belmont-CochranMill-A... 1                0.330407
# PLEASNTV230 KV  274D:L230.Brambleton-Beaumeade.227 1                0.330407
# PLEASNTV230 KV  274D:L230.Brambleton-PolandRoad... 1                0.330407
# PLEASNTV230 KV  274D:L230.EvergreenMills-Brable... 1                0.330407
# PLEASNTV230 KV  274D:L230.EvergreenMills-Yarley... 1                0.330407
# PLEASNTV230 KV  274D:L230.GooseCreek-Ashburn-Be... 1                0.330407
# PLEASNTV230 KV  274D:L230.PleasantView-Belmont.... 1                0.330407
# PLEASNTV230 KV  274D:L230.Shellhorn-Enterprise.... 1                0.330407
# PLEASNTV230 KV  274D:L500.Burches Hill-Possum P... 1                0.330407
# PLEASNTV230 KV  274D:L500.BurchesHill-PossumPoi... 1                0.330407
# PLEASNTV230 KV  274D:L500.Carson-Rawlings.511      1                0.330407
# PLEASNTV230 KV  274D:L500.Clifton-Mosby.559A       1                0.330407
# PLEASNTV230 KV  274D:L500.Elmont-Cunningham.553    1                0.330407
# PLEASNTV230 KV  274D:L500.Loudoun-Meadowbrook (... 1                0.330407
# PLEASNTV230 KV  274D:L500.MtStorm-Meadowbrook (... 1                0.330407
# PLEASNTV230 KV 274D FOR ELMONT-CUNNIGHAM:L500.E... 1                0.330407
#
#                                                                    predicted_binding_count  \
# constraint_id                                      flow_direction
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Belm... 1                                     1
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Bram... 1                                     0
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Bram... 1                                     0
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Ever... 1                                     0
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Ever... 1                                     0
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Goos... 1                                    11
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Plea... 1                                    11
# PLEASNTV-ASHBURN  274D      A  230 KV:L500.Burc... 1                                    11
# PLEASNTV-ASHBURN  274D      A  230 KV:L500.Calv... 1                                     1
# PLEASNTV-ASHBURN  274D      B  230 KV:L230.Bram... 1                                     0
# PLEASNTV-ASHBURN 274D A 230 KV:L230.EvergreenMi... 1                                     0
# PLEASNTV-ASHBURN 274D:L230.EvergreenMills-Brabl... 1                                     0
# PLEASNTV230 KV  274D:BASE                          1                                     0
# PLEASNTV230 KV  274D:L230.Belmont-CochranMill-A... 1                                     1
# PLEASNTV230 KV  274D:L230.Brambleton-Beaumeade.227 1                                     0
# PLEASNTV230 KV  274D:L230.Brambleton-PolandRoad... 1                                     0
# PLEASNTV230 KV  274D:L230.EvergreenMills-Brable... 1                                     0
# PLEASNTV230 KV  274D:L230.EvergreenMills-Yarley... 1                                     0
# PLEASNTV230 KV  274D:L230.GooseCreek-Ashburn-Be... 1                                    11
# PLEASNTV230 KV  274D:L230.PleasantView-Belmont.... 1                                    11
# PLEASNTV230 KV  274D:L230.Shellhorn-Enterprise.... 1                                     0
# PLEASNTV230 KV  274D:L500.Burches Hill-Possum P... 1                                    11
# PLEASNTV230 KV  274D:L500.BurchesHill-PossumPoi... 1                                    11
# PLEASNTV230 KV  274D:L500.Carson-Rawlings.511      1                                     0
# PLEASNTV230 KV  274D:L500.Clifton-Mosby.559A       1                                     0
# PLEASNTV230 KV  274D:L500.Elmont-Cunningham.553    1                                     0
# PLEASNTV230 KV  274D:L500.Loudoun-Meadowbrook (... 1                                     0
# PLEASNTV230 KV  274D:L500.MtStorm-Meadowbrook (... 1                                     0
# PLEASNTV230 KV 274D FOR ELMONT-CUNNIGHAM:L500.E... 1                                     0
#
#                                                                    actual_binding  \
# constraint_id                                      flow_direction
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Belm... 1                            0
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Bram... 1                            0
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Bram... 1                            0
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Ever... 1                            0
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Ever... 1                            0
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Goos... 1                            0
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Plea... 1                            0
# PLEASNTV-ASHBURN  274D      A  230 KV:L500.Burc... 1                            0
# PLEASNTV-ASHBURN  274D      A  230 KV:L500.Calv... 1                            0
# PLEASNTV-ASHBURN  274D      B  230 KV:L230.Bram... 1                            0
# PLEASNTV-ASHBURN 274D A 230 KV:L230.EvergreenMi... 1                            0
# PLEASNTV-ASHBURN 274D:L230.EvergreenMills-Brabl... 1                            0
# PLEASNTV230 KV  274D:BASE                          1                            0
# PLEASNTV230 KV  274D:L230.Belmont-CochranMill-A... 1                            0
# PLEASNTV230 KV  274D:L230.Brambleton-Beaumeade.227 1                            0
# PLEASNTV230 KV  274D:L230.Brambleton-PolandRoad... 1                            0
# PLEASNTV230 KV  274D:L230.EvergreenMills-Brable... 1                            0
# PLEASNTV230 KV  274D:L230.EvergreenMills-Yarley... 1                            0
# PLEASNTV230 KV  274D:L230.GooseCreek-Ashburn-Be... 1                            0
# PLEASNTV230 KV  274D:L230.PleasantView-Belmont.... 1                            0
# PLEASNTV230 KV  274D:L230.Shellhorn-Enterprise.... 1                            0
# PLEASNTV230 KV  274D:L500.Burches Hill-Possum P... 1                            0
# PLEASNTV230 KV  274D:L500.BurchesHill-PossumPoi... 1                            0
# PLEASNTV230 KV  274D:L500.Carson-Rawlings.511      1                            0
# PLEASNTV230 KV  274D:L500.Clifton-Mosby.559A       1                            0
# PLEASNTV230 KV  274D:L500.Elmont-Cunningham.553    1                            0
# PLEASNTV230 KV  274D:L500.Loudoun-Meadowbrook (... 1                            0
# PLEASNTV230 KV  274D:L500.MtStorm-Meadowbrook (... 1                            0
# PLEASNTV230 KV 274D FOR ELMONT-CUNNIGHAM:L500.E... 1                            0
#
#                                                                   auction_month  \
# constraint_id                                      flow_direction
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Belm... 1                 2025-07-01
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Bram... 1                 2025-07-01
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Bram... 1                 2025-07-01
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Ever... 1                 2025-07-01
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Ever... 1                 2025-07-01
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Goos... 1                 2025-07-01
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Plea... 1                 2025-07-01
# PLEASNTV-ASHBURN  274D      A  230 KV:L500.Burc... 1                 2025-07-01
# PLEASNTV-ASHBURN  274D      A  230 KV:L500.Calv... 1                 2025-07-01
# PLEASNTV-ASHBURN  274D      B  230 KV:L230.Bram... 1                 2025-07-01
# PLEASNTV-ASHBURN 274D A 230 KV:L230.EvergreenMi... 1                 2025-07-01
# PLEASNTV-ASHBURN 274D:L230.EvergreenMills-Brabl... 1                 2025-07-01
# PLEASNTV230 KV  274D:BASE                          1                 2025-07-01
# PLEASNTV230 KV  274D:L230.Belmont-CochranMill-A... 1                 2025-07-01
# PLEASNTV230 KV  274D:L230.Brambleton-Beaumeade.227 1                 2025-07-01
# PLEASNTV230 KV  274D:L230.Brambleton-PolandRoad... 1                 2025-07-01
# PLEASNTV230 KV  274D:L230.EvergreenMills-Brable... 1                 2025-07-01
# PLEASNTV230 KV  274D:L230.EvergreenMills-Yarley... 1                 2025-07-01
# PLEASNTV230 KV  274D:L230.GooseCreek-Ashburn-Be... 1                 2025-07-01
# PLEASNTV230 KV  274D:L230.PleasantView-Belmont.... 1                 2025-07-01
# PLEASNTV230 KV  274D:L230.Shellhorn-Enterprise.... 1                 2025-07-01
# PLEASNTV230 KV  274D:L500.Burches Hill-Possum P... 1                 2025-07-01
# PLEASNTV230 KV  274D:L500.BurchesHill-PossumPoi... 1                 2025-07-01
# PLEASNTV230 KV  274D:L500.Carson-Rawlings.511      1                 2025-07-01
# PLEASNTV230 KV  274D:L500.Clifton-Mosby.559A       1                 2025-07-01
# PLEASNTV230 KV  274D:L500.Elmont-Cunningham.553    1                 2025-07-01
# PLEASNTV230 KV  274D:L500.Loudoun-Meadowbrook (... 1                 2025-07-01
# PLEASNTV230 KV  274D:L500.MtStorm-Meadowbrook (... 1                 2025-07-01
# PLEASNTV230 KV 274D FOR ELMONT-CUNNIGHAM:L500.E... 1                 2025-07-01
#
#                                                                   market_month  \
# constraint_id                                      flow_direction
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Belm... 1                2025-07-01
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Bram... 1                2025-07-01
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Bram... 1                2025-07-01
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Ever... 1                2025-07-01
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Ever... 1                2025-07-01
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Goos... 1                2025-07-01
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Plea... 1                2025-07-01
# PLEASNTV-ASHBURN  274D      A  230 KV:L500.Burc... 1                2025-07-01
# PLEASNTV-ASHBURN  274D      A  230 KV:L500.Calv... 1                2025-07-01
# PLEASNTV-ASHBURN  274D      B  230 KV:L230.Bram... 1                2025-07-01
# PLEASNTV-ASHBURN 274D A 230 KV:L230.EvergreenMi... 1                2025-07-01
# PLEASNTV-ASHBURN 274D:L230.EvergreenMills-Brabl... 1                2025-07-01
# PLEASNTV230 KV  274D:BASE                          1                2025-07-01
# PLEASNTV230 KV  274D:L230.Belmont-CochranMill-A... 1                2025-07-01
# PLEASNTV230 KV  274D:L230.Brambleton-Beaumeade.227 1                2025-07-01
# PLEASNTV230 KV  274D:L230.Brambleton-PolandRoad... 1                2025-07-01
# PLEASNTV230 KV  274D:L230.EvergreenMills-Brable... 1                2025-07-01
# PLEASNTV230 KV  274D:L230.EvergreenMills-Yarley... 1                2025-07-01
# PLEASNTV230 KV  274D:L230.GooseCreek-Ashburn-Be... 1                2025-07-01
# PLEASNTV230 KV  274D:L230.PleasantView-Belmont.... 1                2025-07-01
# PLEASNTV230 KV  274D:L230.Shellhorn-Enterprise.... 1                2025-07-01
# PLEASNTV230 KV  274D:L500.Burches Hill-Possum P... 1                2025-07-01
# PLEASNTV230 KV  274D:L500.BurchesHill-PossumPoi... 1                2025-07-01
# PLEASNTV230 KV  274D:L500.Carson-Rawlings.511      1                2025-07-01
# PLEASNTV230 KV  274D:L500.Clifton-Mosby.559A       1                2025-07-01
# PLEASNTV230 KV  274D:L500.Elmont-Cunningham.553    1                2025-07-01
# PLEASNTV230 KV  274D:L500.Loudoun-Meadowbrook (... 1                2025-07-01
# PLEASNTV230 KV  274D:L500.MtStorm-Meadowbrook (... 1                2025-07-01
# PLEASNTV230 KV 274D FOR ELMONT-CUNNIGHAM:L500.E... 1                2025-07-01
#
#                                                                                  model_used  \
# constraint_id                                      flow_direction
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Belm... 1               Branch CLF + Default REG
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Bram... 1                             Branch CLF
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Bram... 1                             Branch CLF
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Ever... 1                             Branch CLF
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Ever... 1                             Branch CLF
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Goos... 1               Branch CLF + Default REG
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Plea... 1               Branch CLF + Default REG
# PLEASNTV-ASHBURN  274D      A  230 KV:L500.Burc... 1               Branch CLF + Default REG
# PLEASNTV-ASHBURN  274D      A  230 KV:L500.Calv... 1               Branch CLF + Default REG
# PLEASNTV-ASHBURN  274D      B  230 KV:L230.Bram... 1                             Branch CLF
# PLEASNTV-ASHBURN 274D A 230 KV:L230.EvergreenMi... 1                             Branch CLF
# PLEASNTV-ASHBURN 274D:L230.EvergreenMills-Brabl... 1                             Branch CLF
# PLEASNTV230 KV  274D:BASE                          1                             Branch CLF
# PLEASNTV230 KV  274D:L230.Belmont-CochranMill-A... 1               Branch CLF + Default REG
# PLEASNTV230 KV  274D:L230.Brambleton-Beaumeade.227 1                             Branch CLF
# PLEASNTV230 KV  274D:L230.Brambleton-PolandRoad... 1                             Branch CLF
# PLEASNTV230 KV  274D:L230.EvergreenMills-Brable... 1                             Branch CLF
# PLEASNTV230 KV  274D:L230.EvergreenMills-Yarley... 1                             Branch CLF
# PLEASNTV230 KV  274D:L230.GooseCreek-Ashburn-Be... 1               Branch CLF + Default REG
# PLEASNTV230 KV  274D:L230.PleasantView-Belmont.... 1               Branch CLF + Default REG
# PLEASNTV230 KV  274D:L230.Shellhorn-Enterprise.... 1                             Branch CLF
# PLEASNTV230 KV  274D:L500.Burches Hill-Possum P... 1               Branch CLF + Default REG
# PLEASNTV230 KV  274D:L500.BurchesHill-PossumPoi... 1               Branch CLF + Default REG
# PLEASNTV230 KV  274D:L500.Carson-Rawlings.511      1                             Branch CLF
# PLEASNTV230 KV  274D:L500.Clifton-Mosby.559A       1                             Branch CLF
# PLEASNTV230 KV  274D:L500.Elmont-Cunningham.553    1                             Branch CLF
# PLEASNTV230 KV  274D:L500.Loudoun-Meadowbrook (... 1                             Branch CLF
# PLEASNTV230 KV  274D:L500.MtStorm-Meadowbrook (... 1                             Branch CLF
# PLEASNTV230 KV 274D FOR ELMONT-CUNNIGHAM:L500.E... 1                             Branch CLF
#
#                                                                    predicted_binding  \
# constraint_id                                      flow_direction
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Belm... 1                            True
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Bram... 1                           False
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Bram... 1                           False
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Ever... 1                           False
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Ever... 1                           False
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Goos... 1                            True
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Plea... 1                            True
# PLEASNTV-ASHBURN  274D      A  230 KV:L500.Burc... 1                            True
# PLEASNTV-ASHBURN  274D      A  230 KV:L500.Calv... 1                            True
# PLEASNTV-ASHBURN  274D      B  230 KV:L230.Bram... 1                           False
# PLEASNTV-ASHBURN 274D A 230 KV:L230.EvergreenMi... 1                           False
# PLEASNTV-ASHBURN 274D:L230.EvergreenMills-Brabl... 1                           False
# PLEASNTV230 KV  274D:BASE                          1                           False
# PLEASNTV230 KV  274D:L230.Belmont-CochranMill-A... 1                            True
# PLEASNTV230 KV  274D:L230.Brambleton-Beaumeade.227 1                           False
# PLEASNTV230 KV  274D:L230.Brambleton-PolandRoad... 1                           False
# PLEASNTV230 KV  274D:L230.EvergreenMills-Brable... 1                           False
# PLEASNTV230 KV  274D:L230.EvergreenMills-Yarley... 1                           False
# PLEASNTV230 KV  274D:L230.GooseCreek-Ashburn-Be... 1                            True
# PLEASNTV230 KV  274D:L230.PleasantView-Belmont.... 1                            True
# PLEASNTV230 KV  274D:L230.Shellhorn-Enterprise.... 1                           False
# PLEASNTV230 KV  274D:L500.Burches Hill-Possum P... 1                            True
# PLEASNTV230 KV  274D:L500.BurchesHill-PossumPoi... 1                            True
# PLEASNTV230 KV  274D:L500.Carson-Rawlings.511      1                           False
# PLEASNTV230 KV  274D:L500.Clifton-Mosby.559A       1                           False
# PLEASNTV230 KV  274D:L500.Elmont-Cunningham.553    1                           False
# PLEASNTV230 KV  274D:L500.Loudoun-Meadowbrook (... 1                           False
# PLEASNTV230 KV  274D:L500.MtStorm-Meadowbrook (... 1                           False
# PLEASNTV230 KV 274D FOR ELMONT-CUNNIGHAM:L500.E... 1                           False
#
#                                                                           error  \
# constraint_id                                      flow_direction
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Belm... 1                2097.359131
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Bram... 1                   0.000000
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Bram... 1                   0.000000
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Ever... 1                   0.000000
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Ever... 1                   0.000000
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Goos... 1               23651.080078
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Plea... 1               23671.671631
# PLEASNTV-ASHBURN  274D      A  230 KV:L500.Burc... 1               23326.573242
# PLEASNTV-ASHBURN  274D      A  230 KV:L500.Calv... 1                2097.359131
# PLEASNTV-ASHBURN  274D      B  230 KV:L230.Bram... 1                   0.000000
# PLEASNTV-ASHBURN 274D A 230 KV:L230.EvergreenMi... 1                   0.000000
# PLEASNTV-ASHBURN 274D:L230.EvergreenMills-Brabl... 1                   0.000000
# PLEASNTV230 KV  274D:BASE                          1                   0.000000
# PLEASNTV230 KV  274D:L230.Belmont-CochranMill-A... 1                2097.359131
# PLEASNTV230 KV  274D:L230.Brambleton-Beaumeade.227 1                   0.000000
# PLEASNTV230 KV  274D:L230.Brambleton-PolandRoad... 1                   0.000000
# PLEASNTV230 KV  274D:L230.EvergreenMills-Brable... 1                   0.000000
# PLEASNTV230 KV  274D:L230.EvergreenMills-Yarley... 1                   0.000000
# PLEASNTV230 KV  274D:L230.GooseCreek-Ashburn-Be... 1               23651.080078
# PLEASNTV230 KV  274D:L230.PleasantView-Belmont.... 1               23671.671631
# PLEASNTV230 KV  274D:L230.Shellhorn-Enterprise.... 1                   0.000000
# PLEASNTV230 KV  274D:L500.Burches Hill-Possum P... 1               23326.573242
# PLEASNTV230 KV  274D:L500.BurchesHill-PossumPoi... 1               23326.573242
# PLEASNTV230 KV  274D:L500.Carson-Rawlings.511      1                   0.000000
# PLEASNTV230 KV  274D:L500.Clifton-Mosby.559A       1                   0.000000
# PLEASNTV230 KV  274D:L500.Elmont-Cunningham.553    1                   0.000000
# PLEASNTV230 KV  274D:L500.Loudoun-Meadowbrook (... 1                   0.000000
# PLEASNTV230 KV  274D:L500.MtStorm-Meadowbrook (... 1                   0.000000
# PLEASNTV230 KV 274D FOR ELMONT-CUNNIGHAM:L500.E... 1                   0.000000
#
#                                                                       abs_error
# constraint_id                                      flow_direction
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Belm... 1                2097.359131
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Bram... 1                   0.000000
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Bram... 1                   0.000000
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Ever... 1                   0.000000
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Ever... 1                   0.000000
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Goos... 1               23651.080078
# PLEASNTV-ASHBURN  274D      A  230 KV:L230.Plea... 1               23671.671631
# PLEASNTV-ASHBURN  274D      A  230 KV:L500.Burc... 1               23326.573242
# PLEASNTV-ASHBURN  274D      A  230 KV:L500.Calv... 1                2097.359131
# PLEASNTV-ASHBURN  274D      B  230 KV:L230.Bram... 1                   0.000000
# PLEASNTV-ASHBURN 274D A 230 KV:L230.EvergreenMi... 1                   0.000000
# PLEASNTV-ASHBURN 274D:L230.EvergreenMills-Brabl... 1                   0.000000
# PLEASNTV230 KV  274D:BASE                          1                   0.000000
# PLEASNTV230 KV  274D:L230.Belmont-CochranMill-A... 1                2097.359131
# PLEASNTV230 KV  274D:L230.Brambleton-Beaumeade.227 1                   0.000000
# PLEASNTV230 KV  274D:L230.Brambleton-PolandRoad... 1                   0.000000
# PLEASNTV230 KV  274D:L230.EvergreenMills-Brable... 1                   0.000000
# PLEASNTV230 KV  274D:L230.EvergreenMills-Yarley... 1                   0.000000
# PLEASNTV230 KV  274D:L230.GooseCreek-Ashburn-Be... 1               23651.080078
# PLEASNTV230 KV  274D:L230.PleasantView-Belmont.... 1               23671.671631
# PLEASNTV230 KV  274D:L230.Shellhorn-Enterprise.... 1                   0.000000
# PLEASNTV230 KV  274D:L500.Burches Hill-Possum P... 1               23326.573242
# PLEASNTV230 KV  274D:L500.BurchesHill-PossumPoi... 1               23326.573242
# PLEASNTV230 KV  274D:L500.Carson-Rawlings.511      1                   0.000000
# PLEASNTV230 KV  274D:L500.Clifton-Mosby.559A       1                   0.000000
# PLEASNTV230 KV  274D:L500.Elmont-Cunningham.553    1                   0.000000
# PLEASNTV230 KV  274D:L500.Loudoun-Meadowbrook (... 1                   0.000000
# PLEASNTV230 KV  274D:L500.MtStorm-Meadowbrook (... 1                   0.000000
# PLEASNTV230 KV 274D FOR ELMONT-CUNNIGHAM:L500.E... 1                   0.000000

# %%
params = {
    'clf_xgb_n_estimators': 500,
    'clf_xgb_max_depth': 3,
    'clf_xgb_learning_rate': 0.3,
    'clf_xgb_gamma': 0,
    'clf_xgb_min_child_weight': 10,
    'clf_xgb_reg_alpha': 0.5,
    'clf_xgb_reg_lambda': 5,
    'reg_xgb_n_estimators': 500,
    'reg_xgb_max_depth': 3,
    'reg_xgb_learning_rate': 0.05,
    'reg_xgb_gamma': 0,
    'reg_xgb_min_child_weight': 10,
    'reg_xgb_reg_alpha': 0.5,
    'reg_xgb_reg_lambda': 10,
    'lr_penalty': 'l2',
    'lr_C': 10.0,
    'enet_alpha': 1.0,
    'enet_l1_ratio': 0.9,
    'threshold_beta': 50,
    'clf_xgb_thres': 1,
    'reg_xgb_thres': 1,
    'clf_lr_thres': 0.1,
    'reg_enet_thres': 0.1,

    'short_term_clf_xgb_w': 1,
    'short_term_reg_xgb_w': 1,
    'long_term_clf_xgb_w': 1,
    'long_term_reg_xgb_w': 1,
}

pipeline = create_pipeline_from_row(pd.Series(params))
# Out:
# Initializing pipeline with selected parameters:
#   clf_xgb_n_estimators: 500
#   clf_xgb_max_depth: 3
#   clf_xgb_learning_rate: 0.3
#   clf_xgb_gamma: 0
#   clf_xgb_min_child_weight: 10
#   clf_xgb_reg_alpha: 0.5
#   clf_xgb_reg_lambda: 5
#   reg_xgb_n_estimators: 500
#   reg_xgb_max_depth: 3
#   reg_xgb_learning_rate: 0.05
#   reg_xgb_gamma: 0
#   reg_xgb_min_child_weight: 10
#   reg_xgb_reg_alpha: 0.5
#   reg_xgb_reg_lambda: 10
#   lr_penalty: l2
#   lr_C: 10.0
#   enet_alpha: 1.0
#   enet_l1_ratio: 0.9
#   threshold_beta: 50
#   clf_xgb_thres: 1
#   reg_xgb_thres: 1
#   clf_lr_thres: 0.1
#   reg_enet_thres: 0.1
#   short_term_clf_xgb_w: 1
#   short_term_reg_xgb_w: 1
#   long_term_clf_xgb_w: 1
#   long_term_reg_xgb_w: 1

# %%
test_periods = []

def get_auction_period_type(auction_month, market_month):
    q_period = f'q{(market_month.month - 6) % 12 // 3 + 1}'
    f_period = f'f{(market_month.year - auction_month.year)*12 + market_month.month - auction_month.month}'
    period_type = None
    # all_periods = aptools.tools._rto_period_type_class.get_valid_periods(auction_month)
    all_periods = config.iso.auction_schedule.get(auction_month.month, [])
    if q_period in all_periods:
        period_type = q_period
    elif f_period in all_periods:
        period_type = f_period
    return period_type

for auction_month in pd.date_range('2024-06', '2026-01', freq='MS'):
    market_st = auction_month
    market_et = market_st
    # market_et = market_st + pd.offsets.MonthBegin(12) if market_st.month >= 6 else market_st
    # market_et = market_et.replace(month=5)
    
    for market_month in pd.date_range(start=market_st, end=market_et, freq='MS'):
        if get_auction_period_type(auction_month, market_month) is None:
            continue
        test_periods.append((auction_month, market_month))
len(test_periods)
# Out:
# 5

# %%
results_per_outage, final_results, metrics, training_res, models = pipeline.run(
    test_periods=test_periods,
    # test_periods=test_periods[2:3],
    verbose=True,
    use_parallel=True,
    n_jobs=22,
    output_dir='/opt/temp/tmp/pw_data/spice6/prod_f0p_model_miso/ml_pred/',
    # output_dir=None,
    refresh=True,
    class_type='onpeak',
    # branch_name='XRDSGRANC11_1  1',
    branch_name=None,
)
# Out:
# ================================================================================
# SHADOW PRICE PREDICTION PIPELINE - PARALLEL PER-AUCTION-MONTH MODE
# ================================================================================
# Total Test Periods: 5
# Unique Auction Months: 5
#
#   Auction: 2026-01 → 1 market month(s)
#     - Market: 2026-01
#   Auction: 2026-01 → 1 market month(s)
#     - Market: 2026-02
#   Auction: 2026-01 → 1 market month(s)
#     - Market: 2026-03
#   Auction: 2026-01 → 1 market month(s)
#     - Market: 2026-04
#   Auction: 2026-01 → 1 market month(s)
#     - Market: 2026-05
# Class Type: onpeak
#
# 🚀 Using Ray parallel processing for 5 auction months
#    Workers: 22
#
# ================================================================================
# [PARALLEL PROCESSING: Training and Predicting for All Auction Months]
# ================================================================================
#   0%|          | 0/5 [00:00<?, ?it/s]
# (PoolActor pid=4067979, ip=10.42.8.15)
# (PoolActor pid=4067979, ip=10.42.8.15) ================================================================================
# (PoolActor pid=4067979, ip=10.42.8.15) [Processing Auction Month: 2026-01]
# (PoolActor pid=4067979, ip=10.42.8.15)   Market Months: 1
# (PoolActor pid=4067979, ip=10.42.8.15)     - 2026-01
# (PoolActor pid=4067979, ip=10.42.8.15) ================================================================================
# (PoolActor pid=110438, ip=10.42.6.149)
# (PoolActor pid=110438, ip=10.42.6.149) ================================================================================
# (PoolActor pid=110438, ip=10.42.6.149) [Processing Auction Month: 2026-01]
# (PoolActor pid=110438, ip=10.42.6.149)   Market Months: 1
# (PoolActor pid=110438, ip=10.42.6.149)     - 2026-05
# (PoolActor pid=110438, ip=10.42.6.149) ================================================================================
# (PoolActor pid=4015463, ip=10.42.7.70)
# (PoolActor pid=4015463, ip=10.42.7.70) ================================================================================
# (PoolActor pid=4015463, ip=10.42.7.70) [Processing Auction Month: 2026-01]
# (PoolActor pid=4015463, ip=10.42.7.70)   Market Months: 1
# (PoolActor pid=4015463, ip=10.42.7.70)     - 2026-03
# (PoolActor pid=4015463, ip=10.42.7.70) ================================================================================
# (PoolActor pid=4082535, ip=10.42.4.173)
# (PoolActor pid=4082535, ip=10.42.4.173) ================================================================================
# (PoolActor pid=4082535, ip=10.42.4.173) [Processing Auction Month: 2026-01]
# (PoolActor pid=4082535, ip=10.42.4.173)   Market Months: 1
# (PoolActor pid=4082535, ip=10.42.4.173)     - 2026-04
# (PoolActor pid=4082535, ip=10.42.4.173) ================================================================================
# (PoolActor pid=4067979, ip=10.42.8.15) 25-12-10 17:05:52 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=4067979, ip=10.42.8.15) 25-12-10 17:05:52 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=4067979, ip=10.42.8.15) 25-12-10 17:05:52 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=4067979, ip=10.42.8.15) 25-12-10 17:05:52 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=110438, ip=10.42.6.149) 25-12-10 17:05:52 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=110438, ip=10.42.6.149) 25-12-10 17:05:52 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=110438, ip=10.42.6.149) 25-12-10 17:05:52 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=110438, ip=10.42.6.149) 25-12-10 17:05:52 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=4082535, ip=10.42.4.173) 25-12-10 17:05:52 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=4082535, ip=10.42.4.173) 25-12-10 17:05:52 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=4082535, ip=10.42.4.173) 25-12-10 17:05:52 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=4082535, ip=10.42.4.173) 25-12-10 17:05:52 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=4015463, ip=10.42.7.70) 25-12-10 17:05:52 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=4015463, ip=10.42.7.70) 25-12-10 17:05:52 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=4015463, ip=10.42.7.70) 25-12-10 17:05:52 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=4015463, ip=10.42.7.70) 25-12-10 17:05:52 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=4003447, ip=10.42.0.182)
# (PoolActor pid=4003447, ip=10.42.0.182) ================================================================================
# (PoolActor pid=4003447, ip=10.42.0.182) [Processing Auction Month: 2026-01]
# (PoolActor pid=4003447, ip=10.42.0.182)   Market Months: 1
# (PoolActor pid=4003447, ip=10.42.0.182)     - 2026-02
# (PoolActor pid=4003447, ip=10.42.0.182) ================================================================================
# (PoolActor pid=4067979, ip=10.42.8.15)
# (PoolActor pid=4067979, ip=10.42.8.15) [STEP 1: Training Period Calculation]
# (PoolActor pid=4067979, ip=10.42.8.15)   Training Range: 2025-01 to 2025-12
# (PoolActor pid=4067979, ip=10.42.8.15)
# (PoolActor pid=4067979, ip=10.42.8.15) [STEP 2: Loading Training Data]
# (PoolActor pid=4067979, ip=10.42.8.15)   Loading training data for 2025-01 (Types: ['f0'])...
# (PoolActor pid=110438, ip=10.42.6.149)
# (PoolActor pid=110438, ip=10.42.6.149) [STEP 1: Training Period Calculation]
# (PoolActor pid=110438, ip=10.42.6.149)   Training Range: 2025-01 to 2025-12
# (PoolActor pid=110438, ip=10.42.6.149)
# (PoolActor pid=110438, ip=10.42.6.149) [STEP 2: Loading Training Data]
# (PoolActor pid=110438, ip=10.42.6.149)   Loading training data for 2025-01 (Types: ['q4'])...
# (PoolActor pid=4003447, ip=10.42.0.182) 25-12-10 17:05:52 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=4003447, ip=10.42.0.182) 25-12-10 17:05:52 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=4003447, ip=10.42.0.182) 25-12-10 17:05:52 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=4003447, ip=10.42.0.182) 25-12-10 17:05:52 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=4082535, ip=10.42.4.173)
# (PoolActor pid=4082535, ip=10.42.4.173) [STEP 1: Training Period Calculation]
# (PoolActor pid=4082535, ip=10.42.4.173)   Training Range: 2025-01 to 2025-12
# (PoolActor pid=4082535, ip=10.42.4.173)
# (PoolActor pid=4082535, ip=10.42.4.173) [STEP 2: Loading Training Data]
# (PoolActor pid=4082535, ip=10.42.4.173)   Loading training data for 2025-01 (Types: ['q4'])...
# (PoolActor pid=4015463, ip=10.42.7.70)
# (PoolActor pid=4015463, ip=10.42.7.70) [STEP 1: Training Period Calculation]
# (PoolActor pid=4015463, ip=10.42.7.70)   Training Range: 2025-01 to 2025-12
# (PoolActor pid=4015463, ip=10.42.7.70)
# (PoolActor pid=4015463, ip=10.42.7.70) [STEP 2: Loading Training Data]
# (PoolActor pid=4015463, ip=10.42.7.70)   Loading training data for 2025-01 (Types: ['q4'])...
# (PoolActor pid=4003447, ip=10.42.0.182)
# (PoolActor pid=4003447, ip=10.42.0.182) [STEP 1: Training Period Calculation]
# (PoolActor pid=4003447, ip=10.42.0.182)   Training Range: 2025-01 to 2025-12
# (PoolActor pid=4003447, ip=10.42.0.182)
# (PoolActor pid=4003447, ip=10.42.0.182) [STEP 2: Loading Training Data]
# (PoolActor pid=4003447, ip=10.42.0.182)   Loading training data for 2025-01 (Types: ['f1'])...
# (PoolActor pid=4067979, ip=10.42.8.15)   Loading training data for 2025-02 (Types: ['f0'])...
# (PoolActor pid=4067979, ip=10.42.8.15)   Loading training data for 2025-03 (Types: ['f0'])...
# (PoolActor pid=4003447, ip=10.42.0.182)   Loading training data for 2025-02 (Types: ['f1'])...
# (PoolActor pid=4067979, ip=10.42.8.15)   Loading training data for 2025-04 (Types: ['f0'])...
# (PoolActor pid=110438, ip=10.42.6.149)   Loading training data for 2025-02 (Types: ['f2', 'f3'])...
# (PoolActor pid=4003447, ip=10.42.0.182)   Loading training data for 2025-03 (Types: ['f1'])...
# (PoolActor pid=4067979, ip=10.42.8.15)   Loading training data for 2025-05 (Types: ['f0'])...
# (PoolActor pid=4015463, ip=10.42.7.70)   Loading training data for 2025-02 (Types: ['f2', 'f3'])...
# (PoolActor pid=4082535, ip=10.42.4.173)   Loading training data for 2025-02 (Types: ['f2', 'f3'])...
# (PoolActor pid=4067979, ip=10.42.8.15)   Loading training data for 2025-06 (Types: ['f0'])...
# (PoolActor pid=4003447, ip=10.42.0.182)   Loading training data for 2025-04 (Types: ['f1'])...
# (PoolActor pid=110438, ip=10.42.6.149)   Loading training data for 2025-03 (Types: ['f2'])...
# (PoolActor pid=4067979, ip=10.42.8.15)   Loading training data for 2025-07 (Types: ['f0'])...
# (PoolActor pid=4015463, ip=10.42.7.70)   Loading training data for 2025-03 (Types: ['f2'])...
# (PoolActor pid=4067979, ip=10.42.8.15)   Loading training data for 2025-08 (Types: ['f0'])...
# (PoolActor pid=110438, ip=10.42.6.149)   Skipping 2025-04: No required period types available.
# (PoolActor pid=110438, ip=10.42.6.149)   Skipping 2025-05: No required period types available.
# (PoolActor pid=110438, ip=10.42.6.149)   Skipping 2025-06: No required period types available.
# (PoolActor pid=110438, ip=10.42.6.149)   Loading training data for 2025-07 (Types: ['q2', 'q3', 'q4'])...
# (PoolActor pid=4082535, ip=10.42.4.173)   Loading training data for 2025-03 (Types: ['f2'])...
# (PoolActor pid=4003447, ip=10.42.0.182)   Skipping 2025-05: No required period types available.
# (PoolActor pid=4003447, ip=10.42.0.182)   Skipping 2025-06: No required period types available.
# (PoolActor pid=4003447, ip=10.42.0.182)   Loading training data for 2025-07 (Types: ['f1'])...
# (PoolActor pid=4067979, ip=10.42.8.15)   Loading training data for 2025-09 (Types: ['f0'])...
# (PoolActor pid=4015463, ip=10.42.7.70)   Skipping 2025-04: No required period types available.
# (PoolActor pid=4015463, ip=10.42.7.70)   Skipping 2025-05: No required period types available.
# (PoolActor pid=4015463, ip=10.42.7.70)   Skipping 2025-06: No required period types available.
# (PoolActor pid=4015463, ip=10.42.7.70)   Loading training data for 2025-07 (Types: ['q2', 'q3', 'q4'])...
# (PoolActor pid=4082535, ip=10.42.4.173)   Skipping 2025-04: No required period types available.
# (PoolActor pid=4082535, ip=10.42.4.173)   Skipping 2025-05: No required period types available.
# (PoolActor pid=4082535, ip=10.42.4.173)   Skipping 2025-06: No required period types available.
# (PoolActor pid=4082535, ip=10.42.4.173)   Loading training data for 2025-07 (Types: ['q2', 'q3', 'q4'])...
# (PoolActor pid=4067979, ip=10.42.8.15)   Loading training data for 2025-10 (Types: ['f0'])...
# (PoolActor pid=4003447, ip=10.42.0.182)   Loading training data for 2025-08 (Types: ['f1'])...
# (PoolActor pid=4067979, ip=10.42.8.15)   Loading training data for 2025-11 (Types: ['f0'])...
# (PoolActor pid=110438, ip=10.42.6.149)     Skipping future month: 2025-12
# (PoolActor pid=110438, ip=10.42.6.149)     Skipping future month: 2026-01
# (PoolActor pid=110438, ip=10.42.6.149)     Skipping future month: 2026-02
# (PoolActor pid=110438, ip=10.42.6.149)     Skipping future month: 2026-03
# (PoolActor pid=110438, ip=10.42.6.149)     Skipping future month: 2026-04
# (PoolActor pid=110438, ip=10.42.6.149)     Skipping future month: 2026-05
# (PoolActor pid=110438, ip=10.42.6.149)   Loading training data for 2025-08 (Types: ['f2', 'f3'])...
# (PoolActor pid=4067979, ip=10.42.8.15)   Applying label modification based on prob_exceed_80 < 1e-05...
# (PoolActor pid=4067979, ip=10.42.8.15)     Modified 782302 labels to 0 where prob_exceed_80 < 1e-05.
# (PoolActor pid=4067979, ip=10.42.8.15)
# (PoolActor pid=4067979, ip=10.42.8.15) [STEP 3: Identifying Target Branches]
# (PoolActor pid=4067979, ip=10.42.8.15)   Identifying target branches from test periods...
# (PoolActor pid=4003447, ip=10.42.0.182)   Loading training data for 2025-09 (Types: ['f1'])...
# (PoolActor pid=4015463, ip=10.42.7.70)     Skipping future month: 2025-12
# (PoolActor pid=4015463, ip=10.42.7.70)     Skipping future month: 2026-01
# (PoolActor pid=4015463, ip=10.42.7.70)     Skipping future month: 2026-02
# (PoolActor pid=4015463, ip=10.42.7.70)     Skipping future month: 2026-03
# (PoolActor pid=4015463, ip=10.42.7.70)     Skipping future month: 2026-04
# (PoolActor pid=4015463, ip=10.42.7.70)     Skipping future month: 2026-05
# (PoolActor pid=4015463, ip=10.42.7.70)   Loading training data for 2025-08 (Types: ['f2', 'f3'])...
# (PoolActor pid=4067979, ip=10.42.8.15)   Found 5437 unique branch-flow pairs in test set.
# (PoolActor pid=4067979, ip=10.42.8.15)
# (PoolActor pid=4067979, ip=10.42.8.15) [STEP 4: Training Models for Auction Month 2026-01]
# (PoolActor pid=4067979, ip=10.42.8.15)
# (PoolActor pid=4067979, ip=10.42.8.15) [Training Classification Models + Threshold Optimization]
# (PoolActor pid=4067979, ip=10.42.8.15) --------------------------------------------------------------------------------
# (PoolActor pid=4067979, ip=10.42.8.15)   Skipping groups not in test periods: f1, long
# (PoolActor pid=4067979, ip=10.42.8.15)
# (PoolActor pid=4067979, ip=10.42.8.15) Processing F0 TERM models...
# (PoolActor pid=4067979, ip=10.42.8.15)   Training default fallback classifier (f0)...
# (PoolActor pid=4003447, ip=10.42.0.182)   Loading training data for 2025-10 (Types: ['f1'])...
# (PoolActor pid=110438, ip=10.42.6.149)   Loading training data for 2025-09 (Types: ['f2'])...
# (PoolActor pid=4082535, ip=10.42.4.173)     Skipping future month: 2025-12
# (PoolActor pid=4082535, ip=10.42.4.173)     Skipping future month: 2026-01
# (PoolActor pid=4082535, ip=10.42.4.173)     Skipping future month: 2026-02
# (PoolActor pid=4082535, ip=10.42.4.173)     Skipping future month: 2026-03
# (PoolActor pid=4082535, ip=10.42.4.173)     Skipping future month: 2026-04
# (PoolActor pid=4082535, ip=10.42.4.173)     Skipping future month: 2026-05
# (PoolActor pid=4082535, ip=10.42.4.173)   Loading training data for 2025-08 (Types: ['f2', 'f3'])...
# (PoolActor pid=4067979, ip=10.42.8.15)     ✓ Default ensemble trained (1 models)
# (PoolActor pid=4067979, ip=10.42.8.15)     Total samples: 1,469,905
# (PoolActor pid=4067979, ip=10.42.8.15)     Selected features: 6/7
# (PoolActor pid=4067979, ip=10.42.8.15)   Optimizing threshold for default ensemble (f0)...
# (PoolActor pid=110438, ip=10.42.6.149)   Loading training data for 2025-10 (Types: ['q3', 'q4'])...
# (PoolActor pid=110438, ip=10.42.6.149)     Skipping future month: 2025-12
# (PoolActor pid=110438, ip=10.42.6.149)     Skipping future month: 2026-01
# (PoolActor pid=110438, ip=10.42.6.149)     Skipping future month: 2026-02
# (PoolActor pid=110438, ip=10.42.6.149)     Skipping future month: 2026-03
# (PoolActor pid=110438, ip=10.42.6.149)     Skipping future month: 2026-04
# (PoolActor pid=110438, ip=10.42.6.149)     Skipping future month: 2026-05
# (PoolActor pid=110438, ip=10.42.6.149)   Loading training data for 2025-11 (Types: ['f2', 'f3'])...
# (PoolActor pid=110438, ip=10.42.6.149)     Skipping future month: 2026-01
# (PoolActor pid=110438, ip=10.42.6.149)     Skipping future month: 2026-02
# (PoolActor pid=110438, ip=10.42.6.149)   Applying label modification based on prob_exceed_80 < 1e-05...
# (PoolActor pid=110438, ip=10.42.6.149)     Modified 870945 labels to 0 where prob_exceed_80 < 1e-05.
# (PoolActor pid=110438, ip=10.42.6.149)
# (PoolActor pid=110438, ip=10.42.6.149) [STEP 3: Identifying Target Branches]
# (PoolActor pid=110438, ip=10.42.6.149)   Identifying target branches from test periods...
# (PoolActor pid=4067979, ip=10.42.8.15)     ✓ Optimal threshold: 0.021 (F-beta=0.990)
# (PoolActor pid=4067979, ip=10.42.8.15)   Training branch-specific classifiers (f0)...
# (PoolActor pid=4003447, ip=10.42.0.182)   Loading training data for 2025-11 (Types: ['f1'])...
# (PoolActor pid=4003447, ip=10.42.0.182)     Skipping future month: 2025-12
# (PoolActor pid=4003447, ip=10.42.0.182)   Applying label modification based on prob_exceed_80 < 1e-05...
# (PoolActor pid=4003447, ip=10.42.0.182)     Modified 572712 labels to 0 where prob_exceed_80 < 1e-05.
# (PoolActor pid=4003447, ip=10.42.0.182)
# (PoolActor pid=4003447, ip=10.42.0.182) [STEP 3: Identifying Target Branches]
# (PoolActor pid=4003447, ip=10.42.0.182)   Identifying target branches from test periods...
# (PoolActor pid=4015463, ip=10.42.7.70)   Loading training data for 2025-09 (Types: ['f2'])...
# (PoolActor pid=110438, ip=10.42.6.149)   Found 5486 unique branch-flow pairs in test set.
# (PoolActor pid=110438, ip=10.42.6.149)
# (PoolActor pid=110438, ip=10.42.6.149) [STEP 4: Training Models for Auction Month 2026-01]
# (PoolActor pid=110438, ip=10.42.6.149)
# (PoolActor pid=110438, ip=10.42.6.149) [Training Classification Models + Threshold Optimization]
# (PoolActor pid=110438, ip=10.42.6.149) --------------------------------------------------------------------------------
# (PoolActor pid=110438, ip=10.42.6.149)   Skipping groups not in test periods: f0, f1
# (PoolActor pid=110438, ip=10.42.6.149)
# (PoolActor pid=110438, ip=10.42.6.149) Processing LONG TERM models...
# (PoolActor pid=110438, ip=10.42.6.149)   Training default fallback classifier (long)...
# (PoolActor pid=4082535, ip=10.42.4.173)   Loading training data for 2025-09 (Types: ['f2'])...
# (PoolActor pid=4003447, ip=10.42.0.182)   Found 5397 unique branch-flow pairs in test set.
# (PoolActor pid=4003447, ip=10.42.0.182)
# (PoolActor pid=4003447, ip=10.42.0.182) [STEP 4: Training Models for Auction Month 2026-01]
# (PoolActor pid=4003447, ip=10.42.0.182)
# (PoolActor pid=4003447, ip=10.42.0.182) [Training Classification Models + Threshold Optimization]
# (PoolActor pid=4003447, ip=10.42.0.182) --------------------------------------------------------------------------------
# (PoolActor pid=4003447, ip=10.42.0.182)   Skipping groups not in test periods: f0, long
# (PoolActor pid=4003447, ip=10.42.0.182)
# (PoolActor pid=4003447, ip=10.42.0.182) Processing F1 TERM models...
# (PoolActor pid=4003447, ip=10.42.0.182)   Training default fallback classifier (f1)...
# (PoolActor pid=4015463, ip=10.42.7.70)   Loading training data for 2025-10 (Types: ['q3', 'q4'])...
# (PoolActor pid=4015463, ip=10.42.7.70)     Skipping future month: 2025-12
# (PoolActor pid=4015463, ip=10.42.7.70)     Skipping future month: 2026-01
# (PoolActor pid=4015463, ip=10.42.7.70)     Skipping future month: 2026-02
# (PoolActor pid=4015463, ip=10.42.7.70)     Skipping future month: 2026-03
# (PoolActor pid=4015463, ip=10.42.7.70)     Skipping future month: 2026-04
# (PoolActor pid=4015463, ip=10.42.7.70)     Skipping future month: 2026-05
# (PoolActor pid=4015463, ip=10.42.7.70)   Loading training data for 2025-11 (Types: ['f2', 'f3'])...
# (PoolActor pid=4015463, ip=10.42.7.70)     Skipping future month: 2026-01
# (PoolActor pid=4015463, ip=10.42.7.70)     Skipping future month: 2026-02
# (PoolActor pid=4015463, ip=10.42.7.70)   Applying label modification based on prob_exceed_80 < 1e-05...
# (PoolActor pid=4015463, ip=10.42.7.70)     Modified 870945 labels to 0 where prob_exceed_80 < 1e-05.
# (PoolActor pid=4015463, ip=10.42.7.70)
# (PoolActor pid=4015463, ip=10.42.7.70) [STEP 3: Identifying Target Branches]
# (PoolActor pid=4015463, ip=10.42.7.70)   Identifying target branches from test periods...
# (PoolActor pid=4082535, ip=10.42.4.173)   Loading training data for 2025-10 (Types: ['q3', 'q4'])...
# (PoolActor pid=4082535, ip=10.42.4.173)     Skipping future month: 2025-12
# (PoolActor pid=4082535, ip=10.42.4.173)     Skipping future month: 2026-01
# (PoolActor pid=4082535, ip=10.42.4.173)     Skipping future month: 2026-02
# (PoolActor pid=4082535, ip=10.42.4.173)     Skipping future month: 2026-03
# (PoolActor pid=4082535, ip=10.42.4.173)     Skipping future month: 2026-04
# (PoolActor pid=4082535, ip=10.42.4.173)     Skipping future month: 2026-05
# (PoolActor pid=4082535, ip=10.42.4.173)   Loading training data for 2025-11 (Types: ['f2', 'f3'])...
# (PoolActor pid=4082535, ip=10.42.4.173)     Skipping future month: 2026-01
# (PoolActor pid=4082535, ip=10.42.4.173)     Skipping future month: 2026-02
# (PoolActor pid=4067979, ip=10.42.8.15)     ✓ Trained 430 branch models (skipped 4907)
# (PoolActor pid=4067979, ip=10.42.8.15)
# (PoolActor pid=4067979, ip=10.42.8.15) ✓ Classification Training Complete
# (PoolActor pid=4067979, ip=10.42.8.15)
# (PoolActor pid=4067979, ip=10.42.8.15) ================================================================================
# (PoolActor pid=4067979, ip=10.42.8.15) FALLBACK MONITORING STATISTICS
# (PoolActor pid=4067979, ip=10.42.8.15) ================================================================================
# (PoolActor pid=4067979, ip=10.42.8.15)
# (PoolActor pid=4067979, ip=10.42.8.15) [F0]
# (PoolActor pid=4067979, ip=10.42.8.15)   Classification Fallback Rate: 0/430 (0.00%)
# (PoolActor pid=4067979, ip=10.42.8.15)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=4067979, ip=10.42.8.15)
# (PoolActor pid=4067979, ip=10.42.8.15) [F1]
# (PoolActor pid=4067979, ip=10.42.8.15)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=4067979, ip=10.42.8.15)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=4067979, ip=10.42.8.15)
# (PoolActor pid=4067979, ip=10.42.8.15) [LONG]
# (PoolActor pid=4067979, ip=10.42.8.15)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=4067979, ip=10.42.8.15)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=4082535, ip=10.42.4.173)   Applying label modification based on prob_exceed_80 < 1e-05...
# (PoolActor pid=4082535, ip=10.42.4.173)     Modified 870945 labels to 0 where prob_exceed_80 < 1e-05.
# (PoolActor pid=4082535, ip=10.42.4.173)
# (PoolActor pid=4082535, ip=10.42.4.173) [STEP 3: Identifying Target Branches]
# (PoolActor pid=4082535, ip=10.42.4.173)   Identifying target branches from test periods...
# (PoolActor pid=4067979, ip=10.42.8.15)
# (PoolActor pid=4067979, ip=10.42.8.15) [STEP 5: Training Regressors for Auction Month 2026-01]
# (PoolActor pid=4067979, ip=10.42.8.15)
# (PoolActor pid=4067979, ip=10.42.8.15) [Characterizing Never-Binding Branches for F0]
# (PoolActor pid=4067979, ip=10.42.8.15)   Detection Features: ['prob_exceed_100', 'prob_exceed_95']
# (PoolActor pid=4067979, ip=10.42.8.15)   Probability Features: ['prob_exceed_100', 'prob_exceed_95', 'density_skewness']
# (PoolActor pid=4067979, ip=10.42.8.15) --------------------------------------------------------------------------------
# (PoolActor pid=110438, ip=10.42.6.149)     ✓ Default ensemble trained (1 models)
# (PoolActor pid=110438, ip=10.42.6.149)     Total samples: 1,593,642
# (PoolActor pid=110438, ip=10.42.6.149)     Selected features: 6/7
# (PoolActor pid=110438, ip=10.42.6.149)   Optimizing threshold for default ensemble (long)...
# (PoolActor pid=4067979, ip=10.42.8.15) Analyzing 4,488 branches for never-binding patterns...
# (PoolActor pid=110438, ip=10.42.6.149)     ✓ Optimal threshold: 0.017 (F-beta=0.990)
# (PoolActor pid=110438, ip=10.42.6.149)   Training branch-specific classifiers (long)...
# (PoolActor pid=4067979, ip=10.42.8.15)
# (PoolActor pid=4067979, ip=10.42.8.15) ✓ Never-Binding Branches Identified (f0): 4,151
# (PoolActor pid=4067979, ip=10.42.8.15)
# (PoolActor pid=4067979, ip=10.42.8.15)   Example Flow Statistics for 'prob_exceed_100' (first 5 branches):
# (PoolActor pid=4067979, ip=10.42.8.15)     0304           1                             : mean=0.0000, P95=0.0003, IQR=0.0000
# (PoolActor pid=4067979, ip=10.42.8.15)     0321X          1                             : mean=0.0031, P95=0.0132, IQR=0.0019
# (PoolActor pid=4067979, ip=10.42.8.15)     0621           1                             : mean=0.0028, P95=0.0000, IQR=0.0000
# (PoolActor pid=4067979, ip=10.42.8.15)     0622           1                             : mean=0.0346, P95=0.1872, IQR=0.0018
# (PoolActor pid=4067979, ip=10.42.8.15)     0624           1                             : mean=0.0000, P95=0.0000, IQR=0.0000
# (PoolActor pid=4067979, ip=10.42.8.15)
# (PoolActor pid=4067979, ip=10.42.8.15)   Distribution of IQR for 'prob_exceed_100':
# (PoolActor pid=4067979, ip=10.42.8.15)     min=0.0000, median=0.0000, max=0.6372
# (PoolActor pid=4067979, ip=10.42.8.15)
# (PoolActor pid=4067979, ip=10.42.8.15) [Training Regression Models]
# (PoolActor pid=4067979, ip=10.42.8.15) --------------------------------------------------------------------------------
# (PoolActor pid=4067979, ip=10.42.8.15)   Skipping groups not in test periods: f1, long
# (PoolActor pid=4067979, ip=10.42.8.15)
# (PoolActor pid=4067979, ip=10.42.8.15) Processing F0 TERM models...
# (PoolActor pid=4067979, ip=10.42.8.15)   Training default fallback regressor (f0)...
# (PoolActor pid=4067979, ip=10.42.8.15)     ✓ Default ensemble trained (1 models)
# (PoolActor pid=4067979, ip=10.42.8.15)     Total binding samples: 32,137
# (PoolActor pid=4067979, ip=10.42.8.15)   Training branch-specific regressors (f0)...
# (PoolActor pid=4015463, ip=10.42.7.70)   Found 5471 unique branch-flow pairs in test set.
# (PoolActor pid=4015463, ip=10.42.7.70)
# (PoolActor pid=4015463, ip=10.42.7.70) [STEP 4: Training Models for Auction Month 2026-01]
# (PoolActor pid=4015463, ip=10.42.7.70)
# (PoolActor pid=4015463, ip=10.42.7.70) [Training Classification Models + Threshold Optimization]
# (PoolActor pid=4015463, ip=10.42.7.70) --------------------------------------------------------------------------------
# (PoolActor pid=4015463, ip=10.42.7.70)   Skipping groups not in test periods: f0, f1
# (PoolActor pid=4015463, ip=10.42.7.70)
# (PoolActor pid=4015463, ip=10.42.7.70) Processing LONG TERM models...
# (PoolActor pid=4015463, ip=10.42.7.70)   Training default fallback classifier (long)...
# (PoolActor pid=4082535, ip=10.42.4.173)   Found 5401 unique branch-flow pairs in test set.
# (PoolActor pid=4082535, ip=10.42.4.173)
# (PoolActor pid=4082535, ip=10.42.4.173) [STEP 4: Training Models for Auction Month 2026-01]
# (PoolActor pid=4082535, ip=10.42.4.173)
# (PoolActor pid=4082535, ip=10.42.4.173) [Training Classification Models + Threshold Optimization]
# (PoolActor pid=4082535, ip=10.42.4.173) --------------------------------------------------------------------------------
# (PoolActor pid=4082535, ip=10.42.4.173)   Skipping groups not in test periods: f0, f1
# (PoolActor pid=4082535, ip=10.42.4.173)
# (PoolActor pid=4082535, ip=10.42.4.173) Processing LONG TERM models...
# (PoolActor pid=4082535, ip=10.42.4.173)   Training default fallback classifier (long)...
# (PoolActor pid=4003447, ip=10.42.0.182)     ✓ Default ensemble trained (1 models)
# (PoolActor pid=4003447, ip=10.42.0.182)     Total samples: 1,062,529
# (PoolActor pid=4003447, ip=10.42.0.182)     Selected features: 6/7
# (PoolActor pid=4003447, ip=10.42.0.182)   Optimizing threshold for default ensemble (f1)...
# (PoolActor pid=4003447, ip=10.42.0.182)     ✓ Optimal threshold: 0.027 (F-beta=0.991)
# (PoolActor pid=4003447, ip=10.42.0.182)   Training branch-specific classifiers (f1)...
# (PoolActor pid=110438, ip=10.42.6.149)     ✓ Trained 387 branch models (skipped 4867)
# (PoolActor pid=110438, ip=10.42.6.149)
# (PoolActor pid=110438, ip=10.42.6.149) ✓ Classification Training Complete
# (PoolActor pid=110438, ip=10.42.6.149)
# (PoolActor pid=110438, ip=10.42.6.149) ================================================================================
# (PoolActor pid=110438, ip=10.42.6.149) FALLBACK MONITORING STATISTICS
# (PoolActor pid=110438, ip=10.42.6.149) ================================================================================
# (PoolActor pid=110438, ip=10.42.6.149)
# (PoolActor pid=110438, ip=10.42.6.149) [F0]
# (PoolActor pid=110438, ip=10.42.6.149)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=110438, ip=10.42.6.149)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=110438, ip=10.42.6.149)
# (PoolActor pid=110438, ip=10.42.6.149) [F1]
# (PoolActor pid=110438, ip=10.42.6.149)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=110438, ip=10.42.6.149)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=110438, ip=10.42.6.149)
# (PoolActor pid=110438, ip=10.42.6.149) [LONG]
# (PoolActor pid=110438, ip=10.42.6.149)   Classification Fallback Rate: 0/387 (0.00%)
# (PoolActor pid=110438, ip=10.42.6.149)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=110438, ip=10.42.6.149)
# (PoolActor pid=110438, ip=10.42.6.149) [STEP 5: Training Regressors for Auction Month 2026-01]
# (PoolActor pid=110438, ip=10.42.6.149)
# (PoolActor pid=110438, ip=10.42.6.149) [Characterizing Never-Binding Branches for LONG]
# (PoolActor pid=110438, ip=10.42.6.149)   Detection Features: ['prob_exceed_100', 'prob_exceed_95']
# (PoolActor pid=110438, ip=10.42.6.149)   Probability Features: ['prob_exceed_100', 'prob_exceed_95', 'density_skewness']
# (PoolActor pid=110438, ip=10.42.6.149) --------------------------------------------------------------------------------
# (PoolActor pid=110438, ip=10.42.6.149) Analyzing 4,419 branches for never-binding patterns...
# (PoolActor pid=110438, ip=10.42.6.149)
# (PoolActor pid=110438, ip=10.42.6.149) ✓ Never-Binding Branches Identified (long): 4,099
# (PoolActor pid=110438, ip=10.42.6.149)
# (PoolActor pid=110438, ip=10.42.6.149)   Example Flow Statistics for 'prob_exceed_100' (first 5 branches):
# (PoolActor pid=110438, ip=10.42.6.149)     0304           1                             : mean=0.0000, P95=0.0000, IQR=0.0000
# (PoolActor pid=110438, ip=10.42.6.149)     0321X          1                             : mean=0.0022, P95=0.0092, IQR=0.0016
# (PoolActor pid=110438, ip=10.42.6.149)     0621           1                             : mean=0.0004, P95=0.0000, IQR=0.0000
# (PoolActor pid=110438, ip=10.42.6.149)     0622           1                             : mean=0.0474, P95=0.2806, IQR=0.0093
# (PoolActor pid=110438, ip=10.42.6.149)     0624           1                             : mean=0.0000, P95=0.0000, IQR=0.0000
# (PoolActor pid=110438, ip=10.42.6.149)
# (PoolActor pid=110438, ip=10.42.6.149)   Distribution of IQR for 'prob_exceed_100':
# (PoolActor pid=110438, ip=10.42.6.149)     min=0.0000, median=0.0000, max=0.7454
# (PoolActor pid=110438, ip=10.42.6.149)
# (PoolActor pid=110438, ip=10.42.6.149) [Training Regression Models]
# (PoolActor pid=110438, ip=10.42.6.149) --------------------------------------------------------------------------------
# (PoolActor pid=110438, ip=10.42.6.149)   Skipping groups not in test periods: f0, f1
# (PoolActor pid=110438, ip=10.42.6.149)
# (PoolActor pid=110438, ip=10.42.6.149) Processing LONG TERM models...
# (PoolActor pid=110438, ip=10.42.6.149)   Training default fallback regressor (long)...
# (PoolActor pid=110438, ip=10.42.6.149)     ✓ Default ensemble trained (1 models)
# (PoolActor pid=110438, ip=10.42.6.149)     Total binding samples: 37,142
# (PoolActor pid=110438, ip=10.42.6.149)   Training branch-specific regressors (long)...
# (PoolActor pid=4015463, ip=10.42.7.70)     ✓ Default ensemble trained (1 models)
# (PoolActor pid=4015463, ip=10.42.7.70)     Total samples: 1,593,642
# (PoolActor pid=4015463, ip=10.42.7.70)     Selected features: 6/7
# (PoolActor pid=4015463, ip=10.42.7.70)   Optimizing threshold for default ensemble (long)...
# (PoolActor pid=4082535, ip=10.42.4.173)     ✓ Default ensemble trained (1 models)
# (PoolActor pid=4082535, ip=10.42.4.173)     Total samples: 1,593,642
# (PoolActor pid=4082535, ip=10.42.4.173)     Selected features: 6/7
# (PoolActor pid=4082535, ip=10.42.4.173)   Optimizing threshold for default ensemble (long)...
# (PoolActor pid=4015463, ip=10.42.7.70)     ✓ Optimal threshold: 0.017 (F-beta=0.990)
# (PoolActor pid=4015463, ip=10.42.7.70)   Training branch-specific classifiers (long)...
# (PoolActor pid=4082535, ip=10.42.4.173)     ✓ Optimal threshold: 0.017 (F-beta=0.990)
# (PoolActor pid=4082535, ip=10.42.4.173)   Training branch-specific classifiers (long)...
# (PoolActor pid=4067979, ip=10.42.8.15)     ✓ Trained 776 branch models (skipped 4561)
# (PoolActor pid=4067979, ip=10.42.8.15)
# (PoolActor pid=4067979, ip=10.42.8.15) ✓ Regression Training Complete
# (PoolActor pid=4067979, ip=10.42.8.15)
# (PoolActor pid=4067979, ip=10.42.8.15) ================================================================================
# (PoolActor pid=4067979, ip=10.42.8.15) FALLBACK MONITORING STATISTICS
# (PoolActor pid=4067979, ip=10.42.8.15) ================================================================================
# (PoolActor pid=4067979, ip=10.42.8.15)
# (PoolActor pid=4067979, ip=10.42.8.15) [F0]
# (PoolActor pid=4067979, ip=10.42.8.15)   Classification Fallback Rate: 0/430 (0.00%)
# (PoolActor pid=4067979, ip=10.42.8.15)   Regression Fallback Rate:     0/776 (0.00%)
# (PoolActor pid=4067979, ip=10.42.8.15)
# (PoolActor pid=4067979, ip=10.42.8.15) [F1]
# (PoolActor pid=4067979, ip=10.42.8.15)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=4067979, ip=10.42.8.15)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=4067979, ip=10.42.8.15)
# (PoolActor pid=4067979, ip=10.42.8.15) [LONG]
# (PoolActor pid=4067979, ip=10.42.8.15)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=4067979, ip=10.42.8.15)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=4067979, ip=10.42.8.15)
# (PoolActor pid=4067979, ip=10.42.8.15) [STEP 6: Making Predictions for Auction Month 2026-01]
# (PoolActor pid=4067979, ip=10.42.8.15)   Predicting for Market Month: 2026-01
# (PoolActor pid=4003447, ip=10.42.0.182)     ✓ Trained 413 branch models (skipped 4820)
# (PoolActor pid=4003447, ip=10.42.0.182)
# (PoolActor pid=4003447, ip=10.42.0.182) ✓ Classification Training Complete
# (PoolActor pid=4003447, ip=10.42.0.182)
# (PoolActor pid=4003447, ip=10.42.0.182) ================================================================================
# (PoolActor pid=4003447, ip=10.42.0.182) FALLBACK MONITORING STATISTICS
# (PoolActor pid=4003447, ip=10.42.0.182) ================================================================================
# (PoolActor pid=4003447, ip=10.42.0.182)
# (PoolActor pid=4003447, ip=10.42.0.182) [F0]
# (PoolActor pid=4003447, ip=10.42.0.182)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=4003447, ip=10.42.0.182)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=4003447, ip=10.42.0.182)
# (PoolActor pid=4003447, ip=10.42.0.182) [F1]
# (PoolActor pid=4003447, ip=10.42.0.182)   Classification Fallback Rate: 0/413 (0.00%)
# (PoolActor pid=4003447, ip=10.42.0.182)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=4003447, ip=10.42.0.182)
# (PoolActor pid=4003447, ip=10.42.0.182) [LONG]
# (PoolActor pid=4003447, ip=10.42.0.182)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=4003447, ip=10.42.0.182)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=4003447, ip=10.42.0.182)
# (PoolActor pid=4003447, ip=10.42.0.182) [STEP 5: Training Regressors for Auction Month 2026-01]
# (PoolActor pid=4003447, ip=10.42.0.182)
# (PoolActor pid=4003447, ip=10.42.0.182) [Characterizing Never-Binding Branches for F1]
# (PoolActor pid=4003447, ip=10.42.0.182)   Detection Features: ['prob_exceed_100', 'prob_exceed_95']
# (PoolActor pid=4003447, ip=10.42.0.182)   Probability Features: ['prob_exceed_100', 'prob_exceed_95', 'density_skewness']
# (PoolActor pid=4003447, ip=10.42.0.182) --------------------------------------------------------------------------------
# (PoolActor pid=110438, ip=10.42.6.149)     ✓ Trained 544 branch models (skipped 4710)
# (PoolActor pid=110438, ip=10.42.6.149)
# (PoolActor pid=110438, ip=10.42.6.149) ✓ Regression Training Complete
# (PoolActor pid=110438, ip=10.42.6.149)
# (PoolActor pid=110438, ip=10.42.6.149) ================================================================================
# (PoolActor pid=110438, ip=10.42.6.149) FALLBACK MONITORING STATISTICS
# (PoolActor pid=110438, ip=10.42.6.149) ================================================================================
# (PoolActor pid=110438, ip=10.42.6.149)
# (PoolActor pid=110438, ip=10.42.6.149) [F0]
# (PoolActor pid=110438, ip=10.42.6.149)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=110438, ip=10.42.6.149)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=110438, ip=10.42.6.149)
# (PoolActor pid=110438, ip=10.42.6.149) [F1]
# (PoolActor pid=110438, ip=10.42.6.149)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=110438, ip=10.42.6.149)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=110438, ip=10.42.6.149)
# (PoolActor pid=110438, ip=10.42.6.149) [LONG]
# (PoolActor pid=110438, ip=10.42.6.149)   Classification Fallback Rate: 0/387 (0.00%)
# (PoolActor pid=110438, ip=10.42.6.149)   Regression Fallback Rate:     0/544 (0.00%)
# (PoolActor pid=110438, ip=10.42.6.149)
# (PoolActor pid=110438, ip=10.42.6.149) [STEP 6: Making Predictions for Auction Month 2026-01]
# (PoolActor pid=110438, ip=10.42.6.149)   Predicting for Market Month: 2026-05
# (PoolActor pid=4003447, ip=10.42.0.182) Analyzing 4,455 branches for never-binding patterns...
# (PoolActor pid=4082535, ip=10.42.4.173)     ✓ Trained 383 branch models (skipped 4797)
# (PoolActor pid=4082535, ip=10.42.4.173)
# (PoolActor pid=4082535, ip=10.42.4.173) ✓ Classification Training Complete
# (PoolActor pid=4082535, ip=10.42.4.173)
# (PoolActor pid=4082535, ip=10.42.4.173) ================================================================================
# (PoolActor pid=4082535, ip=10.42.4.173) FALLBACK MONITORING STATISTICS
# (PoolActor pid=4082535, ip=10.42.4.173) ================================================================================
# (PoolActor pid=4082535, ip=10.42.4.173)
# (PoolActor pid=4082535, ip=10.42.4.173) [F0]
# (PoolActor pid=4082535, ip=10.42.4.173)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=4082535, ip=10.42.4.173)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=4082535, ip=10.42.4.173)
# (PoolActor pid=4082535, ip=10.42.4.173) [F1]
# (PoolActor pid=4082535, ip=10.42.4.173)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=4082535, ip=10.42.4.173)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=4082535, ip=10.42.4.173)
# (PoolActor pid=4082535, ip=10.42.4.173) [LONG]
# (PoolActor pid=4082535, ip=10.42.4.173)   Classification Fallback Rate: 0/383 (0.00%)
# (PoolActor pid=4082535, ip=10.42.4.173)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=4082535, ip=10.42.4.173)
# (PoolActor pid=4082535, ip=10.42.4.173) [STEP 5: Training Regressors for Auction Month 2026-01]
# (PoolActor pid=4082535, ip=10.42.4.173)
# (PoolActor pid=4082535, ip=10.42.4.173) [Characterizing Never-Binding Branches for LONG]
# (PoolActor pid=4082535, ip=10.42.4.173)   Detection Features: ['prob_exceed_100', 'prob_exceed_95']
# (PoolActor pid=4082535, ip=10.42.4.173)   Probability Features: ['prob_exceed_100', 'prob_exceed_95', 'density_skewness']
# (PoolActor pid=4082535, ip=10.42.4.173) --------------------------------------------------------------------------------
# (PoolActor pid=4003447, ip=10.42.0.182)
# (PoolActor pid=4003447, ip=10.42.0.182) ✓ Never-Binding Branches Identified (f1): 4,116
# (PoolActor pid=4003447, ip=10.42.0.182)
# (PoolActor pid=4003447, ip=10.42.0.182)   Example Flow Statistics for 'prob_exceed_95' (first 5 branches):
# (PoolActor pid=4003447, ip=10.42.0.182)     0304           1                             : mean=0.0002, P95=0.0022, IQR=0.0001
# (PoolActor pid=4003447, ip=10.42.0.182)     0321X          1                             : mean=0.0067, P95=0.0245, IQR=0.0051
# (PoolActor pid=4003447, ip=10.42.0.182)     0621           1                             : mean=0.0005, P95=0.0000, IQR=0.0000
# (PoolActor pid=4003447, ip=10.42.0.182)     0622           1                             : mean=0.0695, P95=0.3501, IQR=0.0021
# (PoolActor pid=4003447, ip=10.42.0.182)     0624           1                             : mean=0.0000, P95=0.0000, IQR=0.0000
# (PoolActor pid=4003447, ip=10.42.0.182)
# (PoolActor pid=4003447, ip=10.42.0.182)   Distribution of IQR for 'prob_exceed_95':
# (PoolActor pid=4003447, ip=10.42.0.182)     min=0.0000, median=0.0000, max=0.8617
# (PoolActor pid=4003447, ip=10.42.0.182)
# (PoolActor pid=4003447, ip=10.42.0.182) [Training Regression Models]
# (PoolActor pid=4003447, ip=10.42.0.182) --------------------------------------------------------------------------------
# (PoolActor pid=4003447, ip=10.42.0.182)   Skipping groups not in test periods: f0, long
# (PoolActor pid=4003447, ip=10.42.0.182)
# (PoolActor pid=4003447, ip=10.42.0.182) Processing F1 TERM models...
# (PoolActor pid=4003447, ip=10.42.0.182)   Training default fallback regressor (f1)...
# (PoolActor pid=4082535, ip=10.42.4.173) Analyzing 4,419 branches for never-binding patterns...
# (PoolActor pid=4003447, ip=10.42.0.182)     ✓ Default ensemble trained (1 models)
# (PoolActor pid=4003447, ip=10.42.0.182)     Total binding samples: 24,670
# (PoolActor pid=4003447, ip=10.42.0.182)   Training branch-specific regressors (f1)...
# (PoolActor pid=4015463, ip=10.42.7.70)     ✓ Trained 388 branch models (skipped 4848)
# (PoolActor pid=4015463, ip=10.42.7.70)
# (PoolActor pid=4015463, ip=10.42.7.70) ✓ Classification Training Complete
# (PoolActor pid=4015463, ip=10.42.7.70)
# (PoolActor pid=4015463, ip=10.42.7.70) ================================================================================
# (PoolActor pid=4015463, ip=10.42.7.70) FALLBACK MONITORING STATISTICS
# (PoolActor pid=4015463, ip=10.42.7.70) ================================================================================
# (PoolActor pid=4015463, ip=10.42.7.70)
# (PoolActor pid=4015463, ip=10.42.7.70) [F0]
# (PoolActor pid=4015463, ip=10.42.7.70)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=4015463, ip=10.42.7.70)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=4015463, ip=10.42.7.70)
# (PoolActor pid=4015463, ip=10.42.7.70) [F1]
# (PoolActor pid=4015463, ip=10.42.7.70)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=4015463, ip=10.42.7.70)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=4015463, ip=10.42.7.70)
# (PoolActor pid=4015463, ip=10.42.7.70) [LONG]
# (PoolActor pid=4015463, ip=10.42.7.70)   Classification Fallback Rate: 0/388 (0.00%)
# (PoolActor pid=4015463, ip=10.42.7.70)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=4015463, ip=10.42.7.70)
# (PoolActor pid=4015463, ip=10.42.7.70) [STEP 5: Training Regressors for Auction Month 2026-01]
# (PoolActor pid=4015463, ip=10.42.7.70)
# (PoolActor pid=4015463, ip=10.42.7.70) [Characterizing Never-Binding Branches for LONG]
# (PoolActor pid=4015463, ip=10.42.7.70)   Detection Features: ['prob_exceed_100', 'prob_exceed_95']
# (PoolActor pid=4015463, ip=10.42.7.70)   Probability Features: ['prob_exceed_100', 'prob_exceed_95', 'density_skewness']
# (PoolActor pid=4015463, ip=10.42.7.70) --------------------------------------------------------------------------------
# (PoolActor pid=4015463, ip=10.42.7.70) Analyzing 4,419 branches for never-binding patterns...
# (PoolActor pid=4082535, ip=10.42.4.173)
# (PoolActor pid=4082535, ip=10.42.4.173) ✓ Never-Binding Branches Identified (long): 4,099
# (PoolActor pid=4082535, ip=10.42.4.173)
# (PoolActor pid=4082535, ip=10.42.4.173)   Example Flow Statistics for 'density_skewness' (first 5 branches):
# (PoolActor pid=4082535, ip=10.42.4.173)     0304           1                             : mean=0.7632, P95=1.4518, IQR=0.5347
# (PoolActor pid=4082535, ip=10.42.4.173)     0321X          1                             : mean=0.0713, P95=0.3841, IQR=0.1953
# (PoolActor pid=4082535, ip=10.42.4.173)     0621           1                             : mean=-0.4469, P95=0.2558, IQR=0.6836
# (PoolActor pid=4082535, ip=10.42.4.173)     0622           1                             : mean=-0.4506, P95=0.2551, IQR=0.6796
# (PoolActor pid=4082535, ip=10.42.4.173)     0624           1                             : mean=0.0821, P95=0.2714, IQR=0.1706
# (PoolActor pid=4082535, ip=10.42.4.173)
# (PoolActor pid=4082535, ip=10.42.4.173)   Distribution of IQR for 'density_skewness':
# (PoolActor pid=4082535, ip=10.42.4.173)     min=0.0000, median=0.2935, max=5487750.2122
# (PoolActor pid=4082535, ip=10.42.4.173)
# (PoolActor pid=4082535, ip=10.42.4.173) [Training Regression Models]
# (PoolActor pid=4082535, ip=10.42.4.173) --------------------------------------------------------------------------------
# (PoolActor pid=4082535, ip=10.42.4.173)   Skipping groups not in test periods: f0, f1
# (PoolActor pid=4082535, ip=10.42.4.173)
# (PoolActor pid=4082535, ip=10.42.4.173) Processing LONG TERM models...
# (PoolActor pid=4082535, ip=10.42.4.173)   Training default fallback regressor (long)...
# (PoolActor pid=4082535, ip=10.42.4.173)     ✓ Default ensemble trained (1 models)
# (PoolActor pid=4082535, ip=10.42.4.173)     Total binding samples: 37,142
# (PoolActor pid=4082535, ip=10.42.4.173)   Training branch-specific regressors (long)...
# (PoolActor pid=4067979, ip=10.42.8.15)   Saved final results to: /opt/temp/tmp/pw_data/spice6/prod_f0p_model_miso/ml_pred/auction_month=2026-01/market_month=2026-01/class_type=onpeak
# (PoolActor pid=4067979, ip=10.42.8.15)
# (PoolActor pid=4067979, ip=10.42.8.15) ✅ Auction Month 2026-01 Complete (1 predictions)
# (PoolActor pid=4067979, ip=10.42.8.15) [Timing] _process_auction_month for 2026-01 took 98.41 seconds
# (PoolActor pid=4015463, ip=10.42.7.70)
# (PoolActor pid=4015463, ip=10.42.7.70) ✓ Never-Binding Branches Identified (long): 4,099
# (PoolActor pid=4015463, ip=10.42.7.70)
# (PoolActor pid=4015463, ip=10.42.7.70)   Example Flow Statistics for 'prob_exceed_100' (first 5 branches):
# (PoolActor pid=4015463, ip=10.42.7.70)     0304           1                             : mean=0.0000, P95=0.0000, IQR=0.0000
# (PoolActor pid=4015463, ip=10.42.7.70)     0321X          1                             : mean=0.0022, P95=0.0092, IQR=0.0016
# (PoolActor pid=4015463, ip=10.42.7.70)     0621           1                             : mean=0.0004, P95=0.0000, IQR=0.0000
# (PoolActor pid=4015463, ip=10.42.7.70)     0622           1                             : mean=0.0474, P95=0.2806, IQR=0.0093
# (PoolActor pid=4015463, ip=10.42.7.70)     0624           1                             : mean=0.0000, P95=0.0000, IQR=0.0000
# (PoolActor pid=4015463, ip=10.42.7.70)
# (PoolActor pid=4015463, ip=10.42.7.70)   Distribution of IQR for 'prob_exceed_100':
# (PoolActor pid=4015463, ip=10.42.7.70)     min=0.0000, median=0.0000, max=0.7454
# (PoolActor pid=4015463, ip=10.42.7.70)
# (PoolActor pid=4015463, ip=10.42.7.70) [Training Regression Models]
# (PoolActor pid=4015463, ip=10.42.7.70) --------------------------------------------------------------------------------
# (PoolActor pid=4015463, ip=10.42.7.70)   Skipping groups not in test periods: f0, f1
# (PoolActor pid=4015463, ip=10.42.7.70)
# (PoolActor pid=4015463, ip=10.42.7.70) Processing LONG TERM models...
# (PoolActor pid=4015463, ip=10.42.7.70)   Training default fallback regressor (long)...
# (PoolActor pid=4015463, ip=10.42.7.70)     ✓ Default ensemble trained (1 models)
# (PoolActor pid=4015463, ip=10.42.7.70)     Total binding samples: 37,142
# (PoolActor pid=4015463, ip=10.42.7.70)   Training branch-specific regressors (long)...
# (PoolActor pid=110438, ip=10.42.6.149)   Saved final results to: /opt/temp/tmp/pw_data/spice6/prod_f0p_model_miso/ml_pred/auction_month=2026-01/market_month=2026-05/class_type=onpeak
# (PoolActor pid=110438, ip=10.42.6.149)
# (PoolActor pid=110438, ip=10.42.6.149) ✅ Auction Month 2026-01 Complete (1 predictions)
# (PoolActor pid=110438, ip=10.42.6.149) [Timing] _process_auction_month for 2026-01 took 111.97 seconds
# (PoolActor pid=4003447, ip=10.42.0.182)     ✓ Trained 655 branch models (skipped 4578)
# (PoolActor pid=4003447, ip=10.42.0.182)
# (PoolActor pid=4003447, ip=10.42.0.182) ✓ Regression Training Complete
# (PoolActor pid=4003447, ip=10.42.0.182)
# (PoolActor pid=4003447, ip=10.42.0.182) ================================================================================
# (PoolActor pid=4003447, ip=10.42.0.182) FALLBACK MONITORING STATISTICS
# (PoolActor pid=4003447, ip=10.42.0.182) ================================================================================
# (PoolActor pid=4003447, ip=10.42.0.182)
# (PoolActor pid=4003447, ip=10.42.0.182) [F0]
# (PoolActor pid=4003447, ip=10.42.0.182)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=4003447, ip=10.42.0.182)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=4003447, ip=10.42.0.182)
# (PoolActor pid=4003447, ip=10.42.0.182) [F1]
# (PoolActor pid=4003447, ip=10.42.0.182)   Classification Fallback Rate: 0/413 (0.00%)
# (PoolActor pid=4003447, ip=10.42.0.182)   Regression Fallback Rate:     0/655 (0.00%)
# (PoolActor pid=4003447, ip=10.42.0.182)
# (PoolActor pid=4003447, ip=10.42.0.182) [LONG]
# (PoolActor pid=4003447, ip=10.42.0.182)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=4003447, ip=10.42.0.182)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=4003447, ip=10.42.0.182)
# (PoolActor pid=4003447, ip=10.42.0.182) [STEP 6: Making Predictions for Auction Month 2026-01]
# (PoolActor pid=4003447, ip=10.42.0.182)   Predicting for Market Month: 2026-02
# (PoolActor pid=4082535, ip=10.42.4.173)     ✓ Trained 533 branch models (skipped 4647)
# (PoolActor pid=4082535, ip=10.42.4.173)
# (PoolActor pid=4082535, ip=10.42.4.173) ✓ Regression Training Complete
# (PoolActor pid=4082535, ip=10.42.4.173)
# (PoolActor pid=4082535, ip=10.42.4.173) ================================================================================
# (PoolActor pid=4082535, ip=10.42.4.173) FALLBACK MONITORING STATISTICS
# (PoolActor pid=4082535, ip=10.42.4.173) ================================================================================
# (PoolActor pid=4082535, ip=10.42.4.173)
# (PoolActor pid=4082535, ip=10.42.4.173) [F0]
# (PoolActor pid=4082535, ip=10.42.4.173)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=4082535, ip=10.42.4.173)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=4082535, ip=10.42.4.173)
# (PoolActor pid=4082535, ip=10.42.4.173) [F1]
# (PoolActor pid=4082535, ip=10.42.4.173)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=4082535, ip=10.42.4.173)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=4082535, ip=10.42.4.173)
# (PoolActor pid=4082535, ip=10.42.4.173) [LONG]
# (PoolActor pid=4082535, ip=10.42.4.173)   Classification Fallback Rate: 0/383 (0.00%)
# (PoolActor pid=4082535, ip=10.42.4.173)   Regression Fallback Rate:     0/533 (0.00%)
# (PoolActor pid=4082535, ip=10.42.4.173)
# (PoolActor pid=4082535, ip=10.42.4.173) [STEP 6: Making Predictions for Auction Month 2026-01]
# (PoolActor pid=4082535, ip=10.42.4.173)   Predicting for Market Month: 2026-04
# (PoolActor pid=4015463, ip=10.42.7.70)     ✓ Trained 537 branch models (skipped 4699)
# (PoolActor pid=4015463, ip=10.42.7.70)
# (PoolActor pid=4015463, ip=10.42.7.70) ✓ Regression Training Complete
# (PoolActor pid=4015463, ip=10.42.7.70)
# (PoolActor pid=4015463, ip=10.42.7.70) ================================================================================
# (PoolActor pid=4015463, ip=10.42.7.70) FALLBACK MONITORING STATISTICS
# (PoolActor pid=4015463, ip=10.42.7.70) ================================================================================
# (PoolActor pid=4015463, ip=10.42.7.70)
# (PoolActor pid=4015463, ip=10.42.7.70) [F0]
# (PoolActor pid=4015463, ip=10.42.7.70)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=4015463, ip=10.42.7.70)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=4015463, ip=10.42.7.70)
# (PoolActor pid=4015463, ip=10.42.7.70) [F1]
# (PoolActor pid=4015463, ip=10.42.7.70)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=4015463, ip=10.42.7.70)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=4015463, ip=10.42.7.70)
# (PoolActor pid=4015463, ip=10.42.7.70) [LONG]
# (PoolActor pid=4015463, ip=10.42.7.70)   Classification Fallback Rate: 0/388 (0.00%)
# (PoolActor pid=4015463, ip=10.42.7.70)   Regression Fallback Rate:     0/537 (0.00%)
# (PoolActor pid=4015463, ip=10.42.7.70)
# (PoolActor pid=4015463, ip=10.42.7.70) [STEP 6: Making Predictions for Auction Month 2026-01]
# (PoolActor pid=4015463, ip=10.42.7.70)   Predicting for Market Month: 2026-03
# (PoolActor pid=4082535, ip=10.42.4.173)   Saved final results to: /opt/temp/tmp/pw_data/spice6/prod_f0p_model_miso/ml_pred/auction_month=2026-01/market_month=2026-04/class_type=onpeak
# (PoolActor pid=4082535, ip=10.42.4.173)
# (PoolActor pid=4082535, ip=10.42.4.173) ✅ Auction Month 2026-01 Complete (1 predictions)
# (PoolActor pid=4082535, ip=10.42.4.173) [Timing] _process_auction_month for 2026-01 took 151.54 seconds
# (PoolActor pid=4003447, ip=10.42.0.182)   Saved final results to: /opt/temp/tmp/pw_data/spice6/prod_f0p_model_miso/ml_pred/auction_month=2026-01/market_month=2026-02/class_type=onpeak
# (PoolActor pid=4003447, ip=10.42.0.182)
# (PoolActor pid=4003447, ip=10.42.0.182) ✅ Auction Month 2026-01 Complete (1 predictions)
# (PoolActor pid=4003447, ip=10.42.0.182) [Timing] _process_auction_month for 2026-01 took 152.81 seconds
# (PoolActor pid=4015463, ip=10.42.7.70)   Saved final results to: /opt/temp/tmp/pw_data/spice6/prod_f0p_model_miso/ml_pred/auction_month=2026-01/market_month=2026-03/class_type=onpeak
# (PoolActor pid=4015463, ip=10.42.7.70)
# (PoolActor pid=4015463, ip=10.42.7.70) ✅ Auction Month 2026-01 Complete (1 predictions)
# (PoolActor pid=4015463, ip=10.42.7.70) [Timing] _process_auction_month for 2026-01 took 154.99 seconds
#
# ================================================================================
# ✅ ALL AUCTION MONTHS TRAINING COMPLETE!
# ================================================================================
#
# ================================================================================
# [COMBINING RESULTS ACROSS ALL PERIODS]
# ================================================================================
#
# ✓ Results Combined
#   Total samples (per-outage): 702,852
#   Total unique constraints (monthly): 73,974
#   Date range: 2026-01-01 to 2026-05-31
#
# [ANALYZING COMBINED RESULTS]
#   Skipping metrics calculation (no labels available)
#
# ================================================================================
# ✅ PIPELINE COMPLETE!
# ================================================================================

# %%
results_per_outage, final_results, metrics, training_res, models = pipeline.run(
    test_periods=test_periods,
    # test_periods=test_periods[2:3],
    verbose=True,
    use_parallel=True,
    n_jobs=22,
    output_dir='/opt/temp/tmp/pw_data/spice6/prod_f0p_model_miso/ml_pred/',
    # output_dir=None,
    refresh=True,
    class_type='offpeak',
    # branch_name='XRDSGRANC11_1  1',
    branch_name=None,
)
# Out:
# ================================================================================
# SHADOW PRICE PREDICTION PIPELINE - PARALLEL PER-AUCTION-MONTH MODE
# ================================================================================
# Total Test Periods: 5
# Unique Auction Months: 5
#
#   Auction: 2026-01 → 1 market month(s)
#     - Market: 2026-01
#   Auction: 2026-01 → 1 market month(s)
#     - Market: 2026-02
#   Auction: 2026-01 → 1 market month(s)
#     - Market: 2026-03
#   Auction: 2026-01 → 1 market month(s)
#     - Market: 2026-04
#   Auction: 2026-01 → 1 market month(s)
#     - Market: 2026-05
# Class Type: offpeak
#
# 🚀 Using Ray parallel processing for 5 auction months
#    Workers: 22
#
# ================================================================================
# [PARALLEL PROCESSING: Training and Predicting for All Auction Months]
# ================================================================================
#   0%|          | 0/5 [00:00<?, ?it/s]
# (PoolActor pid=4068090, ip=10.42.8.15)
# (PoolActor pid=4068090, ip=10.42.8.15) ================================================================================
# (PoolActor pid=4068090, ip=10.42.8.15) [Processing Auction Month: 2026-01]
# (PoolActor pid=4068090, ip=10.42.8.15)   Market Months: 1
# (PoolActor pid=4068090, ip=10.42.8.15)     - 2026-02
# (PoolActor pid=4068090, ip=10.42.8.15) ================================================================================
# (PoolActor pid=4069611, ip=10.42.9.131)
# (PoolActor pid=4069611, ip=10.42.9.131) ================================================================================
# (PoolActor pid=4069611, ip=10.42.9.131) [Processing Auction Month: 2026-01]
# (PoolActor pid=4069611, ip=10.42.9.131)   Market Months: 1
# (PoolActor pid=4069611, ip=10.42.9.131)     - 2026-01
# (PoolActor pid=4069611, ip=10.42.9.131) ================================================================================
# (PoolActor pid=4015574, ip=10.42.7.70)
# (PoolActor pid=4015574, ip=10.42.7.70) ================================================================================
# (PoolActor pid=4015574, ip=10.42.7.70) [Processing Auction Month: 2026-01]
# (PoolActor pid=4015574, ip=10.42.7.70)   Market Months: 1
# (PoolActor pid=4015574, ip=10.42.7.70)     - 2026-04
# (PoolActor pid=4015574, ip=10.42.7.70) ================================================================================
# (PoolActor pid=4082646, ip=10.42.4.173)
# (PoolActor pid=4082646, ip=10.42.4.173) ================================================================================
# (PoolActor pid=4082646, ip=10.42.4.173) [Processing Auction Month: 2026-01]
# (PoolActor pid=4082646, ip=10.42.4.173)   Market Months: 1
# (PoolActor pid=4082646, ip=10.42.4.173)     - 2026-05
# (PoolActor pid=4082646, ip=10.42.4.173) ================================================================================
# (PoolActor pid=4003557, ip=10.42.0.182)
# (PoolActor pid=4003557, ip=10.42.0.182) ================================================================================
# (PoolActor pid=4003557, ip=10.42.0.182) [Processing Auction Month: 2026-01]
# (PoolActor pid=4003557, ip=10.42.0.182)   Market Months: 1
# (PoolActor pid=4003557, ip=10.42.0.182)     - 2026-03
# (PoolActor pid=4003557, ip=10.42.0.182) ================================================================================
# (PoolActor pid=4068090, ip=10.42.8.15) 25-12-10 17:08:29 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=4068090, ip=10.42.8.15) 25-12-10 17:08:29 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=4068090, ip=10.42.8.15) 25-12-10 17:08:29 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=4068090, ip=10.42.8.15) 25-12-10 17:08:29 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=4069611, ip=10.42.9.131) 25-12-10 17:08:29 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=4069611, ip=10.42.9.131) 25-12-10 17:08:29 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=4069611, ip=10.42.9.131) 25-12-10 17:08:29 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=4069611, ip=10.42.9.131) 25-12-10 17:08:29 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=4015574, ip=10.42.7.70) 25-12-10 17:08:29 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=4015574, ip=10.42.7.70) 25-12-10 17:08:29 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=4015574, ip=10.42.7.70) 25-12-10 17:08:29 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=4015574, ip=10.42.7.70) 25-12-10 17:08:29 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=4082646, ip=10.42.4.173) 25-12-10 17:08:29 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=4082646, ip=10.42.4.173) 25-12-10 17:08:29 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=4082646, ip=10.42.4.173) 25-12-10 17:08:29 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=4082646, ip=10.42.4.173) 25-12-10 17:08:29 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=4003557, ip=10.42.0.182) 25-12-10 17:08:29 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=4003557, ip=10.42.0.182) 25-12-10 17:08:29 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=4003557, ip=10.42.0.182) 25-12-10 17:08:29 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=4003557, ip=10.42.0.182) 25-12-10 17:08:29 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=4068090, ip=10.42.8.15)
# (PoolActor pid=4068090, ip=10.42.8.15) [STEP 1: Training Period Calculation]
# (PoolActor pid=4068090, ip=10.42.8.15)   Training Range: 2025-01 to 2025-12
# (PoolActor pid=4068090, ip=10.42.8.15)
# (PoolActor pid=4068090, ip=10.42.8.15) [STEP 2: Loading Training Data]
# (PoolActor pid=4068090, ip=10.42.8.15)   Loading training data for 2025-01 (Types: ['f1'])...
# (PoolActor pid=4069611, ip=10.42.9.131)
# (PoolActor pid=4069611, ip=10.42.9.131) [STEP 1: Training Period Calculation]
# (PoolActor pid=4069611, ip=10.42.9.131)   Training Range: 2025-01 to 2025-12
# (PoolActor pid=4069611, ip=10.42.9.131)
# (PoolActor pid=4069611, ip=10.42.9.131) [STEP 2: Loading Training Data]
# (PoolActor pid=4069611, ip=10.42.9.131)   Loading training data for 2025-01 (Types: ['f0'])...
# (PoolActor pid=4003557, ip=10.42.0.182)
# (PoolActor pid=4003557, ip=10.42.0.182) [STEP 1: Training Period Calculation]
# (PoolActor pid=4003557, ip=10.42.0.182)   Training Range: 2025-01 to 2025-12
# (PoolActor pid=4003557, ip=10.42.0.182)
# (PoolActor pid=4003557, ip=10.42.0.182) [STEP 2: Loading Training Data]
# (PoolActor pid=4003557, ip=10.42.0.182)   Loading training data for 2025-01 (Types: ['q4'])...
# (PoolActor pid=4015574, ip=10.42.7.70)
# (PoolActor pid=4015574, ip=10.42.7.70) [STEP 1: Training Period Calculation]
# (PoolActor pid=4015574, ip=10.42.7.70)   Training Range: 2025-01 to 2025-12
# (PoolActor pid=4015574, ip=10.42.7.70)
# (PoolActor pid=4015574, ip=10.42.7.70) [STEP 2: Loading Training Data]
# (PoolActor pid=4015574, ip=10.42.7.70)   Loading training data for 2025-01 (Types: ['q4'])...
# (PoolActor pid=4082646, ip=10.42.4.173)
# (PoolActor pid=4082646, ip=10.42.4.173) [STEP 1: Training Period Calculation]
# (PoolActor pid=4082646, ip=10.42.4.173)   Training Range: 2025-01 to 2025-12
# (PoolActor pid=4082646, ip=10.42.4.173)
# (PoolActor pid=4082646, ip=10.42.4.173) [STEP 2: Loading Training Data]
# (PoolActor pid=4082646, ip=10.42.4.173)   Loading training data for 2025-01 (Types: ['q4'])...
# (PoolActor pid=4068090, ip=10.42.8.15)   Loading training data for 2025-02 (Types: ['f1'])...
# (PoolActor pid=4069611, ip=10.42.9.131)   Loading training data for 2025-02 (Types: ['f0'])...
# (PoolActor pid=4068090, ip=10.42.8.15)   Loading training data for 2025-03 (Types: ['f1'])...
# (PoolActor pid=4069611, ip=10.42.9.131)   Loading training data for 2025-03 (Types: ['f0'])...
# (PoolActor pid=4068090, ip=10.42.8.15)   Loading training data for 2025-04 (Types: ['f1'])...
# (PoolActor pid=4069611, ip=10.42.9.131)   Loading training data for 2025-04 (Types: ['f0'])...
# (PoolActor pid=4068090, ip=10.42.8.15)   Skipping 2025-05: No required period types available.
# (PoolActor pid=4068090, ip=10.42.8.15)   Skipping 2025-06: No required period types available.
# (PoolActor pid=4068090, ip=10.42.8.15)   Loading training data for 2025-07 (Types: ['f1'])...
# (PoolActor pid=4082646, ip=10.42.4.173)   Loading training data for 2025-02 (Types: ['f2', 'f3'])...
# (PoolActor pid=4003557, ip=10.42.0.182)   Loading training data for 2025-02 (Types: ['f2', 'f3'])...
# (PoolActor pid=4015574, ip=10.42.7.70)   Loading training data for 2025-02 (Types: ['f2', 'f3'])...
# (PoolActor pid=4068090, ip=10.42.8.15)   Loading training data for 2025-08 (Types: ['f1'])...
# (PoolActor pid=4069611, ip=10.42.9.131)   Loading training data for 2025-05 (Types: ['f0'])...
# (PoolActor pid=4068090, ip=10.42.8.15)   Loading training data for 2025-09 (Types: ['f1'])...
# (PoolActor pid=4069611, ip=10.42.9.131)   Loading training data for 2025-06 (Types: ['f0'])...
# (PoolActor pid=4082646, ip=10.42.4.173)   Loading training data for 2025-03 (Types: ['f2'])...
# (PoolActor pid=4068090, ip=10.42.8.15)   Loading training data for 2025-10 (Types: ['f1'])...
# (PoolActor pid=4003557, ip=10.42.0.182)   Loading training data for 2025-03 (Types: ['f2'])...
# (PoolActor pid=4015574, ip=10.42.7.70)   Loading training data for 2025-03 (Types: ['f2'])...
# (PoolActor pid=4069611, ip=10.42.9.131)   Loading training data for 2025-07 (Types: ['f0'])...
# (PoolActor pid=4068090, ip=10.42.8.15)   Loading training data for 2025-11 (Types: ['f1'])...
# (PoolActor pid=4068090, ip=10.42.8.15)     Skipping future month: 2025-12
# (PoolActor pid=4068090, ip=10.42.8.15)   Applying label modification based on prob_exceed_80 < 1e-05...
# (PoolActor pid=4068090, ip=10.42.8.15)     Modified 572712 labels to 0 where prob_exceed_80 < 1e-05.
# (PoolActor pid=4068090, ip=10.42.8.15)
# (PoolActor pid=4068090, ip=10.42.8.15) [STEP 3: Identifying Target Branches]
# (PoolActor pid=4068090, ip=10.42.8.15)   Identifying target branches from test periods...
# (PoolActor pid=4082646, ip=10.42.4.173)   Skipping 2025-04: No required period types available.
# (PoolActor pid=4082646, ip=10.42.4.173)   Skipping 2025-05: No required period types available.
# (PoolActor pid=4082646, ip=10.42.4.173)   Skipping 2025-06: No required period types available.
# (PoolActor pid=4082646, ip=10.42.4.173)   Loading training data for 2025-07 (Types: ['q2', 'q3', 'q4'])...
# (PoolActor pid=4003557, ip=10.42.0.182)   Skipping 2025-04: No required period types available.
# (PoolActor pid=4003557, ip=10.42.0.182)   Skipping 2025-05: No required period types available.
# (PoolActor pid=4003557, ip=10.42.0.182)   Skipping 2025-06: No required period types available.
# (PoolActor pid=4003557, ip=10.42.0.182)   Loading training data for 2025-07 (Types: ['q2', 'q3', 'q4'])...
# (PoolActor pid=4069611, ip=10.42.9.131)   Loading training data for 2025-08 (Types: ['f0'])...
# (PoolActor pid=4015574, ip=10.42.7.70)   Skipping 2025-04: No required period types available.
# (PoolActor pid=4015574, ip=10.42.7.70)   Skipping 2025-05: No required period types available.
# (PoolActor pid=4015574, ip=10.42.7.70)   Skipping 2025-06: No required period types available.
# (PoolActor pid=4015574, ip=10.42.7.70)   Loading training data for 2025-07 (Types: ['q2', 'q3', 'q4'])...
# (PoolActor pid=4068090, ip=10.42.8.15)   Found 5398 unique branch-flow pairs in test set.
# (PoolActor pid=4068090, ip=10.42.8.15)
# (PoolActor pid=4068090, ip=10.42.8.15) [STEP 4: Training Models for Auction Month 2026-01]
# (PoolActor pid=4068090, ip=10.42.8.15)
# (PoolActor pid=4068090, ip=10.42.8.15) [Training Classification Models + Threshold Optimization]
# (PoolActor pid=4068090, ip=10.42.8.15) --------------------------------------------------------------------------------
# (PoolActor pid=4068090, ip=10.42.8.15)   Skipping groups not in test periods: f0, long
# (PoolActor pid=4068090, ip=10.42.8.15)
# (PoolActor pid=4068090, ip=10.42.8.15) Processing F1 TERM models...
# (PoolActor pid=4068090, ip=10.42.8.15)   Training default fallback classifier (f1)...
# (PoolActor pid=4069611, ip=10.42.9.131)   Loading training data for 2025-09 (Types: ['f0'])...
# (PoolActor pid=4068090, ip=10.42.8.15)     ✓ Default ensemble trained (1 models)
# (PoolActor pid=4068090, ip=10.42.8.15)     Total samples: 1,062,529
# (PoolActor pid=4068090, ip=10.42.8.15)     Selected features: 6/7
# (PoolActor pid=4068090, ip=10.42.8.15)   Optimizing threshold for default ensemble (f1)...
# (PoolActor pid=4068090, ip=10.42.8.15)     ✓ Optimal threshold: 0.015 (F-beta=0.991)
# (PoolActor pid=4068090, ip=10.42.8.15)   Training branch-specific classifiers (f1)...
# (PoolActor pid=4069611, ip=10.42.9.131)   Loading training data for 2025-10 (Types: ['f0'])...
# (PoolActor pid=4082646, ip=10.42.4.173)     Skipping future month: 2025-12
# (PoolActor pid=4082646, ip=10.42.4.173)     Skipping future month: 2026-01
# (PoolActor pid=4082646, ip=10.42.4.173)     Skipping future month: 2026-02
# (PoolActor pid=4082646, ip=10.42.4.173)     Skipping future month: 2026-03
# (PoolActor pid=4082646, ip=10.42.4.173)     Skipping future month: 2026-04
# (PoolActor pid=4082646, ip=10.42.4.173)     Skipping future month: 2026-05
# (PoolActor pid=4082646, ip=10.42.4.173)   Loading training data for 2025-08 (Types: ['f2', 'f3'])...
# (PoolActor pid=4069611, ip=10.42.9.131)   Loading training data for 2025-11 (Types: ['f0'])...
# (PoolActor pid=4003557, ip=10.42.0.182)     Skipping future month: 2025-12
# (PoolActor pid=4003557, ip=10.42.0.182)     Skipping future month: 2026-01
# (PoolActor pid=4003557, ip=10.42.0.182)     Skipping future month: 2026-02
# (PoolActor pid=4003557, ip=10.42.0.182)     Skipping future month: 2026-03
# (PoolActor pid=4003557, ip=10.42.0.182)     Skipping future month: 2026-04
# (PoolActor pid=4003557, ip=10.42.0.182)     Skipping future month: 2026-05
# (PoolActor pid=4003557, ip=10.42.0.182)   Loading training data for 2025-08 (Types: ['f2', 'f3'])...
# (PoolActor pid=4068090, ip=10.42.8.15)     ✓ Trained 381 branch models (skipped 4852)
# (PoolActor pid=4068090, ip=10.42.8.15)
# (PoolActor pid=4068090, ip=10.42.8.15) ✓ Classification Training Complete
# (PoolActor pid=4068090, ip=10.42.8.15)
# (PoolActor pid=4068090, ip=10.42.8.15) ================================================================================
# (PoolActor pid=4068090, ip=10.42.8.15) FALLBACK MONITORING STATISTICS
# (PoolActor pid=4068090, ip=10.42.8.15) ================================================================================
# (PoolActor pid=4068090, ip=10.42.8.15)
# (PoolActor pid=4068090, ip=10.42.8.15) [F0]
# (PoolActor pid=4068090, ip=10.42.8.15)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=4068090, ip=10.42.8.15)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=4068090, ip=10.42.8.15)
# (PoolActor pid=4068090, ip=10.42.8.15) [F1]
# (PoolActor pid=4068090, ip=10.42.8.15)   Classification Fallback Rate: 0/381 (0.00%)
# (PoolActor pid=4068090, ip=10.42.8.15)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=4068090, ip=10.42.8.15)
# (PoolActor pid=4068090, ip=10.42.8.15) [LONG]
# (PoolActor pid=4068090, ip=10.42.8.15)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=4068090, ip=10.42.8.15)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=4068090, ip=10.42.8.15)
# (PoolActor pid=4068090, ip=10.42.8.15) [STEP 5: Training Regressors for Auction Month 2026-01]
# (PoolActor pid=4068090, ip=10.42.8.15)
# (PoolActor pid=4068090, ip=10.42.8.15) [Characterizing Never-Binding Branches for F1]
# (PoolActor pid=4068090, ip=10.42.8.15)   Detection Features: ['prob_exceed_100', 'prob_exceed_95']
# (PoolActor pid=4068090, ip=10.42.8.15)   Probability Features: ['prob_exceed_100', 'prob_exceed_95', 'density_skewness']
# (PoolActor pid=4068090, ip=10.42.8.15) --------------------------------------------------------------------------------
# (PoolActor pid=4015574, ip=10.42.7.70)     Skipping future month: 2025-12
# (PoolActor pid=4015574, ip=10.42.7.70)     Skipping future month: 2026-01
# (PoolActor pid=4015574, ip=10.42.7.70)     Skipping future month: 2026-02
# (PoolActor pid=4015574, ip=10.42.7.70)     Skipping future month: 2026-03
# (PoolActor pid=4015574, ip=10.42.7.70)     Skipping future month: 2026-04
# (PoolActor pid=4015574, ip=10.42.7.70)     Skipping future month: 2026-05
# (PoolActor pid=4015574, ip=10.42.7.70)   Loading training data for 2025-08 (Types: ['f2', 'f3'])...
# (PoolActor pid=4068090, ip=10.42.8.15) Analyzing 4,455 branches for never-binding patterns...
# (PoolActor pid=4069611, ip=10.42.9.131)   Applying label modification based on prob_exceed_80 < 1e-05...
# (PoolActor pid=4069611, ip=10.42.9.131)     Modified 782302 labels to 0 where prob_exceed_80 < 1e-05.
# (PoolActor pid=4069611, ip=10.42.9.131)
# (PoolActor pid=4069611, ip=10.42.9.131) [STEP 3: Identifying Target Branches]
# (PoolActor pid=4069611, ip=10.42.9.131)   Identifying target branches from test periods...
# (PoolActor pid=4068090, ip=10.42.8.15)
# (PoolActor pid=4068090, ip=10.42.8.15) ✓ Never-Binding Branches Identified (f1): 4,155
# (PoolActor pid=4068090, ip=10.42.8.15)
# (PoolActor pid=4068090, ip=10.42.8.15)   Example Flow Statistics for 'density_skewness' (first 5 branches):
# (PoolActor pid=4068090, ip=10.42.8.15)     0304           1                             : mean=0.7016, P95=1.9840, IQR=0.3457
# (PoolActor pid=4068090, ip=10.42.8.15)     0321X          1                             : mean=0.1081, P95=0.9188, IQR=0.2820
# (PoolActor pid=4068090, ip=10.42.8.15)     0621           1                             : mean=-0.5061, P95=0.1377, IQR=0.1893
# (PoolActor pid=4068090, ip=10.42.8.15)     0622           1                             : mean=-0.5168, P95=0.1359, IQR=0.2037
# (PoolActor pid=4068090, ip=10.42.8.15)     0624           1                             : mean=0.0743, P95=0.2977, IQR=0.2033
# (PoolActor pid=4068090, ip=10.42.8.15)
# (PoolActor pid=4068090, ip=10.42.8.15)   Distribution of IQR for 'density_skewness':
# (PoolActor pid=4068090, ip=10.42.8.15)     min=0.0000, median=0.3303, max=719049.5659
# (PoolActor pid=4068090, ip=10.42.8.15)
# (PoolActor pid=4068090, ip=10.42.8.15) [Training Regression Models]
# (PoolActor pid=4068090, ip=10.42.8.15) --------------------------------------------------------------------------------
# (PoolActor pid=4068090, ip=10.42.8.15)   Skipping groups not in test periods: f0, long
# (PoolActor pid=4068090, ip=10.42.8.15)
# (PoolActor pid=4068090, ip=10.42.8.15) Processing F1 TERM models...
# (PoolActor pid=4068090, ip=10.42.8.15)   Training default fallback regressor (f1)...
# (PoolActor pid=4068090, ip=10.42.8.15)     ✓ Default ensemble trained (1 models)
# (PoolActor pid=4068090, ip=10.42.8.15)     Total binding samples: 25,187
# (PoolActor pid=4068090, ip=10.42.8.15)   Training branch-specific regressors (f1)...
# (PoolActor pid=4069611, ip=10.42.9.131)   Found 5439 unique branch-flow pairs in test set.
# (PoolActor pid=4069611, ip=10.42.9.131)
# (PoolActor pid=4069611, ip=10.42.9.131) [STEP 4: Training Models for Auction Month 2026-01]
# (PoolActor pid=4069611, ip=10.42.9.131)
# (PoolActor pid=4069611, ip=10.42.9.131) [Training Classification Models + Threshold Optimization]
# (PoolActor pid=4069611, ip=10.42.9.131) --------------------------------------------------------------------------------
# (PoolActor pid=4069611, ip=10.42.9.131)   Skipping groups not in test periods: f1, long
# (PoolActor pid=4069611, ip=10.42.9.131)
# (PoolActor pid=4069611, ip=10.42.9.131) Processing F0 TERM models...
# (PoolActor pid=4069611, ip=10.42.9.131)   Training default fallback classifier (f0)...
# (PoolActor pid=4082646, ip=10.42.4.173)   Loading training data for 2025-09 (Types: ['f2'])...
# (PoolActor pid=4003557, ip=10.42.0.182)   Loading training data for 2025-09 (Types: ['f2'])...
# (PoolActor pid=4015574, ip=10.42.7.70)   Loading training data for 2025-09 (Types: ['f2'])...
# (PoolActor pid=4082646, ip=10.42.4.173)   Loading training data for 2025-10 (Types: ['q3', 'q4'])...
# (PoolActor pid=4082646, ip=10.42.4.173)     Skipping future month: 2025-12
# (PoolActor pid=4082646, ip=10.42.4.173)     Skipping future month: 2026-01
# (PoolActor pid=4082646, ip=10.42.4.173)     Skipping future month: 2026-02
# (PoolActor pid=4082646, ip=10.42.4.173)     Skipping future month: 2026-03
# (PoolActor pid=4082646, ip=10.42.4.173)     Skipping future month: 2026-04
# (PoolActor pid=4082646, ip=10.42.4.173)     Skipping future month: 2026-05
# (PoolActor pid=4082646, ip=10.42.4.173)   Loading training data for 2025-11 (Types: ['f2', 'f3'])...
# (PoolActor pid=4082646, ip=10.42.4.173)     Skipping future month: 2026-01
# (PoolActor pid=4082646, ip=10.42.4.173)     Skipping future month: 2026-02
# (PoolActor pid=4082646, ip=10.42.4.173)   Applying label modification based on prob_exceed_80 < 1e-05...
# (PoolActor pid=4082646, ip=10.42.4.173)     Modified 870945 labels to 0 where prob_exceed_80 < 1e-05.
# (PoolActor pid=4082646, ip=10.42.4.173)
# (PoolActor pid=4082646, ip=10.42.4.173) [STEP 3: Identifying Target Branches]
# (PoolActor pid=4082646, ip=10.42.4.173)   Identifying target branches from test periods...
# (PoolActor pid=4003557, ip=10.42.0.182)   Loading training data for 2025-10 (Types: ['q3', 'q4'])...
# (PoolActor pid=4003557, ip=10.42.0.182)     Skipping future month: 2025-12
# (PoolActor pid=4003557, ip=10.42.0.182)     Skipping future month: 2026-01
# (PoolActor pid=4003557, ip=10.42.0.182)     Skipping future month: 2026-02
# (PoolActor pid=4003557, ip=10.42.0.182)     Skipping future month: 2026-03
# (PoolActor pid=4003557, ip=10.42.0.182)     Skipping future month: 2026-04
# (PoolActor pid=4003557, ip=10.42.0.182)     Skipping future month: 2026-05
# (PoolActor pid=4003557, ip=10.42.0.182)   Loading training data for 2025-11 (Types: ['f2', 'f3'])...
# (PoolActor pid=4003557, ip=10.42.0.182)     Skipping future month: 2026-01
# (PoolActor pid=4003557, ip=10.42.0.182)     Skipping future month: 2026-02
# (PoolActor pid=4003557, ip=10.42.0.182)   Applying label modification based on prob_exceed_80 < 1e-05...
# (PoolActor pid=4003557, ip=10.42.0.182)     Modified 870945 labels to 0 where prob_exceed_80 < 1e-05.
# (PoolActor pid=4003557, ip=10.42.0.182)
# (PoolActor pid=4003557, ip=10.42.0.182) [STEP 3: Identifying Target Branches]
# (PoolActor pid=4003557, ip=10.42.0.182)   Identifying target branches from test periods...
# (PoolActor pid=4015574, ip=10.42.7.70)   Loading training data for 2025-10 (Types: ['q3', 'q4'])...
# (PoolActor pid=4015574, ip=10.42.7.70)     Skipping future month: 2025-12
# (PoolActor pid=4015574, ip=10.42.7.70)     Skipping future month: 2026-01
# (PoolActor pid=4015574, ip=10.42.7.70)     Skipping future month: 2026-02
# (PoolActor pid=4015574, ip=10.42.7.70)     Skipping future month: 2026-03
# (PoolActor pid=4015574, ip=10.42.7.70)     Skipping future month: 2026-04
# (PoolActor pid=4015574, ip=10.42.7.70)     Skipping future month: 2026-05
# (PoolActor pid=4015574, ip=10.42.7.70)   Loading training data for 2025-11 (Types: ['f2', 'f3'])...
# (PoolActor pid=4015574, ip=10.42.7.70)     Skipping future month: 2026-01
# (PoolActor pid=4015574, ip=10.42.7.70)     Skipping future month: 2026-02
# (PoolActor pid=4068090, ip=10.42.8.15)     ✓ Trained 617 branch models (skipped 4616)
# (PoolActor pid=4068090, ip=10.42.8.15)
# (PoolActor pid=4068090, ip=10.42.8.15) ✓ Regression Training Complete
# (PoolActor pid=4068090, ip=10.42.8.15)
# (PoolActor pid=4068090, ip=10.42.8.15) ================================================================================
# (PoolActor pid=4068090, ip=10.42.8.15) FALLBACK MONITORING STATISTICS
# (PoolActor pid=4068090, ip=10.42.8.15) ================================================================================
# (PoolActor pid=4068090, ip=10.42.8.15)
# (PoolActor pid=4068090, ip=10.42.8.15) [F0]
# (PoolActor pid=4068090, ip=10.42.8.15)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=4068090, ip=10.42.8.15)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=4068090, ip=10.42.8.15)
# (PoolActor pid=4068090, ip=10.42.8.15) [F1]
# (PoolActor pid=4068090, ip=10.42.8.15)   Classification Fallback Rate: 0/381 (0.00%)
# (PoolActor pid=4068090, ip=10.42.8.15)   Regression Fallback Rate:     0/617 (0.00%)
# (PoolActor pid=4068090, ip=10.42.8.15)
# (PoolActor pid=4068090, ip=10.42.8.15) [LONG]
# (PoolActor pid=4068090, ip=10.42.8.15)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=4068090, ip=10.42.8.15)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=4015574, ip=10.42.7.70)   Applying label modification based on prob_exceed_80 < 1e-05...
# (PoolActor pid=4015574, ip=10.42.7.70)     Modified 870945 labels to 0 where prob_exceed_80 < 1e-05.
# (PoolActor pid=4015574, ip=10.42.7.70)
# (PoolActor pid=4015574, ip=10.42.7.70) [STEP 3: Identifying Target Branches]
# (PoolActor pid=4015574, ip=10.42.7.70)   Identifying target branches from test periods...
# (PoolActor pid=4068090, ip=10.42.8.15)
# (PoolActor pid=4068090, ip=10.42.8.15) [STEP 6: Making Predictions for Auction Month 2026-01]
# (PoolActor pid=4068090, ip=10.42.8.15)   Predicting for Market Month: 2026-02
# (PoolActor pid=4082646, ip=10.42.4.173)   Found 5487 unique branch-flow pairs in test set.
# (PoolActor pid=4082646, ip=10.42.4.173)
# (PoolActor pid=4082646, ip=10.42.4.173) [STEP 4: Training Models for Auction Month 2026-01]
# (PoolActor pid=4082646, ip=10.42.4.173)
# (PoolActor pid=4082646, ip=10.42.4.173) [Training Classification Models + Threshold Optimization]
# (PoolActor pid=4082646, ip=10.42.4.173) --------------------------------------------------------------------------------
# (PoolActor pid=4082646, ip=10.42.4.173)   Skipping groups not in test periods: f0, f1
# (PoolActor pid=4082646, ip=10.42.4.173)
# (PoolActor pid=4082646, ip=10.42.4.173) Processing LONG TERM models...
# (PoolActor pid=4082646, ip=10.42.4.173)   Training default fallback classifier (long)...
# (PoolActor pid=4069611, ip=10.42.9.131)     ✓ Default ensemble trained (1 models)
# (PoolActor pid=4069611, ip=10.42.9.131)     Total samples: 1,469,905
# (PoolActor pid=4069611, ip=10.42.9.131)     Selected features: 6/7
# (PoolActor pid=4069611, ip=10.42.9.131)   Optimizing threshold for default ensemble (f0)...
# (PoolActor pid=4003557, ip=10.42.0.182)   Found 5472 unique branch-flow pairs in test set.
# (PoolActor pid=4003557, ip=10.42.0.182)
# (PoolActor pid=4003557, ip=10.42.0.182) [STEP 4: Training Models for Auction Month 2026-01]
# (PoolActor pid=4003557, ip=10.42.0.182)
# (PoolActor pid=4003557, ip=10.42.0.182) [Training Classification Models + Threshold Optimization]
# (PoolActor pid=4003557, ip=10.42.0.182) --------------------------------------------------------------------------------
# (PoolActor pid=4003557, ip=10.42.0.182)   Skipping groups not in test periods: f0, f1
# (PoolActor pid=4003557, ip=10.42.0.182)
# (PoolActor pid=4003557, ip=10.42.0.182) Processing LONG TERM models...
# (PoolActor pid=4069611, ip=10.42.9.131)     ✓ Optimal threshold: 0.010 (F-beta=0.990)
# (PoolActor pid=4069611, ip=10.42.9.131)   Training branch-specific classifiers (f0)...
# (PoolActor pid=4003557, ip=10.42.0.182)   Training default fallback classifier (long)...
# (PoolActor pid=4015574, ip=10.42.7.70)   Found 5402 unique branch-flow pairs in test set.
# (PoolActor pid=4015574, ip=10.42.7.70)
# (PoolActor pid=4015574, ip=10.42.7.70) [STEP 4: Training Models for Auction Month 2026-01]
# (PoolActor pid=4015574, ip=10.42.7.70)
# (PoolActor pid=4015574, ip=10.42.7.70) [Training Classification Models + Threshold Optimization]
# (PoolActor pid=4015574, ip=10.42.7.70) --------------------------------------------------------------------------------
# (PoolActor pid=4015574, ip=10.42.7.70)   Skipping groups not in test periods: f0, f1
# (PoolActor pid=4015574, ip=10.42.7.70)
# (PoolActor pid=4015574, ip=10.42.7.70) Processing LONG TERM models...
# (PoolActor pid=4015574, ip=10.42.7.70)   Training default fallback classifier (long)...
# (PoolActor pid=4003557, ip=10.42.0.182)     ✓ Default ensemble trained (1 models)
# (PoolActor pid=4003557, ip=10.42.0.182)     Total samples: 1,593,642
# (PoolActor pid=4003557, ip=10.42.0.182)     Selected features: 6/7
# (PoolActor pid=4003557, ip=10.42.0.182)   Optimizing threshold for default ensemble (long)...
# (PoolActor pid=4082646, ip=10.42.4.173)     ✓ Default ensemble trained (1 models)
# (PoolActor pid=4082646, ip=10.42.4.173)     Total samples: 1,593,642
# (PoolActor pid=4082646, ip=10.42.4.173)     Selected features: 6/7
# (PoolActor pid=4082646, ip=10.42.4.173)   Optimizing threshold for default ensemble (long)...
# (PoolActor pid=4003557, ip=10.42.0.182)     ✓ Optimal threshold: 0.036 (F-beta=0.991)
# (PoolActor pid=4003557, ip=10.42.0.182)   Training branch-specific classifiers (long)...
# (PoolActor pid=4082646, ip=10.42.4.173)     ✓ Optimal threshold: 0.036 (F-beta=0.991)
# (PoolActor pid=4082646, ip=10.42.4.173)   Training branch-specific classifiers (long)...
# (PoolActor pid=4069611, ip=10.42.9.131)     ✓ Trained 386 branch models (skipped 4951)
# (PoolActor pid=4069611, ip=10.42.9.131)
# (PoolActor pid=4069611, ip=10.42.9.131) ✓ Classification Training Complete
# (PoolActor pid=4069611, ip=10.42.9.131)
# (PoolActor pid=4069611, ip=10.42.9.131) ================================================================================
# (PoolActor pid=4069611, ip=10.42.9.131) FALLBACK MONITORING STATISTICS
# (PoolActor pid=4069611, ip=10.42.9.131) ================================================================================
# (PoolActor pid=4069611, ip=10.42.9.131)
# (PoolActor pid=4069611, ip=10.42.9.131) [F0]
# (PoolActor pid=4069611, ip=10.42.9.131)   Classification Fallback Rate: 0/386 (0.00%)
# (PoolActor pid=4069611, ip=10.42.9.131)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=4069611, ip=10.42.9.131)
# (PoolActor pid=4069611, ip=10.42.9.131) [F1]
# (PoolActor pid=4069611, ip=10.42.9.131)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=4069611, ip=10.42.9.131)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=4069611, ip=10.42.9.131)
# (PoolActor pid=4069611, ip=10.42.9.131) [LONG]
# (PoolActor pid=4069611, ip=10.42.9.131)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=4069611, ip=10.42.9.131)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=4069611, ip=10.42.9.131)
# (PoolActor pid=4069611, ip=10.42.9.131) [STEP 5: Training Regressors for Auction Month 2026-01]
# (PoolActor pid=4069611, ip=10.42.9.131)
# (PoolActor pid=4069611, ip=10.42.9.131) [Characterizing Never-Binding Branches for F0]
# (PoolActor pid=4069611, ip=10.42.9.131)   Detection Features: ['prob_exceed_100', 'prob_exceed_95']
# (PoolActor pid=4069611, ip=10.42.9.131)   Probability Features: ['prob_exceed_100', 'prob_exceed_95', 'density_skewness']
# (PoolActor pid=4069611, ip=10.42.9.131) --------------------------------------------------------------------------------
# (PoolActor pid=4069611, ip=10.42.9.131) Analyzing 4,488 branches for never-binding patterns...
# (PoolActor pid=4015574, ip=10.42.7.70)     ✓ Default ensemble trained (1 models)
# (PoolActor pid=4015574, ip=10.42.7.70)     Total samples: 1,593,642
# (PoolActor pid=4015574, ip=10.42.7.70)     Selected features: 6/7
# (PoolActor pid=4015574, ip=10.42.7.70)   Optimizing threshold for default ensemble (long)...
# (PoolActor pid=4068090, ip=10.42.8.15)   Saved final results to: /opt/temp/tmp/pw_data/spice6/prod_f0p_model_miso/ml_pred/auction_month=2026-01/market_month=2026-02/class_type=offpeak
# (PoolActor pid=4015574, ip=10.42.7.70)     ✓ Optimal threshold: 0.036 (F-beta=0.991)
# (PoolActor pid=4015574, ip=10.42.7.70)   Training branch-specific classifiers (long)...
# (PoolActor pid=4068090, ip=10.42.8.15)
# (PoolActor pid=4068090, ip=10.42.8.15) ✅ Auction Month 2026-01 Complete (1 predictions)
# (PoolActor pid=4068090, ip=10.42.8.15) [Timing] _process_auction_month for 2026-01 took 80.83 seconds
# (PoolActor pid=4069611, ip=10.42.9.131)
# (PoolActor pid=4069611, ip=10.42.9.131) ✓ Never-Binding Branches Identified (f0): 4,192
# (PoolActor pid=4069611, ip=10.42.9.131)
# (PoolActor pid=4069611, ip=10.42.9.131)   Example Flow Statistics for 'prob_exceed_95' (first 5 branches):
# (PoolActor pid=4069611, ip=10.42.9.131)     0304           1                             : mean=0.0002, P95=0.0008, IQR=0.0003
# (PoolActor pid=4069611, ip=10.42.9.131)     0321X          1                             : mean=0.0060, P95=0.0274, IQR=0.0045
# (PoolActor pid=4069611, ip=10.42.9.131)     0621           1                             : mean=0.0050, P95=0.0004, IQR=0.0000
# (PoolActor pid=4069611, ip=10.42.9.131)     0622           1                             : mean=0.0653, P95=0.3349, IQR=0.0087
# (PoolActor pid=4069611, ip=10.42.9.131)     0624           1                             : mean=0.0000, P95=0.0000, IQR=0.0000
# (PoolActor pid=4069611, ip=10.42.9.131)
# (PoolActor pid=4069611, ip=10.42.9.131)   Distribution of IQR for 'prob_exceed_95':
# (PoolActor pid=4069611, ip=10.42.9.131)     min=0.0000, median=0.0000, max=0.7204
# (PoolActor pid=4069611, ip=10.42.9.131)
# (PoolActor pid=4069611, ip=10.42.9.131) [Training Regression Models]
# (PoolActor pid=4069611, ip=10.42.9.131) --------------------------------------------------------------------------------
# (PoolActor pid=4069611, ip=10.42.9.131)   Skipping groups not in test periods: f1, long
# (PoolActor pid=4069611, ip=10.42.9.131)
# (PoolActor pid=4069611, ip=10.42.9.131) Processing F0 TERM models...
# (PoolActor pid=4069611, ip=10.42.9.131)   Training default fallback regressor (f0)...
# (PoolActor pid=4069611, ip=10.42.9.131)     ✓ Default ensemble trained (1 models)
# (PoolActor pid=4069611, ip=10.42.9.131)     Total binding samples: 33,053
# (PoolActor pid=4069611, ip=10.42.9.131)   Training branch-specific regressors (f0)...
# (PoolActor pid=4082646, ip=10.42.4.173)     ✓ Trained 359 branch models (skipped 4894)
# (PoolActor pid=4082646, ip=10.42.4.173)
# (PoolActor pid=4082646, ip=10.42.4.173) ✓ Classification Training Complete
# (PoolActor pid=4082646, ip=10.42.4.173)
# (PoolActor pid=4082646, ip=10.42.4.173) ================================================================================
# (PoolActor pid=4082646, ip=10.42.4.173) FALLBACK MONITORING STATISTICS
# (PoolActor pid=4082646, ip=10.42.4.173) ================================================================================
# (PoolActor pid=4082646, ip=10.42.4.173)
# (PoolActor pid=4082646, ip=10.42.4.173) [F0]
# (PoolActor pid=4082646, ip=10.42.4.173)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=4082646, ip=10.42.4.173)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=4082646, ip=10.42.4.173)
# (PoolActor pid=4082646, ip=10.42.4.173) [F1]
# (PoolActor pid=4082646, ip=10.42.4.173)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=4082646, ip=10.42.4.173)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=4082646, ip=10.42.4.173)
# (PoolActor pid=4082646, ip=10.42.4.173) [LONG]
# (PoolActor pid=4082646, ip=10.42.4.173)   Classification Fallback Rate: 0/359 (0.00%)
# (PoolActor pid=4082646, ip=10.42.4.173)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=4082646, ip=10.42.4.173)
# (PoolActor pid=4082646, ip=10.42.4.173) [STEP 5: Training Regressors for Auction Month 2026-01]
# (PoolActor pid=4082646, ip=10.42.4.173)
# (PoolActor pid=4082646, ip=10.42.4.173) [Characterizing Never-Binding Branches for LONG]
# (PoolActor pid=4082646, ip=10.42.4.173)   Detection Features: ['prob_exceed_100', 'prob_exceed_95']
# (PoolActor pid=4082646, ip=10.42.4.173)   Probability Features: ['prob_exceed_100', 'prob_exceed_95', 'density_skewness']
# (PoolActor pid=4082646, ip=10.42.4.173) --------------------------------------------------------------------------------
# (PoolActor pid=4003557, ip=10.42.0.182)     ✓ Trained 363 branch models (skipped 4872)
# (PoolActor pid=4003557, ip=10.42.0.182)
# (PoolActor pid=4003557, ip=10.42.0.182) ✓ Classification Training Complete
# (PoolActor pid=4003557, ip=10.42.0.182)
# (PoolActor pid=4003557, ip=10.42.0.182) ================================================================================
# (PoolActor pid=4003557, ip=10.42.0.182) FALLBACK MONITORING STATISTICS
# (PoolActor pid=4003557, ip=10.42.0.182) ================================================================================
# (PoolActor pid=4003557, ip=10.42.0.182)
# (PoolActor pid=4003557, ip=10.42.0.182) [F0]
# (PoolActor pid=4003557, ip=10.42.0.182)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=4003557, ip=10.42.0.182)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=4003557, ip=10.42.0.182)
# (PoolActor pid=4003557, ip=10.42.0.182) [F1]
# (PoolActor pid=4003557, ip=10.42.0.182)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=4003557, ip=10.42.0.182)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=4003557, ip=10.42.0.182)
# (PoolActor pid=4003557, ip=10.42.0.182) [LONG]
# (PoolActor pid=4003557, ip=10.42.0.182)   Classification Fallback Rate: 0/363 (0.00%)
# (PoolActor pid=4003557, ip=10.42.0.182)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=4003557, ip=10.42.0.182)
# (PoolActor pid=4003557, ip=10.42.0.182) [STEP 5: Training Regressors for Auction Month 2026-01]
# (PoolActor pid=4082646, ip=10.42.4.173) Analyzing 4,419 branches for never-binding patterns...
# (PoolActor pid=4003557, ip=10.42.0.182)
# (PoolActor pid=4003557, ip=10.42.0.182) [Characterizing Never-Binding Branches for LONG]
# (PoolActor pid=4003557, ip=10.42.0.182)   Detection Features: ['prob_exceed_100', 'prob_exceed_95']
# (PoolActor pid=4003557, ip=10.42.0.182)   Probability Features: ['prob_exceed_100', 'prob_exceed_95', 'density_skewness']
# (PoolActor pid=4003557, ip=10.42.0.182) --------------------------------------------------------------------------------
# (PoolActor pid=4003557, ip=10.42.0.182) Analyzing 4,419 branches for never-binding patterns...
# (PoolActor pid=4015574, ip=10.42.7.70)     ✓ Trained 362 branch models (skipped 4817)
# (PoolActor pid=4015574, ip=10.42.7.70)
# (PoolActor pid=4015574, ip=10.42.7.70) ✓ Classification Training Complete
# (PoolActor pid=4015574, ip=10.42.7.70)
# (PoolActor pid=4015574, ip=10.42.7.70) ================================================================================
# (PoolActor pid=4015574, ip=10.42.7.70) FALLBACK MONITORING STATISTICS
# (PoolActor pid=4015574, ip=10.42.7.70) ================================================================================
# (PoolActor pid=4015574, ip=10.42.7.70)
# (PoolActor pid=4015574, ip=10.42.7.70) [F0]
# (PoolActor pid=4015574, ip=10.42.7.70)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=4015574, ip=10.42.7.70)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=4015574, ip=10.42.7.70)
# (PoolActor pid=4015574, ip=10.42.7.70) [F1]
# (PoolActor pid=4015574, ip=10.42.7.70)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=4015574, ip=10.42.7.70)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=4015574, ip=10.42.7.70)
# (PoolActor pid=4015574, ip=10.42.7.70) [LONG]
# (PoolActor pid=4015574, ip=10.42.7.70)   Classification Fallback Rate: 0/362 (0.00%)
# (PoolActor pid=4015574, ip=10.42.7.70)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=4015574, ip=10.42.7.70)
# (PoolActor pid=4015574, ip=10.42.7.70) [STEP 5: Training Regressors for Auction Month 2026-01]
# (PoolActor pid=4015574, ip=10.42.7.70)
# (PoolActor pid=4015574, ip=10.42.7.70) [Characterizing Never-Binding Branches for LONG]
# (PoolActor pid=4015574, ip=10.42.7.70)   Detection Features: ['prob_exceed_100', 'prob_exceed_95']
# (PoolActor pid=4015574, ip=10.42.7.70)   Probability Features: ['prob_exceed_100', 'prob_exceed_95', 'density_skewness']
# (PoolActor pid=4015574, ip=10.42.7.70) --------------------------------------------------------------------------------
# (PoolActor pid=4082646, ip=10.42.4.173)
# (PoolActor pid=4082646, ip=10.42.4.173) ✓ Never-Binding Branches Identified (long): 4,130
# (PoolActor pid=4082646, ip=10.42.4.173)
# (PoolActor pid=4082646, ip=10.42.4.173)   Example Flow Statistics for 'density_skewness' (first 5 branches):
# (PoolActor pid=4082646, ip=10.42.4.173)     0304           1                             : mean=0.7632, P95=1.4518, IQR=0.5347
# (PoolActor pid=4082646, ip=10.42.4.173)     0321X          1                             : mean=0.0713, P95=0.3841, IQR=0.1953
# (PoolActor pid=4082646, ip=10.42.4.173)     0621           1                             : mean=-0.4469, P95=0.2558, IQR=0.6836
# (PoolActor pid=4082646, ip=10.42.4.173)     0622           1                             : mean=-0.4506, P95=0.2551, IQR=0.6796
# (PoolActor pid=4082646, ip=10.42.4.173)     0624           1                             : mean=0.0821, P95=0.2714, IQR=0.1706
# (PoolActor pid=4082646, ip=10.42.4.173)
# (PoolActor pid=4082646, ip=10.42.4.173)   Distribution of IQR for 'density_skewness':
# (PoolActor pid=4082646, ip=10.42.4.173)     min=0.0000, median=0.2934, max=5487750.2122
# (PoolActor pid=4082646, ip=10.42.4.173)
# (PoolActor pid=4082646, ip=10.42.4.173) [Training Regression Models]
# (PoolActor pid=4082646, ip=10.42.4.173) --------------------------------------------------------------------------------
# (PoolActor pid=4082646, ip=10.42.4.173)   Skipping groups not in test periods: f0, f1
# (PoolActor pid=4082646, ip=10.42.4.173)
# (PoolActor pid=4082646, ip=10.42.4.173) Processing LONG TERM models...
# (PoolActor pid=4015574, ip=10.42.7.70) Analyzing 4,419 branches for never-binding patterns...
# (PoolActor pid=4082646, ip=10.42.4.173)   Training default fallback regressor (long)...
# (PoolActor pid=4082646, ip=10.42.4.173)     ✓ Default ensemble trained (1 models)
# (PoolActor pid=4082646, ip=10.42.4.173)     Total binding samples: 38,581
# (PoolActor pid=4082646, ip=10.42.4.173)   Training branch-specific regressors (long)...
# (PoolActor pid=4003557, ip=10.42.0.182)
# (PoolActor pid=4003557, ip=10.42.0.182) ✓ Never-Binding Branches Identified (long): 4,130
# (PoolActor pid=4003557, ip=10.42.0.182)
# (PoolActor pid=4003557, ip=10.42.0.182)   Example Flow Statistics for 'density_skewness' (first 5 branches):
# (PoolActor pid=4003557, ip=10.42.0.182)     0304           1                             : mean=0.7632, P95=1.4518, IQR=0.5347
# (PoolActor pid=4003557, ip=10.42.0.182)     0321X          1                             : mean=0.0713, P95=0.3841, IQR=0.1953
# (PoolActor pid=4003557, ip=10.42.0.182)     0621           1                             : mean=-0.4469, P95=0.2558, IQR=0.6836
# (PoolActor pid=4003557, ip=10.42.0.182)     0622           1                             : mean=-0.4506, P95=0.2551, IQR=0.6796
# (PoolActor pid=4003557, ip=10.42.0.182)     0624           1                             : mean=0.0821, P95=0.2714, IQR=0.1706
# (PoolActor pid=4003557, ip=10.42.0.182)
# (PoolActor pid=4003557, ip=10.42.0.182)   Distribution of IQR for 'density_skewness':
# (PoolActor pid=4003557, ip=10.42.0.182)     min=0.0000, median=0.2934, max=5487750.2122
# (PoolActor pid=4003557, ip=10.42.0.182)
# (PoolActor pid=4003557, ip=10.42.0.182) [Training Regression Models]
# (PoolActor pid=4003557, ip=10.42.0.182) --------------------------------------------------------------------------------
# (PoolActor pid=4003557, ip=10.42.0.182)   Skipping groups not in test periods: f0, f1
# (PoolActor pid=4003557, ip=10.42.0.182)
# (PoolActor pid=4003557, ip=10.42.0.182) Processing LONG TERM models...
# (PoolActor pid=4003557, ip=10.42.0.182)   Training default fallback regressor (long)...
# (PoolActor pid=4003557, ip=10.42.0.182)     ✓ Default ensemble trained (1 models)
# (PoolActor pid=4003557, ip=10.42.0.182)     Total binding samples: 38,581
# (PoolActor pid=4003557, ip=10.42.0.182)   Training branch-specific regressors (long)...
# (PoolActor pid=4015574, ip=10.42.7.70)
# (PoolActor pid=4015574, ip=10.42.7.70) ✓ Never-Binding Branches Identified (long): 4,130
# (PoolActor pid=4015574, ip=10.42.7.70)
# (PoolActor pid=4015574, ip=10.42.7.70)   Example Flow Statistics for 'density_skewness' (first 5 branches):
# (PoolActor pid=4015574, ip=10.42.7.70)     0304           1                             : mean=0.7632, P95=1.4518, IQR=0.5347
# (PoolActor pid=4015574, ip=10.42.7.70)     0321X          1                             : mean=0.0713, P95=0.3841, IQR=0.1953
# (PoolActor pid=4015574, ip=10.42.7.70)     0621           1                             : mean=-0.4469, P95=0.2558, IQR=0.6836
# (PoolActor pid=4015574, ip=10.42.7.70)     0622           1                             : mean=-0.4506, P95=0.2551, IQR=0.6796
# (PoolActor pid=4015574, ip=10.42.7.70)     0624           1                             : mean=0.0821, P95=0.2714, IQR=0.1706
# (PoolActor pid=4015574, ip=10.42.7.70)
# (PoolActor pid=4015574, ip=10.42.7.70)   Distribution of IQR for 'density_skewness':
# (PoolActor pid=4015574, ip=10.42.7.70)     min=0.0000, median=0.2934, max=5487750.2122
# (PoolActor pid=4015574, ip=10.42.7.70)
# (PoolActor pid=4015574, ip=10.42.7.70) [Training Regression Models]
# (PoolActor pid=4015574, ip=10.42.7.70) --------------------------------------------------------------------------------
# (PoolActor pid=4015574, ip=10.42.7.70)   Skipping groups not in test periods: f0, f1
# (PoolActor pid=4015574, ip=10.42.7.70)
# (PoolActor pid=4015574, ip=10.42.7.70) Processing LONG TERM models...
# (PoolActor pid=4015574, ip=10.42.7.70)   Training default fallback regressor (long)...
# (PoolActor pid=4015574, ip=10.42.7.70)     ✓ Default ensemble trained (1 models)
# (PoolActor pid=4015574, ip=10.42.7.70)     Total binding samples: 38,581
# (PoolActor pid=4015574, ip=10.42.7.70)   Training branch-specific regressors (long)...
# (PoolActor pid=4069611, ip=10.42.9.131)     ✓ Trained 709 branch models (skipped 4628)
# (PoolActor pid=4069611, ip=10.42.9.131)
# (PoolActor pid=4069611, ip=10.42.9.131) ✓ Regression Training Complete
# (PoolActor pid=4069611, ip=10.42.9.131)
# (PoolActor pid=4069611, ip=10.42.9.131) ================================================================================
# (PoolActor pid=4069611, ip=10.42.9.131) FALLBACK MONITORING STATISTICS
# (PoolActor pid=4069611, ip=10.42.9.131) ================================================================================
# (PoolActor pid=4069611, ip=10.42.9.131)
# (PoolActor pid=4069611, ip=10.42.9.131) [F0]
# (PoolActor pid=4069611, ip=10.42.9.131)   Classification Fallback Rate: 0/386 (0.00%)
# (PoolActor pid=4069611, ip=10.42.9.131)   Regression Fallback Rate:     0/709 (0.00%)
# (PoolActor pid=4069611, ip=10.42.9.131)
# (PoolActor pid=4069611, ip=10.42.9.131) [F1]
# (PoolActor pid=4069611, ip=10.42.9.131)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=4069611, ip=10.42.9.131)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=4069611, ip=10.42.9.131)
# (PoolActor pid=4069611, ip=10.42.9.131) [LONG]
# (PoolActor pid=4069611, ip=10.42.9.131)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=4069611, ip=10.42.9.131)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=4069611, ip=10.42.9.131)
# (PoolActor pid=4069611, ip=10.42.9.131) [STEP 6: Making Predictions for Auction Month 2026-01]
# (PoolActor pid=4069611, ip=10.42.9.131)   Predicting for Market Month: 2026-01
# (PoolActor pid=4082646, ip=10.42.4.173)     ✓ Trained 515 branch models (skipped 4738)
# (PoolActor pid=4082646, ip=10.42.4.173)
# (PoolActor pid=4082646, ip=10.42.4.173) ✓ Regression Training Complete
# (PoolActor pid=4082646, ip=10.42.4.173)
# (PoolActor pid=4082646, ip=10.42.4.173) ================================================================================
# (PoolActor pid=4082646, ip=10.42.4.173) FALLBACK MONITORING STATISTICS
# (PoolActor pid=4082646, ip=10.42.4.173) ================================================================================
# (PoolActor pid=4082646, ip=10.42.4.173)
# (PoolActor pid=4082646, ip=10.42.4.173) [F0]
# (PoolActor pid=4082646, ip=10.42.4.173)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=4082646, ip=10.42.4.173)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=4082646, ip=10.42.4.173)
# (PoolActor pid=4082646, ip=10.42.4.173) [F1]
# (PoolActor pid=4082646, ip=10.42.4.173)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=4082646, ip=10.42.4.173)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=4082646, ip=10.42.4.173)
# (PoolActor pid=4082646, ip=10.42.4.173) [LONG]
# (PoolActor pid=4082646, ip=10.42.4.173)   Classification Fallback Rate: 0/359 (0.00%)
# (PoolActor pid=4082646, ip=10.42.4.173)   Regression Fallback Rate:     0/515 (0.00%)
# (PoolActor pid=4082646, ip=10.42.4.173)
# (PoolActor pid=4082646, ip=10.42.4.173) [STEP 6: Making Predictions for Auction Month 2026-01]
# (PoolActor pid=4082646, ip=10.42.4.173)   Predicting for Market Month: 2026-05
# (PoolActor pid=4003557, ip=10.42.0.182)     ✓ Trained 513 branch models (skipped 4722)
# (PoolActor pid=4003557, ip=10.42.0.182)
# (PoolActor pid=4003557, ip=10.42.0.182) ✓ Regression Training Complete
# (PoolActor pid=4003557, ip=10.42.0.182)
# (PoolActor pid=4003557, ip=10.42.0.182) ================================================================================
# (PoolActor pid=4003557, ip=10.42.0.182) FALLBACK MONITORING STATISTICS
# (PoolActor pid=4003557, ip=10.42.0.182) ================================================================================
# (PoolActor pid=4003557, ip=10.42.0.182)
# (PoolActor pid=4003557, ip=10.42.0.182) [F0]
# (PoolActor pid=4003557, ip=10.42.0.182)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=4003557, ip=10.42.0.182)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=4003557, ip=10.42.0.182)
# (PoolActor pid=4003557, ip=10.42.0.182) [F1]
# (PoolActor pid=4003557, ip=10.42.0.182)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=4003557, ip=10.42.0.182)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=4003557, ip=10.42.0.182)
# (PoolActor pid=4003557, ip=10.42.0.182) [LONG]
# (PoolActor pid=4003557, ip=10.42.0.182)   Classification Fallback Rate: 0/363 (0.00%)
# (PoolActor pid=4003557, ip=10.42.0.182)   Regression Fallback Rate:     0/513 (0.00%)
# (PoolActor pid=4003557, ip=10.42.0.182)
# (PoolActor pid=4003557, ip=10.42.0.182) [STEP 6: Making Predictions for Auction Month 2026-01]
# (PoolActor pid=4003557, ip=10.42.0.182)   Predicting for Market Month: 2026-03
# (PoolActor pid=4015574, ip=10.42.7.70)     ✓ Trained 512 branch models (skipped 4667)
# (PoolActor pid=4015574, ip=10.42.7.70)
# (PoolActor pid=4015574, ip=10.42.7.70) ✓ Regression Training Complete
# (PoolActor pid=4015574, ip=10.42.7.70)
# (PoolActor pid=4015574, ip=10.42.7.70) ================================================================================
# (PoolActor pid=4015574, ip=10.42.7.70) FALLBACK MONITORING STATISTICS
# (PoolActor pid=4015574, ip=10.42.7.70) ================================================================================
# (PoolActor pid=4015574, ip=10.42.7.70)
# (PoolActor pid=4015574, ip=10.42.7.70) [F0]
# (PoolActor pid=4015574, ip=10.42.7.70)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=4015574, ip=10.42.7.70)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=4015574, ip=10.42.7.70)
# (PoolActor pid=4015574, ip=10.42.7.70) [F1]
# (PoolActor pid=4015574, ip=10.42.7.70)   Classification Fallback Rate: N/A (0 branches)
# (PoolActor pid=4015574, ip=10.42.7.70)   Regression Fallback Rate:     N/A (0 branches)
# (PoolActor pid=4015574, ip=10.42.7.70)
# (PoolActor pid=4015574, ip=10.42.7.70) [LONG]
# (PoolActor pid=4015574, ip=10.42.7.70)   Classification Fallback Rate: 0/362 (0.00%)
# (PoolActor pid=4015574, ip=10.42.7.70)   Regression Fallback Rate:     0/512 (0.00%)
# (PoolActor pid=4015574, ip=10.42.7.70)
# (PoolActor pid=4015574, ip=10.42.7.70) [STEP 6: Making Predictions for Auction Month 2026-01]
# (PoolActor pid=4015574, ip=10.42.7.70)   Predicting for Market Month: 2026-04
# (PoolActor pid=4069611, ip=10.42.9.131)   Saved final results to: /opt/temp/tmp/pw_data/spice6/prod_f0p_model_miso/ml_pred/auction_month=2026-01/market_month=2026-01/class_type=offpeak
# (PoolActor pid=4069611, ip=10.42.9.131)
# (PoolActor pid=4069611, ip=10.42.9.131) ✅ Auction Month 2026-01 Complete (1 predictions)
# (PoolActor pid=4069611, ip=10.42.9.131) [Timing] _process_auction_month for 2026-01 took 133.92 seconds
# (PoolActor pid=4082646, ip=10.42.4.173)   Saved final results to: /opt/temp/tmp/pw_data/spice6/prod_f0p_model_miso/ml_pred/auction_month=2026-01/market_month=2026-05/class_type=offpeak
# (PoolActor pid=4082646, ip=10.42.4.173)
# (PoolActor pid=4082646, ip=10.42.4.173) ✅ Auction Month 2026-01 Complete (1 predictions)
# (PoolActor pid=4082646, ip=10.42.4.173) [Timing] _process_auction_month for 2026-01 took 149.50 seconds
# (PoolActor pid=4003557, ip=10.42.0.182)   Saved final results to: /opt/temp/tmp/pw_data/spice6/prod_f0p_model_miso/ml_pred/auction_month=2026-01/market_month=2026-03/class_type=offpeak
# (PoolActor pid=4003557, ip=10.42.0.182)
# (PoolActor pid=4003557, ip=10.42.0.182) ✅ Auction Month 2026-01 Complete (1 predictions)
# (PoolActor pid=4003557, ip=10.42.0.182) [Timing] _process_auction_month for 2026-01 took 156.41 seconds
# (PoolActor pid=4015574, ip=10.42.7.70)   Saved final results to: /opt/temp/tmp/pw_data/spice6/prod_f0p_model_miso/ml_pred/auction_month=2026-01/market_month=2026-04/class_type=offpeak
# (PoolActor pid=4015574, ip=10.42.7.70)
# (PoolActor pid=4015574, ip=10.42.7.70) ✅ Auction Month 2026-01 Complete (1 predictions)
# (PoolActor pid=4015574, ip=10.42.7.70) [Timing] _process_auction_month for 2026-01 took 159.80 seconds
#
# ================================================================================
# ✅ ALL AUCTION MONTHS TRAINING COMPLETE!
# ================================================================================
#
# ================================================================================
# [COMBINING RESULTS ACROSS ALL PERIODS]
# ================================================================================
#
# ✓ Results Combined
#   Total samples (per-outage): 702,852
#   Total unique constraints (monthly): 73,974
#   Date range: 2026-01-01 to 2026-05-31
#
# [ANALYZING COMBINED RESULTS]
#   Skipping metrics calculation (no labels available)
#
# ================================================================================
# ✅ PIPELINE COMPLETE!
# ================================================================================

# %%
f = pd.read_parquet('/opt/temp/tmp/pw_data/spice6/prod_f0p_model_miso/ml_pred/auction_month=2026-01/market_month=2026-01/class_type=onpeak/final_results.parquet')

# %%
f[f['branch_name'].str.contains('zach', case=False)]
# Out:
#                                    branch_name  prob_exceed_105  \
# constraint_id flow_direction
# 391448        1                   ZACH     TR1         0.000000
# 429694        1               ZACH_ADIR_7671 A         0.000318
# 519679        1                   ZACH     TR2         0.003459
# 519961        1                   ZACH     TR2         0.003459
#
#                               prob_exceed_110  prob_exceed_95   hist_da  \
# constraint_id flow_direction
# 391448        1                      0.000000        0.000000  6.427320
# 429694        1                      0.000185        0.000811  7.550595
# 519679        1                      0.001951        0.011938  4.585780
# 519961        1                      0.001951        0.011938  4.585780
#
#                               density_skewness  prob_below_90  prob_exceed_90  \
# constraint_id flow_direction
# 391448        1                      -0.236686       1.000000        0.000000
# 429694        1                      -0.347820       0.998708        0.001292
# 519679        1                      -0.225424       0.980037        0.019963
# 519961        1                      -0.225424       0.980037        0.019963
#
#                               prob_exceed_100  actual_shadow_price  \
# constraint_id flow_direction
# 391448        1                      0.000000                  0.0
# 429694        1                      0.000505                  0.0
# 519679        1                      0.006591                  0.0
# 519961        1                      0.006591                  0.0
#
#                               predicted_shadow_price  binding_probability  \
# constraint_id flow_direction
# 391448        1                             0.000000              0.00000
# 429694        1                             0.000000              0.00000
# 519679        1                          2604.065964              0.79863
# 519961        1                          2604.065964              0.79863
#
#                               binding_probability_scaled  threshold  \
# constraint_id flow_direction
# 391448        1                                 0.000000   0.500000
# 429694        1                                 0.000000   0.500000
# 519679        1                                 0.869396   0.020892
# 519961        1                                 0.869396   0.020892
#
#                               predicted_binding_count  actual_binding  \
# constraint_id flow_direction
# 391448        1                                     0               0
# 429694        1                                     0               0
# 519679        1                                    11               0
# 519961        1                                    11               0
#
#                              auction_month market_month  \
# constraint_id flow_direction
# 391448        1                 2026-01-01   2026-01-01
# 429694        1                 2026-01-01   2026-01-01
# 519679        1                 2026-01-01   2026-01-01
# 519961        1                 2026-01-01   2026-01-01
#
#                                                    model_used  \
# constraint_id flow_direction
# 391448        1                   Never-Binding: ZACH     TR1
# 429694        1               Never-Binding: ZACH_ADIR_7671 A
# 519679        1                     Default CLF + Default REG
# 519961        1                     Default CLF + Default REG
#
#                               predicted_binding        error    abs_error
# constraint_id flow_direction
# 391448        1                           False     0.000000     0.000000
# 429694        1                           False     0.000000     0.000000
# 519679        1                            True  2604.065964  2604.065964
# 519961        1                            True  2604.065964  2604.065964

# %%
# 4. Run Pipeline
results_per_outage, final_results, metrics, training_res, models = pipeline.run(
    test_periods=test_periods,
    verbose=True,
    use_parallel=True,
    n_jobs=36,
    output_dir='/opt/temp/tmp/pw_data/spice6/prod_f0p_model_pjm/ml_pred/', # Separate output dir for PJM
    refresh=True,
    class_type='dailyoffpeak',
    branch_name=None,
)
