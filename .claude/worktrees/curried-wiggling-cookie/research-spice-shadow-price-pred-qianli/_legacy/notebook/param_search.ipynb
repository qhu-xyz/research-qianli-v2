# %% [markdown]
# # Pipeline Hyperparameter Tuning (Parallel)
#
# This notebook performs hyperparameter tuning on the **entire pipeline** using **parallel processing**.
# It iterates through different parameter combinations, runs the full pipeline for specified test periods in parallel, and saves all results.
#
# **Test Periods:**
# - 2025-09 (Auction) / 2025-09 (Market)
# - 2025-10 (Auction) / 2025-10 (Market)
#
# **Output Structure:**
# - `/opt/temp/haoyan/param_search/`
#     - `metrics/`: Parquet files containing parameters and key metrics.
#     - `per_outage/`: Parquet files containing per-outage prediction results.
#     - `agg/`: Parquet files containing monthly aggregated prediction results.

# %%
from pbase.config.ray import init_ray
import shadow_price_prediction

# Initialize Ray for parallel processing
extra_modules = [shadow_price_prediction]
init_ray(address='ray://10.8.0.36:10001', extra_modules=extra_modules)

import pandas as pd
import numpy as np
import random
from pathlib import Path
from pbase.utils.ray import parallel_equal_pool

# Import tuning utilities for resumable search
from shadow_price_prediction.tuning_utils import (
    load_previous_params,
    sample_params,
    run_single_experiment
)

pd.set_option('display.max_columns', 99)
# Out:
# 2025-11-19 21:35:13,768	INFO client_builder.py:242 -- Passing the following kwargs to ray.init() on the server: log_to_driver
# 2025-11-19 21:35:14,288	INFO packaging.py:588 -- Creating a file package for local module '/home/xyz/workspace/pbase/src/pbase'.
# 2025-11-19 21:35:14,485	INFO packaging.py:380 -- Pushing file package 'gcs://_ray_pkg_99f88ab2ee9d98c2.zip' (8.64MiB) to Ray cluster...
# 2025-11-19 21:35:14,543	INFO packaging.py:393 -- Successfully pushed file package 'gcs://_ray_pkg_99f88ab2ee9d98c2.zip'.
# 2025-11-19 21:35:14,550	INFO packaging.py:588 -- Creating a file package for local module '/home/xyz/workspace/research-spice-shadow-price-pred/src/shadow_price_prediction'.
# 2025-11-19 21:35:14,554	INFO packaging.py:380 -- Pushing file package 'gcs://_ray_pkg_97a0c930ad95ed14.zip' (0.24MiB) to Ray cluster...
# 2025-11-19 21:35:14,557	INFO packaging.py:393 -- Successfully pushed file package 'gcs://_ray_pkg_97a0c930ad95ed14.zip'.
# SIGTERM handler is not set because current thread is not the main thread.

# %% [markdown]
# ## 1. Define Parameter Search Space
# Define the grid of parameters to sample from.

# %%
param_grid = {
    # XGBoost Params (shared between classifier and regressor)
    'clf_xgb_n_estimators': [100, 200, 300, 500],
    'clf_xgb_max_depth': [3, 4, 5, 6],
    'clf_xgb_learning_rate': [0.05, 0.1, 0.2],
    'clf_xgb_gamma': [0, 0.1, 0.2],
    'clf_xgb_min_child_weight': [1, 5, 10],
    'clf_xgb_reg_alpha': [0, 0.1, 1.0],
    'clf_xgb_reg_lambda': [1, 10, 100],

    'reg_xgb_n_estimators': [100, 200, 300, 500],
    'reg_xgb_max_depth': [3, 4, 5, 6],
    'reg_xgb_learning_rate': [0.05, 0.1, 0.2],
    'reg_xgb_gamma': [0, 0.1, 0.2],
    'reg_xgb_min_child_weight': [1, 5, 10],
    'reg_xgb_reg_alpha': [0, 0.1, 1.0],
    'reg_xgb_reg_lambda': [1, 10, 100],
    
    # Logistic Regression Params
    'lr_penalty': ['l2'],
    'lr_C': [0.1, 1.0, 10.0],
    
    # ElasticNet Params
    'enet_alpha': [0.1, 1.0, 10.0],
    'enet_l1_ratio': [0.1, 0.5, 0.9],
    
    # Threshold Config
    'threshold_beta': [0.1, 0.5, 1.0, 2.0, 3.0],
    
    # Ensemble weights
    'clf_xgb_thres': [0.3, 0.5, 0.7],
    'reg_xgb_thres': [0.3, 0.5, 0.7],
}

# Calculate total combinations
total_combinations = 1
for values in param_grid.values():
    total_combinations *= len(values)
    
print(f"Total possible parameter combinations: {total_combinations:,}")
# Out:
# Total possible parameter combinations: 18,366,600,960

# %% [markdown]
# # Configuration & Resume Previous Search

# %%
N_ITER = 10000  # Total number of experiments to run (including previous ones)
BASE_OUTPUT_DIR = Path('/opt/temp/haoyan/param_search_new')

# Define Test Periods
TEST_PERIODS = [
    (pd.Timestamp('2025-07-01'), pd.Timestamp('2025-07-01')),
    (pd.Timestamp('2025-08-01'), pd.Timestamp('2025-08-01')),
    (pd.Timestamp('2025-09-01'), pd.Timestamp('2025-09-01')),
    (pd.Timestamp('2025-10-01'), pd.Timestamp('2025-10-01')),
]

# Load previously searched parameters
seen_params = load_previous_params(BASE_OUTPUT_DIR)

if seen_params:
    print(f"✓ Resuming: {len(seen_params)} combinations already tested")
    remaining_iterations = N_ITER - len(seen_params)
    
    if remaining_iterations <= 0:
        print(f"\n✓ All {N_ITER} experiments completed!")
        print("  To run more, increase N_ITER.")
    else:
        print(f"  Will run {remaining_iterations} more experiments")
else:
    print("✓ Starting fresh search")
    remaining_iterations = N_ITER
# Out:
# Metrics directory /opt/temp/haoyan/param_search_new/metrics does not exist. Starting fresh.
# ✓ Starting fresh search

# %% [markdown]
# ## 3. Prepare Experiments

# %%
if remaining_iterations > 0:
    print(f"Preparing {remaining_iterations} new experiments...")
    print("Pre-sampling parameters to ensure uniqueness...")
    
    # PRE-SAMPLE all parameters sequentially to ensure uniqueness
    sampled_params_list = []
    for i in range(remaining_iterations):
        iteration_idx = len(seen_params) + i
        
        # Sample parameters (this updates seen_params)
        params = sample_params(param_grid, seen_params)
        sampled_params_list.append((iteration_idx, params))
    
    print(f"✓ Sampled {len(sampled_params_list)} unique parameter combinations")
    
    # Now prepare experiment tuples with PRE-SAMPLED parameters
    experiment_params = []
    for iteration_idx, params in sampled_params_list:
        experiment_params.append({
            'iteration': iteration_idx,
            'params': params,
            'test_periods': TEST_PERIODS,
            'save_dir': BASE_OUTPUT_DIR
        })
    
    print(f"✓ Prepared {len(experiment_params)} experiments")
    print(f"  Output: {BASE_OUTPUT_DIR}")
# Out:
# Preparing 10000 new experiments...
# Pre-sampling parameters to ensure uniqueness...
# ✓ Sampled 10000 unique parameter combinations
# ✓ Prepared 10000 experiments
#   Output: /opt/temp/haoyan/param_search_new

# %% [markdown]
# ## 4. Run Parallel Execution

# %%
n_jobs = 12

if remaining_iterations > 0:
    print(f"Starting parallel execution with {min(remaining_iterations, n_jobs)} jobs...")
    
    results = parallel_equal_pool(
        func=run_single_experiment,
        param_dict_list=experiment_params,
        n_jobs=min(remaining_iterations, n_jobs),
        param_serialization='default',
        raise_error=False,
        use_tqdm=True
    )
    
    # Summary
    success_count = sum(1 for r in results if r['status'] == 'success')
    error_count = sum(1 for r in results if r['status'] == 'failed')
    
    print(f"\nExecution Complete!")
    print(f"  Successful: {success_count}")
    print(f"  Failed: {error_count}")
    print(f"  Total completed: {len(seen_params) + success_count} / {N_ITER}")
    
    if error_count > 0:
        print("\nErrors:")
        for r in results:
            if r['status'] == 'failed':
                print(f"  Iteration {r['iteration']}: {r.get('error', 'Unknown')}")
# Out:
# Starting parallel execution with 12 jobs...
#   0%|          | 0/10000 [00:00<?, ?it/s]
# (PoolActor pid=345197, ip=10.42.8.15) 25-11-19 21:35:29 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=345197, ip=10.42.8.15) 25-11-19 21:35:29 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=345197, ip=10.42.8.15) 25-11-19 21:35:29 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=345197, ip=10.42.8.15) 25-11-19 21:35:29 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=345196, ip=10.42.8.15) 25-11-19 21:35:29 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=345196, ip=10.42.8.15) 25-11-19 21:35:29 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=345196, ip=10.42.8.15) 25-11-19 21:35:29 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=345196, ip=10.42.8.15) 25-11-19 21:35:29 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=509987, ip=10.42.6.149) 25-11-19 21:35:29 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=509987, ip=10.42.6.149) 25-11-19 21:35:29 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=509987, ip=10.42.6.149) 25-11-19 21:35:29 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=509987, ip=10.42.6.149) 25-11-19 21:35:29 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=509988, ip=10.42.6.149) 25-11-19 21:35:29 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=509988, ip=10.42.6.149) 25-11-19 21:35:29 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=509988, ip=10.42.6.149) 25-11-19 21:35:29 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=509988, ip=10.42.6.149) 25-11-19 21:35:29 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=357478, ip=10.42.4.173) 25-11-19 21:35:29 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=357478, ip=10.42.4.173) 25-11-19 21:35:29 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=357478, ip=10.42.4.173) 25-11-19 21:35:29 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=357478, ip=10.42.4.173) 25-11-19 21:35:29 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=357479, ip=10.42.4.173) 25-11-19 21:35:29 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=357479, ip=10.42.4.173) 25-11-19 21:35:29 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=357479, ip=10.42.4.173) 25-11-19 21:35:29 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=357479, ip=10.42.4.173) 25-11-19 21:35:29 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=286964, ip=10.42.7.70) 25-11-19 21:35:29 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=286964, ip=10.42.7.70) 25-11-19 21:35:29 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=286964, ip=10.42.7.70) 25-11-19 21:35:29 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=286964, ip=10.42.7.70) 25-11-19 21:35:29 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=286965, ip=10.42.7.70) 25-11-19 21:35:29 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=286965, ip=10.42.7.70) 25-11-19 21:35:29 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=286965, ip=10.42.7.70) 25-11-19 21:35:29 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=286965, ip=10.42.7.70) 25-11-19 21:35:29 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=283860, ip=10.42.0.182) 25-11-19 21:35:29 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=283860, ip=10.42.0.182) 25-11-19 21:35:29 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=283860, ip=10.42.0.182) 25-11-19 21:35:29 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=283860, ip=10.42.0.182) 25-11-19 21:35:29 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=283859, ip=10.42.0.182) 25-11-19 21:35:29 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=283859, ip=10.42.0.182) 25-11-19 21:35:29 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=283859, ip=10.42.0.182) 25-11-19 21:35:29 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=283859, ip=10.42.0.182) 25-11-19 21:35:29 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=343020, ip=10.42.9.131) 25-11-19 21:35:29 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=343020, ip=10.42.9.131) 25-11-19 21:35:29 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=343020, ip=10.42.9.131) 25-11-19 21:35:29 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=343020, ip=10.42.9.131) 25-11-19 21:35:29 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=343019, ip=10.42.9.131) 25-11-19 21:35:29 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=343019, ip=10.42.9.131) 25-11-19 21:35:29 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=343019, ip=10.42.9.131) 25-11-19 21:35:29 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=343019, ip=10.42.9.131) 25-11-19 21:35:29 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=345197, ip=10.42.8.15) 25-11-19 21:35:29 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #321 | Ray is installed, version: 2.47.0
# (PoolActor pid=345197, ip=10.42.8.15) 25-11-19 21:35:29 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #459 | RAY_ADDRESS is set to 'ray://ray-head:10001', using ray (ignore 'no_ray (False)')...
# (PoolActor pid=345197, ip=10.42.8.15) 25-11-19 21:35:29 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #478 | Do 4 tasks [Called by: ..._ray_pkg_97a0c930ad95ed14/shadow_price_prediction/pipeline.py - run(...) #286] parallelly in ray 2 processes...
# (PoolActor pid=345197, ip=10.42.8.15) 25-11-19 21:35:29 EST | INFO    | /tmp/ray/session_2025-11-16_14-43-18_409267_1/runtime_resources/py_modules_files/_ray_pkg_99f88ab2ee9d98c2/pbase/config/ray.py | init_ray            | #42  | ray is already initialized, skipping init_ray
# (PoolActor pid=345196, ip=10.42.8.15) 25-11-19 21:35:29 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #321 | Ray is installed, version: 2.47.0
# (PoolActor pid=345196, ip=10.42.8.15) 25-11-19 21:35:29 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #459 | RAY_ADDRESS is set to 'ray://ray-head:10001', using ray (ignore 'no_ray (False)')...
# (PoolActor pid=345196, ip=10.42.8.15) 25-11-19 21:35:29 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #478 | Do 4 tasks [Called by: ..._ray_pkg_97a0c930ad95ed14/shadow_price_prediction/pipeline.py - run(...) #286] parallelly in ray 2 processes...
# (PoolActor pid=345196, ip=10.42.8.15) 25-11-19 21:35:29 EST | INFO    | /tmp/ray/session_2025-11-16_14-43-18_409267_1/runtime_resources/py_modules_files/_ray_pkg_99f88ab2ee9d98c2/pbase/config/ray.py | init_ray            | #42  | ray is already initialized, skipping init_ray
# (PoolActor pid=509988, ip=10.42.6.149) 25-11-19 21:35:29 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #321 | Ray is installed, version: 2.47.0
# (PoolActor pid=509988, ip=10.42.6.149) 25-11-19 21:35:29 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #459 | RAY_ADDRESS is set to 'ray://ray-head:10001', using ray (ignore 'no_ray (False)')...
# (PoolActor pid=509988, ip=10.42.6.149) 25-11-19 21:35:29 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #478 | Do 4 tasks [Called by: ..._ray_pkg_97a0c930ad95ed14/shadow_price_prediction/pipeline.py - run(...) #286] parallelly in ray 2 processes...
# (PoolActor pid=509988, ip=10.42.6.149) 25-11-19 21:35:29 EST | INFO    | /tmp/ray/session_2025-11-16_14-43-18_409267_1/runtime_resources/py_modules_files/_ray_pkg_99f88ab2ee9d98c2/pbase/config/ray.py | init_ray            | #42  | ray is already initialized, skipping init_ray
# (PoolActor pid=283860, ip=10.42.0.182) 25-11-19 21:35:29 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #321 | Ray is installed, version: 2.47.0
# (PoolActor pid=283860, ip=10.42.0.182) 25-11-19 21:35:29 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #459 | RAY_ADDRESS is set to 'ray://ray-head:10001', using ray (ignore 'no_ray (False)')...
# (PoolActor pid=283860, ip=10.42.0.182) 25-11-19 21:35:29 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #478 | Do 4 tasks [Called by: ..._ray_pkg_97a0c930ad95ed14/shadow_price_prediction/pipeline.py - run(...) #286] parallelly in ray 2 processes...
# (PoolActor pid=283860, ip=10.42.0.182) 25-11-19 21:35:29 EST | INFO    | /tmp/ray/session_2025-11-16_14-43-18_409267_1/runtime_resources/py_modules_files/_ray_pkg_99f88ab2ee9d98c2/pbase/config/ray.py | init_ray            | #42  | ray is already initialized, skipping init_ray
# (PoolActor pid=509987, ip=10.42.6.149) 25-11-19 21:35:29 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #321 | Ray is installed, version: 2.47.0
# (PoolActor pid=509987, ip=10.42.6.149) 25-11-19 21:35:29 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #459 | RAY_ADDRESS is set to 'ray://ray-head:10001', using ray (ignore 'no_ray (False)')...
# (PoolActor pid=509987, ip=10.42.6.149) 25-11-19 21:35:29 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #478 | Do 4 tasks [Called by: ..._ray_pkg_97a0c930ad95ed14/shadow_price_prediction/pipeline.py - run(...) #286] parallelly in ray 2 processes...
# (PoolActor pid=509987, ip=10.42.6.149) 25-11-19 21:35:29 EST | INFO    | /tmp/ray/session_2025-11-16_14-43-18_409267_1/runtime_resources/py_modules_files/_ray_pkg_99f88ab2ee9d98c2/pbase/config/ray.py | init_ray            | #42  | ray is already initialized, skipping init_ray
# (PoolActor pid=343020, ip=10.42.9.131) 25-11-19 21:35:29 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #321 | Ray is installed, version: 2.47.0
# (PoolActor pid=343020, ip=10.42.9.131) 25-11-19 21:35:29 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #459 | RAY_ADDRESS is set to 'ray://ray-head:10001', using ray (ignore 'no_ray (False)')...
# (PoolActor pid=343020, ip=10.42.9.131) 25-11-19 21:35:29 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #478 | Do 4 tasks [Called by: ..._ray_pkg_97a0c930ad95ed14/shadow_price_prediction/pipeline.py - run(...) #286] parallelly in ray 2 processes...
# (PoolActor pid=343020, ip=10.42.9.131) 25-11-19 21:35:29 EST | INFO    | /tmp/ray/session_2025-11-16_14-43-18_409267_1/runtime_resources/py_modules_files/_ray_pkg_99f88ab2ee9d98c2/pbase/config/ray.py | init_ray            | #42  | ray is already initialized, skipping init_ray
# (PoolActor pid=343019, ip=10.42.9.131) 25-11-19 21:35:29 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #321 | Ray is installed, version: 2.47.0
# (PoolActor pid=343019, ip=10.42.9.131) 25-11-19 21:35:29 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #459 | RAY_ADDRESS is set to 'ray://ray-head:10001', using ray (ignore 'no_ray (False)')...
# (PoolActor pid=343019, ip=10.42.9.131) 25-11-19 21:35:29 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #478 | Do 4 tasks [Called by: ..._ray_pkg_97a0c930ad95ed14/shadow_price_prediction/pipeline.py - run(...) #286] parallelly in ray 2 processes...
# (PoolActor pid=343019, ip=10.42.9.131) 25-11-19 21:35:29 EST | INFO    | /tmp/ray/session_2025-11-16_14-43-18_409267_1/runtime_resources/py_modules_files/_ray_pkg_99f88ab2ee9d98c2/pbase/config/ray.py | init_ray            | #42  | ray is already initialized, skipping init_ray
# (PoolActor pid=357479, ip=10.42.4.173) 25-11-19 21:35:29 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #321 | Ray is installed, version: 2.47.0
# (PoolActor pid=357479, ip=10.42.4.173) 25-11-19 21:35:29 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #459 | RAY_ADDRESS is set to 'ray://ray-head:10001', using ray (ignore 'no_ray (False)')...
# (PoolActor pid=357479, ip=10.42.4.173) 25-11-19 21:35:29 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #478 | Do 4 tasks [Called by: ..._ray_pkg_97a0c930ad95ed14/shadow_price_prediction/pipeline.py - run(...) #286] parallelly in ray 2 processes...
# (PoolActor pid=357479, ip=10.42.4.173) 25-11-19 21:35:29 EST | INFO    | /tmp/ray/session_2025-11-16_14-43-18_409267_1/runtime_resources/py_modules_files/_ray_pkg_99f88ab2ee9d98c2/pbase/config/ray.py | init_ray            | #42  | ray is already initialized, skipping init_ray
# (PoolActor pid=357478, ip=10.42.4.173) 25-11-19 21:35:29 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #321 | Ray is installed, version: 2.47.0
# (PoolActor pid=357478, ip=10.42.4.173) 25-11-19 21:35:29 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #459 | RAY_ADDRESS is set to 'ray://ray-head:10001', using ray (ignore 'no_ray (False)')...
# (PoolActor pid=357478, ip=10.42.4.173) 25-11-19 21:35:29 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #478 | Do 4 tasks [Called by: ..._ray_pkg_97a0c930ad95ed14/shadow_price_prediction/pipeline.py - run(...) #286] parallelly in ray 2 processes...
# (PoolActor pid=357478, ip=10.42.4.173) 25-11-19 21:35:29 EST | INFO    | /tmp/ray/session_2025-11-16_14-43-18_409267_1/runtime_resources/py_modules_files/_ray_pkg_99f88ab2ee9d98c2/pbase/config/ray.py | init_ray            | #42  | ray is already initialized, skipping init_ray
# (PoolActor pid=286964, ip=10.42.7.70) 25-11-19 21:35:29 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #321 | Ray is installed, version: 2.47.0
# (PoolActor pid=286964, ip=10.42.7.70) 25-11-19 21:35:29 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #459 | RAY_ADDRESS is set to 'ray://ray-head:10001', using ray (ignore 'no_ray (False)')...
# (PoolActor pid=286964, ip=10.42.7.70) 25-11-19 21:35:29 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #478 | Do 4 tasks [Called by: ..._ray_pkg_97a0c930ad95ed14/shadow_price_prediction/pipeline.py - run(...) #286] parallelly in ray 2 processes...
# (PoolActor pid=286964, ip=10.42.7.70) 25-11-19 21:35:29 EST | INFO    | /tmp/ray/session_2025-11-16_14-43-18_409267_1/runtime_resources/py_modules_files/_ray_pkg_99f88ab2ee9d98c2/pbase/config/ray.py | init_ray            | #42  | ray is already initialized, skipping init_ray
# (PoolActor pid=286965, ip=10.42.7.70) 25-11-19 21:35:29 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #321 | Ray is installed, version: 2.47.0
# (PoolActor pid=286965, ip=10.42.7.70) 25-11-19 21:35:29 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #459 | RAY_ADDRESS is set to 'ray://ray-head:10001', using ray (ignore 'no_ray (False)')...
# (PoolActor pid=286965, ip=10.42.7.70) 25-11-19 21:35:29 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #478 | Do 4 tasks [Called by: ..._ray_pkg_97a0c930ad95ed14/shadow_price_prediction/pipeline.py - run(...) #286] parallelly in ray 2 processes...
# (PoolActor pid=286965, ip=10.42.7.70) 25-11-19 21:35:29 EST | INFO    | /tmp/ray/session_2025-11-16_14-43-18_409267_1/runtime_resources/py_modules_files/_ray_pkg_99f88ab2ee9d98c2/pbase/config/ray.py | init_ray            | #42  | ray is already initialized, skipping init_ray
# (PoolActor pid=283859, ip=10.42.0.182) 25-11-19 21:35:29 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #321 | Ray is installed, version: 2.47.0
# (PoolActor pid=283859, ip=10.42.0.182) 25-11-19 21:35:29 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #459 | RAY_ADDRESS is set to 'ray://ray-head:10001', using ray (ignore 'no_ray (False)')...
# (PoolActor pid=283859, ip=10.42.0.182) 25-11-19 21:35:29 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #478 | Do 4 tasks [Called by: ..._ray_pkg_97a0c930ad95ed14/shadow_price_prediction/pipeline.py - run(...) #286] parallelly in ray 2 processes...
# (PoolActor pid=283859, ip=10.42.0.182) 25-11-19 21:35:29 EST | INFO    | /tmp/ray/session_2025-11-16_14-43-18_409267_1/runtime_resources/py_modules_files/_ray_pkg_99f88ab2ee9d98c2/pbase/config/ray.py | init_ray            | #42  | ray is already initialized, skipping init_ray
# (PoolActor pid=284013, ip=10.42.0.182) 25-11-19 21:35:30 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=284013, ip=10.42.0.182) 25-11-19 21:35:30 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=284013, ip=10.42.0.182) 25-11-19 21:35:30 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=284013, ip=10.42.0.182) 25-11-19 21:35:30 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=510141, ip=10.42.6.149) 25-11-19 21:35:30 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=510141, ip=10.42.6.149) 25-11-19 21:35:30 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=510141, ip=10.42.6.149) 25-11-19 21:35:30 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=510141, ip=10.42.6.149) 25-11-19 21:35:30 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=357632, ip=10.42.4.173) 25-11-19 21:35:30 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=357632, ip=10.42.4.173) 25-11-19 21:35:30 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=357632, ip=10.42.4.173) 25-11-19 21:35:30 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=357632, ip=10.42.4.173) 25-11-19 21:35:30 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=287119, ip=10.42.7.70) 25-11-19 21:35:30 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=287119, ip=10.42.7.70) 25-11-19 21:35:30 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=287119, ip=10.42.7.70) 25-11-19 21:35:30 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=287119, ip=10.42.7.70) 25-11-19 21:35:30 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=287118, ip=10.42.7.70) 25-11-19 21:35:30 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=287118, ip=10.42.7.70) 25-11-19 21:35:30 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=287118, ip=10.42.7.70) 25-11-19 21:35:30 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=287118, ip=10.42.7.70) 25-11-19 21:35:30 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=284014, ip=10.42.0.182) 25-11-19 21:35:30 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=284014, ip=10.42.0.182) 25-11-19 21:35:30 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=284014, ip=10.42.0.182) 25-11-19 21:35:30 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=284014, ip=10.42.0.182) 25-11-19 21:35:30 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=510147, ip=10.42.6.149) 25-11-19 21:35:30 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=510147, ip=10.42.6.149) 25-11-19 21:35:30 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=510147, ip=10.42.6.149) 25-11-19 21:35:30 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=510147, ip=10.42.6.149) 25-11-19 21:35:30 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=510148, ip=10.42.6.149) 25-11-19 21:35:30 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=510148, ip=10.42.6.149) 25-11-19 21:35:30 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=510148, ip=10.42.6.149) 25-11-19 21:35:30 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=510148, ip=10.42.6.149) 25-11-19 21:35:30 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=510152, ip=10.42.6.149) 25-11-19 21:35:30 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=510152, ip=10.42.6.149) 25-11-19 21:35:30 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=510152, ip=10.42.6.149) 25-11-19 21:35:30 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=510152, ip=10.42.6.149) 25-11-19 21:35:30 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=510146, ip=10.42.6.149) 25-11-19 21:35:30 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=510146, ip=10.42.6.149) 25-11-19 21:35:30 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=510146, ip=10.42.6.149) 25-11-19 21:35:30 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=510146, ip=10.42.6.149) 25-11-19 21:35:30 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=357639, ip=10.42.4.173) 25-11-19 21:35:30 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=357639, ip=10.42.4.173) 25-11-19 21:35:30 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=357639, ip=10.42.4.173) 25-11-19 21:35:30 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=357639, ip=10.42.4.173) 25-11-19 21:35:30 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=357638, ip=10.42.4.173) 25-11-19 21:35:30 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=357638, ip=10.42.4.173) 25-11-19 21:35:30 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=357638, ip=10.42.4.173) 25-11-19 21:35:30 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=357638, ip=10.42.4.173) 25-11-19 21:35:30 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=357633, ip=10.42.4.173) 25-11-19 21:35:30 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=357633, ip=10.42.4.173) 25-11-19 21:35:30 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=357633, ip=10.42.4.173) 25-11-19 21:35:30 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=357633, ip=10.42.4.173) 25-11-19 21:35:30 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=284017, ip=10.42.0.182) 25-11-19 21:35:30 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=284017, ip=10.42.0.182) 25-11-19 21:35:30 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=284017, ip=10.42.0.182) 25-11-19 21:35:30 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=284017, ip=10.42.0.182) 25-11-19 21:35:30 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=510153, ip=10.42.6.149) 25-11-19 21:35:30 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=510153, ip=10.42.6.149) 25-11-19 21:35:30 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=510153, ip=10.42.6.149) 25-11-19 21:35:30 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=510153, ip=10.42.6.149) 25-11-19 21:35:30 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=357640, ip=10.42.4.173) 25-11-19 21:35:30 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=357640, ip=10.42.4.173) 25-11-19 21:35:30 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=357640, ip=10.42.4.173) 25-11-19 21:35:30 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=357640, ip=10.42.4.173) 25-11-19 21:35:30 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=357641, ip=10.42.4.173) 25-11-19 21:35:30 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=357641, ip=10.42.4.173) 25-11-19 21:35:30 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=357641, ip=10.42.4.173) 25-11-19 21:35:30 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=357641, ip=10.42.4.173) 25-11-19 21:35:30 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=287126, ip=10.42.7.70) 25-11-19 21:35:30 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=287126, ip=10.42.7.70) 25-11-19 21:35:30 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=287126, ip=10.42.7.70) 25-11-19 21:35:30 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=287126, ip=10.42.7.70) 25-11-19 21:35:30 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=287124, ip=10.42.7.70) 25-11-19 21:35:30 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=287124, ip=10.42.7.70) 25-11-19 21:35:30 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=287124, ip=10.42.7.70) 25-11-19 21:35:30 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=287124, ip=10.42.7.70) 25-11-19 21:35:30 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=287125, ip=10.42.7.70) 25-11-19 21:35:30 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=287125, ip=10.42.7.70) 25-11-19 21:35:30 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=287125, ip=10.42.7.70) 25-11-19 21:35:30 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=287125, ip=10.42.7.70) 25-11-19 21:35:30 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=287127, ip=10.42.7.70) 25-11-19 21:35:30 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=287127, ip=10.42.7.70) 25-11-19 21:35:30 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=287127, ip=10.42.7.70) 25-11-19 21:35:30 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=287127, ip=10.42.7.70) 25-11-19 21:35:30 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=284018, ip=10.42.0.182) 25-11-19 21:35:30 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=284018, ip=10.42.0.182) 25-11-19 21:35:30 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=284018, ip=10.42.0.182) 25-11-19 21:35:30 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=284018, ip=10.42.0.182) 25-11-19 21:35:30 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=284021, ip=10.42.0.182) 25-11-19 21:35:30 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=284021, ip=10.42.0.182) 25-11-19 21:35:30 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=284021, ip=10.42.0.182) 25-11-19 21:35:30 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=284021, ip=10.42.0.182) 25-11-19 21:35:30 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=284022, ip=10.42.0.182) 25-11-19 21:35:30 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=284022, ip=10.42.0.182) 25-11-19 21:35:30 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=284022, ip=10.42.0.182) 25-11-19 21:35:30 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=284022, ip=10.42.0.182) 25-11-19 21:35:30 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# 100%|██████████| 4/4 [00:00<00:00, 87381.33it/s]
# 100%|██████████| 4/4 [00:00<00:00, 176602.27it/s]
# 100%|██████████| 4/4 [00:00<00:00, 172960.99it/s]
# 100%|██████████| 4/4 [00:00<00:00, 120699.40it/s]
# (PoolActor pid=509987, ip=10.42.6.149) 25-11-19 21:45:42 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #321 | Ray is installed, version: 2.47.0
# (PoolActor pid=509987, ip=10.42.6.149) 25-11-19 21:45:42 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #459 | RAY_ADDRESS is set to 'ray://ray-head:10001', using ray (ignore 'no_ray (False)')...
# (PoolActor pid=509987, ip=10.42.6.149) 25-11-19 21:45:42 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #478 | Do 4 tasks [Called by: ..._ray_pkg_97a0c930ad95ed14/shadow_price_prediction/pipeline.py - run(...) #286] parallelly in ray 2 processes...
# (PoolActor pid=509987, ip=10.42.6.149) 25-11-19 21:45:42 EST | INFO    | /tmp/ray/session_2025-11-16_14-43-18_409267_1/runtime_resources/py_modules_files/_ray_pkg_99f88ab2ee9d98c2/pbase/config/ray.py | init_ray            | #42  | ray is already initialized, skipping init_ray
# (PoolActor pid=345358, ip=10.42.8.15) 25-11-19 21:45:43 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=345358, ip=10.42.8.15) 25-11-19 21:45:43 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=345358, ip=10.42.8.15) 25-11-19 21:45:43 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=345358, ip=10.42.8.15) 25-11-19 21:45:43 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=343182, ip=10.42.9.131) 25-11-19 21:45:43 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=343182, ip=10.42.9.131) 25-11-19 21:45:43 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=343182, ip=10.42.9.131) 25-11-19 21:45:43 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=343182, ip=10.42.9.131) 25-11-19 21:45:43 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# 100%|██████████| 4/4 [00:00<00:00, 129055.51it/s]
# (PoolActor pid=283859, ip=10.42.0.182) 25-11-19 21:45:53 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #321 | Ray is installed, version: 2.47.0
# (PoolActor pid=283859, ip=10.42.0.182) 25-11-19 21:45:53 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #459 | RAY_ADDRESS is set to 'ray://ray-head:10001', using ray (ignore 'no_ray (False)')...
# (PoolActor pid=283859, ip=10.42.0.182) 25-11-19 21:45:53 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #478 | Do 4 tasks [Called by: ..._ray_pkg_97a0c930ad95ed14/shadow_price_prediction/pipeline.py - run(...) #286] parallelly in ray 2 processes...
# (PoolActor pid=283859, ip=10.42.0.182) 25-11-19 21:45:53 EST | INFO    | /tmp/ray/session_2025-11-16_14-43-18_409267_1/runtime_resources/py_modules_files/_ray_pkg_99f88ab2ee9d98c2/pbase/config/ray.py | init_ray            | #42  | ray is already initialized, skipping init_ray
# (PoolActor pid=345196, ip=10.42.8.15) 25-11-19 21:45:53 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #321 | Ray is installed, version: 2.47.0
# (PoolActor pid=345196, ip=10.42.8.15) 25-11-19 21:45:53 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #459 | RAY_ADDRESS is set to 'ray://ray-head:10001', using ray (ignore 'no_ray (False)')...
# (PoolActor pid=345196, ip=10.42.8.15) 25-11-19 21:45:53 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #478 | Do 4 tasks [Called by: ..._ray_pkg_97a0c930ad95ed14/shadow_price_prediction/pipeline.py - run(...) #286] parallelly in ray 2 processes...
# (PoolActor pid=345196, ip=10.42.8.15) 25-11-19 21:45:53 EST | INFO    | /tmp/ray/session_2025-11-16_14-43-18_409267_1/runtime_resources/py_modules_files/_ray_pkg_99f88ab2ee9d98c2/pbase/config/ray.py | init_ray            | #42  | ray is already initialized, skipping init_ray
# (PoolActor pid=345445, ip=10.42.8.15) 25-11-19 21:45:54 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=345445, ip=10.42.8.15) 25-11-19 21:45:54 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=345445, ip=10.42.8.15) 25-11-19 21:45:54 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=345445, ip=10.42.8.15) 25-11-19 21:45:54 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=345444, ip=10.42.8.15) 25-11-19 21:45:54 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=345444, ip=10.42.8.15) 25-11-19 21:45:54 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=345444, ip=10.42.8.15) 25-11-19 21:45:54 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=345444, ip=10.42.8.15) 25-11-19 21:45:54 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=343268, ip=10.42.9.131) 25-11-19 21:45:54 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=343268, ip=10.42.9.131) 25-11-19 21:45:54 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=343268, ip=10.42.9.131) 25-11-19 21:45:54 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=343268, ip=10.42.9.131) 25-11-19 21:45:54 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=343269, ip=10.42.9.131) 25-11-19 21:45:54 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=343269, ip=10.42.9.131) 25-11-19 21:45:54 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=343269, ip=10.42.9.131) 25-11-19 21:45:54 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=343269, ip=10.42.9.131) 25-11-19 21:45:54 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# 100%|██████████| 4/4 [00:00<00:00, 180400.17it/s]
# (PoolActor pid=286964, ip=10.42.7.70) 25-11-19 21:47:01 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #321 | Ray is installed, version: 2.47.0
# (PoolActor pid=286964, ip=10.42.7.70) 25-11-19 21:47:01 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #459 | RAY_ADDRESS is set to 'ray://ray-head:10001', using ray (ignore 'no_ray (False)')...
# (PoolActor pid=286964, ip=10.42.7.70) 25-11-19 21:47:01 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #478 | Do 4 tasks [Called by: ..._ray_pkg_97a0c930ad95ed14/shadow_price_prediction/pipeline.py - run(...) #286] parallelly in ray 2 processes...
# (PoolActor pid=286964, ip=10.42.7.70) 25-11-19 21:47:01 EST | INFO    | /tmp/ray/session_2025-11-16_14-43-18_409267_1/runtime_resources/py_modules_files/_ray_pkg_99f88ab2ee9d98c2/pbase/config/ray.py | init_ray            | #42  | ray is already initialized, skipping init_ray
# (PoolActor pid=345618, ip=10.42.8.15) 25-11-19 21:47:02 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=345618, ip=10.42.8.15) 25-11-19 21:47:02 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=345618, ip=10.42.8.15) 25-11-19 21:47:02 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=345618, ip=10.42.8.15) 25-11-19 21:47:02 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=343441, ip=10.42.9.131) 25-11-19 21:47:02 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=343441, ip=10.42.9.131) 25-11-19 21:47:02 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=343441, ip=10.42.9.131) 25-11-19 21:47:02 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=343441, ip=10.42.9.131) 25-11-19 21:47:02 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# 100%|██████████| 4/4 [00:00<00:00, 109655.01it/s]
# (PoolActor pid=357479, ip=10.42.4.173) 25-11-19 21:47:49 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #321 | Ray is installed, version: 2.47.0
# (PoolActor pid=357479, ip=10.42.4.173) 25-11-19 21:47:49 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #459 | RAY_ADDRESS is set to 'ray://ray-head:10001', using ray (ignore 'no_ray (False)')...
# (PoolActor pid=357479, ip=10.42.4.173) 25-11-19 21:47:49 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #478 | Do 4 tasks [Called by: ..._ray_pkg_97a0c930ad95ed14/shadow_price_prediction/pipeline.py - run(...) #286] parallelly in ray 2 processes...
# (PoolActor pid=357479, ip=10.42.4.173) 25-11-19 21:47:49 EST | INFO    | /tmp/ray/session_2025-11-16_14-43-18_409267_1/runtime_resources/py_modules_files/_ray_pkg_99f88ab2ee9d98c2/pbase/config/ray.py | init_ray            | #42  | ray is already initialized, skipping init_ray
# (PoolActor pid=345705, ip=10.42.8.15) 25-11-19 21:47:50 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=345705, ip=10.42.8.15) 25-11-19 21:47:50 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=345705, ip=10.42.8.15) 25-11-19 21:47:50 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=345705, ip=10.42.8.15) 25-11-19 21:47:50 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=343528, ip=10.42.9.131) 25-11-19 21:47:50 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=343528, ip=10.42.9.131) 25-11-19 21:47:50 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=343528, ip=10.42.9.131) 25-11-19 21:47:50 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=343528, ip=10.42.9.131) 25-11-19 21:47:50 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# 100%|██████████| 4/4 [00:00<00:00, 171196.08it/s]
# (PoolActor pid=509988, ip=10.42.6.149) 25-11-19 21:47:59 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #321 | Ray is installed, version: 2.47.0
# (PoolActor pid=509988, ip=10.42.6.149) 25-11-19 21:47:59 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #459 | RAY_ADDRESS is set to 'ray://ray-head:10001', using ray (ignore 'no_ray (False)')...
# (PoolActor pid=509988, ip=10.42.6.149) 25-11-19 21:47:59 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #478 | Do 4 tasks [Called by: ..._ray_pkg_97a0c930ad95ed14/shadow_price_prediction/pipeline.py - run(...) #286] parallelly in ray 2 processes...
# (PoolActor pid=509988, ip=10.42.6.149) 25-11-19 21:47:59 EST | INFO    | /tmp/ray/session_2025-11-16_14-43-18_409267_1/runtime_resources/py_modules_files/_ray_pkg_99f88ab2ee9d98c2/pbase/config/ray.py | init_ray            | #42  | ray is already initialized, skipping init_ray
# (PoolActor pid=287792, ip=10.42.7.70) 25-11-19 21:48:00 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=287792, ip=10.42.7.70) 25-11-19 21:48:00 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=287792, ip=10.42.7.70) 25-11-19 21:48:00 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=287792, ip=10.42.7.70) 25-11-19 21:48:00 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=284758, ip=10.42.0.182) 25-11-19 21:47:59 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=284758, ip=10.42.0.182) 25-11-19 21:47:59 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=284758, ip=10.42.0.182) 25-11-19 21:47:59 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=284758, ip=10.42.0.182) 25-11-19 21:47:59 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# 100%|██████████| 4/4 [00:00<00:00, 184365.01it/s]
# ...
# (PoolActor pid=308611, ip=10.42.0.182) 25-11-20 07:52:28 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=308611, ip=10.42.0.182) 25-11-20 07:52:28 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=308611, ip=10.42.0.182) 25-11-20 07:52:28 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=311654, ip=10.42.7.70) 25-11-20 07:52:28 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=311654, ip=10.42.7.70) 25-11-20 07:52:28 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=369433, ip=10.42.8.15) 25-11-20 07:52:28 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=369433, ip=10.42.8.15) 25-11-20 07:52:28 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=369433, ip=10.42.8.15) 25-11-20 07:52:28 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=369433, ip=10.42.8.15) 25-11-20 07:52:28 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=311654, ip=10.42.7.70) 25-11-20 07:52:28 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=311654, ip=10.42.7.70) 25-11-20 07:52:28 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=367237, ip=10.42.9.131) 25-11-20 07:52:28 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=367237, ip=10.42.9.131) 25-11-20 07:52:28 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=367237, ip=10.42.9.131) 25-11-20 07:52:28 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=367237, ip=10.42.9.131) 25-11-20 07:52:28 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# 100%|██████████| 4/4 [00:00<00:00, 226719.14it/s]
# (PoolActor pid=357479, ip=10.42.4.173) 25-11-20 07:54:12 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #321 | Ray is installed, version: 2.47.0
# (PoolActor pid=357479, ip=10.42.4.173) 25-11-20 07:54:12 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #459 | RAY_ADDRESS is set to 'ray://ray-head:10001', using ray (ignore 'no_ray (False)')...
# (PoolActor pid=357479, ip=10.42.4.173) 25-11-20 07:54:12 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #478 | Do 4 tasks [Called by: ..._ray_pkg_97a0c930ad95ed14/shadow_price_prediction/pipeline.py - run(...) #286] parallelly in ray 2 processes...
# (PoolActor pid=357479, ip=10.42.4.173) 25-11-20 07:54:12 EST | INFO    | /tmp/ray/session_2025-11-16_14-43-18_409267_1/runtime_resources/py_modules_files/_ray_pkg_99f88ab2ee9d98c2/pbase/config/ray.py | init_ray            | #42  | ray is already initialized, skipping init_ray
# (PoolActor pid=283860, ip=10.42.0.182) 25-11-20 07:54:12 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #321 | Ray is installed, version: 2.47.0
# (PoolActor pid=283860, ip=10.42.0.182) 25-11-20 07:54:12 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #459 | RAY_ADDRESS is set to 'ray://ray-head:10001', using ray (ignore 'no_ray (False)')...
# (PoolActor pid=283860, ip=10.42.0.182) 25-11-20 07:54:12 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #478 | Do 4 tasks [Called by: ..._ray_pkg_97a0c930ad95ed14/shadow_price_prediction/pipeline.py - run(...) #286] parallelly in ray 2 processes...
# (PoolActor pid=283860, ip=10.42.0.182) 25-11-20 07:54:12 EST | INFO    | /tmp/ray/session_2025-11-16_14-43-18_409267_1/runtime_resources/py_modules_files/_ray_pkg_99f88ab2ee9d98c2/pbase/config/ray.py | init_ray            | #42  | ray is already initialized, skipping init_ray
# (PoolActor pid=311758, ip=10.42.7.70) 25-11-20 07:54:13 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=311758, ip=10.42.7.70) 25-11-20 07:54:13 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=311759, ip=10.42.7.70) 25-11-20 07:54:13 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=311759, ip=10.42.7.70) 25-11-20 07:54:13 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=308698, ip=10.42.0.182) 25-11-20 07:54:13 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=308698, ip=10.42.0.182) 25-11-20 07:54:13 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=308698, ip=10.42.0.182) 25-11-20 07:54:13 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=308698, ip=10.42.0.182) 25-11-20 07:54:13 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=308699, ip=10.42.0.182) 25-11-20 07:54:13 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=308699, ip=10.42.0.182) 25-11-20 07:54:13 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=308699, ip=10.42.0.182) 25-11-20 07:54:13 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=308699, ip=10.42.0.182) 25-11-20 07:54:13 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=311758, ip=10.42.7.70) 25-11-20 07:54:13 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=311758, ip=10.42.7.70) 25-11-20 07:54:13 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=311759, ip=10.42.7.70) 25-11-20 07:54:13 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=311759, ip=10.42.7.70) 25-11-20 07:54:13 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# 100%|██████████| 4/4 [00:00<00:00, 172960.99it/s]
# (PoolActor pid=286964, ip=10.42.7.70) 25-11-20 07:54:18 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #321 | Ray is installed, version: 2.47.0
# (PoolActor pid=286964, ip=10.42.7.70) 25-11-20 07:54:18 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #459 | RAY_ADDRESS is set to 'ray://ray-head:10001', using ray (ignore 'no_ray (False)')...
# (PoolActor pid=286964, ip=10.42.7.70) 25-11-20 07:54:18 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #478 | Do 4 tasks [Called by: ..._ray_pkg_97a0c930ad95ed14/shadow_price_prediction/pipeline.py - run(...) #286] parallelly in ray 2 processes...
# (PoolActor pid=286964, ip=10.42.7.70) 25-11-20 07:54:18 EST | INFO    | /tmp/ray/session_2025-11-16_14-43-18_409267_1/runtime_resources/py_modules_files/_ray_pkg_99f88ab2ee9d98c2/pbase/config/ray.py | init_ray            | #42  | ray is already initialized, skipping init_ray
# (PoolActor pid=286965, ip=10.42.7.70) 25-11-20 07:54:18 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #321 | Ray is installed, version: 2.47.0
# (PoolActor pid=286965, ip=10.42.7.70) 25-11-20 07:54:18 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #459 | RAY_ADDRESS is set to 'ray://ray-head:10001', using ray (ignore 'no_ray (False)')...
# (PoolActor pid=286965, ip=10.42.7.70) 25-11-20 07:54:18 EST | INFO    | pbase.utils.ray      | parallel_equal_pool | #478 | Do 4 tasks [Called by: ..._ray_pkg_97a0c930ad95ed14/shadow_price_prediction/pipeline.py - run(...) #286] parallelly in ray 2 processes...
# (PoolActor pid=286965, ip=10.42.7.70) 25-11-20 07:54:18 EST | INFO    | /tmp/ray/session_2025-11-16_14-43-18_409267_1/runtime_resources/py_modules_files/_ray_pkg_99f88ab2ee9d98c2/pbase/config/ray.py | init_ray            | #42  | ray is already initialized, skipping init_ray
# (PoolActor pid=369575, ip=10.42.8.15) 25-11-20 07:54:19 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=369575, ip=10.42.8.15) 25-11-20 07:54:19 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=369575, ip=10.42.8.15) 25-11-20 07:54:19 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=369575, ip=10.42.8.15) 25-11-20 07:54:19 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=311944, ip=10.42.7.70) 25-11-20 07:54:19 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=311944, ip=10.42.7.70) 25-11-20 07:54:19 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=311944, ip=10.42.7.70) 25-11-20 07:54:19 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=311944, ip=10.42.7.70) 25-11-20 07:54:19 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=367341, ip=10.42.9.131) 25-11-20 07:54:19 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=367341, ip=10.42.9.131) 25-11-20 07:54:19 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=367341, ip=10.42.9.131) 25-11-20 07:54:19 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=367341, ip=10.42.9.131) 25-11-20 07:54:19 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=308889, ip=10.42.0.182) 25-11-20 07:54:19 EST | INFO    | dotenv.main          | _get_stream         | #61  | python-dotenv could not find configuration file .env.
# (PoolActor pid=308889, ip=10.42.0.182) 25-11-20 07:54:19 EST | WARNING | pbase.utils.utils    | load_env            | #478 | .env could not be found...
# (PoolActor pid=308889, ip=10.42.0.182) 25-11-20 07:54:19 EST | INFO    | pbase.config.base    | load_global_config  | #435 | Loading config from local cached json file...
# (PoolActor pid=308889, ip=10.42.0.182) 25-11-20 07:54:19 EST | INFO    | pbase.config.base    | __init__            | #44  | Init global config...
# (PoolActor pid=308611, ip=10.42.0.182) Exception ignored on calling ctypes callback function <bound method DataIter._next_wrapper of <xgboost.data.SingleBatchInternalIter object at 0x7fb11c7109f0>>:
# (PoolActor pid=308611, ip=10.42.0.182) Traceback (most recent call last):
# (PoolActor pid=308611, ip=10.42.0.182)   File "/home/ray/.venv/lib/python3.13/site-packages/xgboost/core.py", line 640, in _next_wrapper
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 6
#       3 if remaining_iterations > 0:
#       4     print(f"Starting parallel execution with {min(remaining_iterations, n_jobs)} jobs...")
# ----> 6     results = parallel_equal_pool(
#       7         func=run_single_experiment,
#       8         param_dict_list=experiment_params,
#       9         n_jobs=min(remaining_iterations, n_jobs),
#      10         param_serialization='default',
#      11         raise_error=False,
#      12         use_tqdm=True
#      13     )
#      15     # Summary
#      16     success_count = sum(1 for r in results if r['status'] == 'success')
#
# File ~/workspace/pbase/src/pbase/utils/ray.py:530, in parallel_equal_pool(func, param_dict_list, param_serialization, n_jobs, chunksize, unordered, raise_error, memory_per_job, cpu_per_job, gpu_per_job, scheduling_strategy, retry, address, extra_modules, no_ray, catch_exceptions_1, use_tqdm, **kwargs)
#     528 if unordered:
#     529     if use_tqdm:
# --> 530         results = list(
#     531             tqdm(
#     532                 pool.imap_unordered(worker_func, working_param_list, chunksize=chunksize),
#     533                 total=len(working_param_list),
#     534             )
#     535         )
#     536     else:
#     537         results = list(pool.imap_unordered(worker_func, working_param_list, chunksize=chunksize))
#
# File ~/workspace/research-spice-shadow-price-pred/.venv/lib/python3.13/site-packages/tqdm/notebook.py:250, in tqdm_notebook.__iter__(self)
#     248 try:
#     249     it = super().__iter__()
# --> 250     for obj in it:
#     251         # return super(tqdm...) will not catch exception
#     252         yield obj
#     253 # NB: except ... [ as ...] breaks IPython async KeyboardInterrupt
#
# File ~/workspace/research-spice-shadow-price-pred/.venv/lib/python3.13/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File ~/workspace/research-spice-shadow-price-pred/.venv/lib/python3.13/site-packages/ray/util/multiprocessing/pool.py:442, in IMapIterator.__next__(self)
#     441 def __next__(self):
# --> 442     return self.next()
#
# File ~/workspace/research-spice-shadow-price-pred/.venv/lib/python3.13/site-packages/ray/util/multiprocessing/pool.py:509, in UnorderedIMapIterator.next(self, timeout)
#     502 if self._finished_iterating and (
#     503     self._next_chunk_index == len(self._submitted_chunks)
#     504 ):
#     505     # Finish when all chunks have been dispatched and processed
#     506     # Notify the calling process that the work is done.
#     507     raise StopIteration
# --> 509 index = self._result_thread.next_ready_index(timeout=timeout)
#     510 self._submit_next_chunk()
#     512 for result in self._result_thread.result(index):
#
# File ~/workspace/research-spice-shadow-price-pred/.venv/lib/python3.13/site-packages/ray/util/multiprocessing/pool.py:310, in ResultThread.next_ready_index(self, timeout)
#     308 def next_ready_index(self, timeout=None):
#     309     try:
# --> 310         return self._ready_index_queue.get(timeout=timeout)
#     311     except queue.Empty:
#     312         # queue.Queue signals a timeout by raising queue.Empty.
#     313         raise TimeoutError
#
# File ~/.local/uv/python/cpython-3.13.5-linux-x86_64-gnu/lib/python3.13/queue.py:202, in Queue.get(self, block, timeout)
#     200 elif timeout is None:
#     201     while not self._qsize():
# --> 202         self.not_empty.wait()
#     203         if self.is_shutdown and not self._qsize():
#     204             raise ShutDown
#
# File ~/.local/uv/python/cpython-3.13.5-linux-x86_64-gnu/lib/python3.13/threading.py:359, in Condition.wait(self, timeout)
#     357 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     358     if timeout is None:
# --> 359         waiter.acquire()
#     360         gotit = True
#     361     else:
#
# KeyboardInterrupt:

# %% [markdown]
# ## 5. Analyze Best Results

# %%
metrics_dir = BASE_OUTPUT_DIR / 'metrics'

if metrics_dir.exists():
    all_metrics = []
    for file in metrics_dir.glob('iter_*.parquet'):
        try:
            df = pd.read_parquet(file)
            all_metrics.append(df)
        except Exception as e:
            print(f"Warning: Could not load {file.name}: {e}")
    
    if all_metrics:
        combined_metrics = pd.concat(all_metrics, ignore_index=True)
        
        print(f"Total runs analyzed: {len(combined_metrics)}")
        
        # Best by F1 Score
        if 'F1' in combined_metrics.columns:
            best_idx = combined_metrics['F1'].idxmax()
            best_result = combined_metrics.iloc[best_idx]
            
            print("\n" + "=" * 60)
            print("Best Run (by F1 Score)")
            print("=" * 60)
            print(f"Iteration: {best_result.get('iteration', 'N/A')}")
            print(f"F1 Score: {best_result['F1']:.4f}")
            if 'MAE' in best_result:
                print(f"MAE: {best_result['MAE']:.4f}")
            if 'Precision' in best_result:
                print(f"Precision: {best_result['Precision']:.4f}")
            if 'Recall' in best_result:
                print(f"Recall: {best_result['Recall']:.4f}")
            
            # Print parameters
            print("\nParameters:")
            param_cols = [col for col in combined_metrics.columns 
                         if col not in ['F1', 'Precision', 'Recall', 'MAE', 'RMSE', 'R2',
                                       'iteration', 'timestamp', 'run_id', 'metrics_file',
                                       'per_outage_file', 'agg_file']]
            for col in param_cols:
                print(f"  {col}: {best_result[col]}")
        
        # Best by MAE (lower is better)
        if 'MAE' in combined_metrics.columns:
            best_idx = combined_metrics['MAE'].idxmin()
            best_result = combined_metrics.iloc[best_idx]
            
            print("\n" + "=" * 60)
            print("Best Run (by MAE)")
            print("=" * 60)
            print(f"Iteration: {best_result.get('iteration', 'N/A')}")
            print(f"MAE: {best_result['MAE']:.4f}")
            if 'F1' in best_result:
                print(f"F1 Score: {best_result['F1']:.4f}")
            if 'RMSE' in best_result:
                print(f"RMSE: {best_result['RMSE']:.4f}")
            
            # Print parameters
            print("\nParameters:")
            for col in param_cols:
                print(f"  {col}: {best_result[col]}")
# Out:
# Total runs analyzed: 3

# %% [markdown]
# ## 6. View Results Summary

# %%
if 'combined_metrics' in locals():
    # Display summary statistics
    print("Summary Statistics:")
    print("=" * 60)
    
    metric_cols = ['f1_score', 'precision', 'recall', 'mae', 'rmse']
    available_metrics = [col for col in metric_cols if col in combined_metrics.columns]
    
    summary = combined_metrics[available_metrics].describe()
    print(summary)
    
    # Optionally display the top 5 runs by F1
    if 'F1' in combined_metrics.columns:
        print("\n" + "=" * 60)
        print("Top 5 Runs by F1 Score")
        print("=" * 60)
        
        display_cols = ['iteration'] + available_metrics
        top5 = combined_metrics.nlargest(5, 'F1')[display_cols]
        print(top5.to_string(index=False))
# Out:
# Summary Statistics:
# ============================================================
#        f1_score  precision    recall         mae         rmse
# count  3.000000   3.000000  3.000000    3.000000     3.000000
# mean   0.316343   0.314473  0.320927  344.475091  1910.261852
# std    0.048320   0.023213  0.073790    6.542887    10.179312
# min    0.267681   0.291769  0.247267  336.960047  1899.808735
# 25%    0.292358   0.302628  0.283967  342.260002  1905.321146
# 50%    0.317036   0.313486  0.320666  347.559956  1910.833558
# 75%    0.340674   0.325825  0.357756  348.232612  1915.488411
# max    0.364313   0.338163  0.394846  348.905269  1920.143264

# %%
# import shutil

# shutil.rmtree(BASE_OUTPUT_DIR)
