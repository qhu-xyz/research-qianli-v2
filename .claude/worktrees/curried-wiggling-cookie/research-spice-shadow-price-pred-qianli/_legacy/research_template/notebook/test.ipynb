# %%
from pbase.analysis.tools.all_positions import MisoApTools

aptools = MisoApTools()
aptools.get_all_cleared_trades(start_date="2024-06-01", end_date="2024-08-01")
# Out:
#         hedge_type trade_type class_type  cleared_volume     mcp  \
# 0       obligation        buy    offpeak             6.0 -228.51
# 1       obligation        buy    offpeak             1.0   37.34
# 2       obligation        buy     onpeak             0.9  -10.69
# 3       obligation        buy     onpeak             0.4  -10.69
# 4       obligation        buy    offpeak             0.4   -6.33
# ...            ...        ...        ...             ...     ...
# 630364  obligation        buy     onpeak             0.5 -349.32
# 630365  obligation        buy    offpeak             0.1 -750.55
# 630366  obligation       sell     onpeak             5.2 -224.01
# 630367  obligation        buy    offpeak             0.2   -2.62
# 630368  obligation       sell     onpeak             5.0 -480.49
#
#         split_month_mcp split_market_month  split_month_hours  \
# 0               -228.51         2024-06-01                400
# ...
